# %%
import pandas as pd    # загрузка библиотеки pandas
'''from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
'''
from numpy import isnan   # загрузка функции из numpy

# %%
# загружаем бд  city
df_city=pd.read_sql(
"""
SELECT
  *
FROM
  city
""",
"postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)
df_city.head(7)
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
#    id            name country_code       district  population
# 0   1           Kabul          AFG          Kabol     1780000
# 1   2        Qandahar          AFG       Qandahar      237500
# 2   3           Herat          AFG          Herat      186800
# 3   4  Mazar-e-Sharif          AFG          Balkh      127800
# 4   5       Amsterdam          NLD  Noord-Holland      731200
# 5   6       Rotterdam          NLD   Zuid-Holland      593321
# 6   7            Haag          NLD   Zuid-Holland      440900

# %%
# загружаем  CSV
df_holidays = pd.read_csv('Holidays (Responses) - Form responses 1.csv', sep=",")
# смотрим первые 5 строк таблицы
display(df_holidays.head())
# смотрим последние 5 строк таблицы
display(df_holidays.tail())
# Out:
#            Timestamp Страна пребывания Город размещения Дата выезда  \
# 0  5/26/2022 8:19:04            Италия            Милан    1/6/2018
# 1  5/26/2022 8:20:52            Турция          Анталья  10/27/2018
# 2  5/26/2022 8:36:04           Франция         Гренобль    1/5/2019
# 3  5/26/2022 8:38:04           Австрия             Вена   9/14/2019
# 4  5/26/2022 8:39:15           Австрия          Серфаус   1/11/2020
#
#   Дата возращения  Планируемый бюджет поездки (руб.)  Дней       City  \
# 0       1/20/2018                             175000    14     Milano
# 1       11/3/2018                             130000     7    Antalya
# 2       1/12/2019                              90000     7   Grenoble
# 3       9/21/2019                             100000     7       Wien
# 4       1/18/2020                             140000     7  Innsbruck
#
#    Стоимость билетов  Стоимость отеля  Расходы на месте  Всего расходов  \
# ...

# %%
# объединяем бд по наименованию города
df_merged = pd.merge(df_holidays, df_city,how="left", left_on="City", right_on="name")
df_merged
# Out:
#             Timestamp Страна пребывания Город размещения Дата выезда  \
# 0   5/26/2022 8:19:04            Италия            Милан    1/6/2018
# 1   5/26/2022 8:20:52            Турция          Анталья  10/27/2018
# 2   5/26/2022 8:36:04           Франция         Гренобль    1/5/2019
# 3   5/26/2022 8:38:04           Австрия             Вена   9/14/2019
# 4   5/26/2022 8:39:15           Австрия          Серфаус   1/11/2020
# 5   5/26/2022 8:40:04                РФ  Санкт-Петербург    8/3/2020
# 6   5/26/2022 8:41:11            Турция          Анталья   5/29/2021
# 7   5/26/2022 8:42:09            Грузия        Бакуриани    3/6/2021
# 8   5/26/2022 8:43:38              Кипр          Никосия  10/30/2021
# 9   5/26/2022 8:47:18                РФ             Сочи    2/5/2022
# 10  5/26/2022 8:49:21           Армения           Ереван   2/24/2022
#
#    Дата возращения  Планируемый бюджет поездки (руб.)  Дней           City  \
# ...

# %%
#  тренировочный фрагмент. использовал для поиска по базе подходящих городов
df_query=pd.read_sql(
"""
SELECT 
  * 
FROM  
  city c
INNER JOIN
  country co
ON 
  co.code = c.country_code
WHERE
  c.country_code like 'GE_'
""",
'postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db'
)
df_query
# Out:
#     id     name country_code            district  population code     name  \
# 0  905  Tbilisi          GEO             Tbilisi     1235200  GEO  Georgia
# 1  906  Kutaisi          GEO             Imereti      240900  GEO  Georgia
# 2  907  Rustavi          GEO        Kvemo Kartli      155400  GEO  Georgia
# 3  908   Batumi          GEO    Adzaria [Atara]      137700  GEO  Georgia
# 4  909   Sohumi          GEO  Abhasia [Aphazeti]      111700  GEO  Georgia
#
#   continent       region  surface_area  indep_year  population  \
# 0      Asia  Middle East       69700.0        1991     4968000
# 1      Asia  Middle East       69700.0        1991     4968000
# 2      Asia  Middle East       69700.0        1991     4968000
# 3      Asia  Middle East       69700.0        1991     4968000
# 4      Asia  Middle East       69700.0        1991     4968000
#
#    life_expectancy     gnp  gnp_old  local_name government_form  \
# 0             64.5  6064.0   5924.0  Sakartvelo        Republic
# ...

# %%
#  проверка на отсутствие данных по населению городов. В city нет города с таким названием....
#  простой вариант - вручную исправить в CSV.  ВРУЧНУЮ поправил справочник в Google Sheets

df_merged[(isnan(df_merged['population']))]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Страна пребывания, Город размещения, Дата выезда, Дата возращения, Планируемый бюджет поездки (руб.), Дней, City, Стоимость билетов, Стоимость отеля, Расходы на месте, Всего расходов, Отклонение, Оценка, Стоимость 1 дня отпуска, id, name, country_code, district, population]
# Index: []

# %% [markdown]
# Выводится пустая бд. Все данные заполнены. В противном случае будут NaN из df_city

# %%
# прикидка на глаз, всё ли в порядке
df_merged.tail()
# Out:
#             Timestamp Страна пребывания Город размещения Дата выезда  \
# 6   5/26/2022 8:41:11            Турция          Анталья   5/29/2021
# 7   5/26/2022 8:42:09            Грузия        Бакуриани    3/6/2021
# 8   5/26/2022 8:43:38              Кипр          Никосия  10/30/2021
# 9   5/26/2022 8:47:18                РФ             Сочи    2/5/2022
# 10  5/26/2022 8:49:21           Армения           Ереван   2/24/2022
#
#    Дата возращения  Планируемый бюджет поездки (руб.)  Дней     City  \
# 6        6/12/2021                             160000    14  Antalya
# 7        3/13/2021                             100000     7  Tbilisi
# 8        11/6/2021                             130000     7  Nicosia
# 9        2/12/2022                             110000     7   Maikop
# 10       3/26/2022                              90000    30  Yerevan
#
#     Стоимость билетов  Стоимость отеля  Расходы на месте  Всего расходов  \
# ...

# %%
#  рассчитать  среднюю численность населения в посещенных городах в разбивке по странам
df_merged\
  .groupby(['country_code'])['population']\
  .agg(['mean', 'count'])\
  .sort_values(by='mean',ascending=False)\
  #.head(15)
# Out:
#                    mean  count
# country_code
# RUS           2430650.0      2
# ITA           1300977.0      1
# ARM           1248700.0      1
# GEO           1235200.0      1
# AUT            859948.0      2
# TUR            564914.0      2
# CYP            195000.0      1
# FRA            153317.0      1
