# %% [markdown]
# # Машинное обучение на PySpark

# %% [markdown]
# ## Установка PySpark

# %%
# !apt-get update #libraries update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null # java installation
# !wget -q https://downloads.apache.org/spark/spark-3.3.1/spark-3.3.1-bin-hadoop3-scala2.13.tgz #download actual spark version
# !tar -xvf spark-3.3.1-bin-hadoop3-scala2.13.tgz # unzip spark 
# !pip install -q findspark # install python findspark module

import os
# define environment variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.3.1-bin-hadoop3-scala2.13"

"""Find spark home, and initialize by adding pyspark to sys.path.

If SPARK_HOME is defined, it will be used to put pyspark on sys.path.
Otherwise, common locations for spark will be searched."""

import findspark
# initialize findspark
findspark.init()
from pyspark.sql import SparkSession

# master. Sets the Spark master URL to connect to, 
#such as "local" to run locally, "local[4]" to run locally with 4 cores, 
#or "spark://master:7077" to run on a Spark standalone cluster.
spark = SparkSession.builder.master("local[*]").getOrCreate()

"""
Main entry point for Spark functionality. 
A SparkContext represents the connection to a Spark cluster, and can be used to create RDDs, 
accumulators and broadcast variables on that cluster.
Only one SparkContext may be active per JVM. 
You must stop() the active SparkContext before creating a new one.
"""

#sc = spark.sparkContext
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:2 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# spark-3.3.1-bin-hadoop3-scala2.13/
# spark-3.3.1-bin-hadoop3-scala2.13/LICENSE
# spark-3.3.1-bin-hadoop3-scala2.13/NOTICE
# spark-3.3.1-bin-hadoop3-scala2.13/R/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/DESCRIPTION
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/INDEX
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/Meta/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/Meta/Rd.rds
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/Meta/features.rds
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/Meta/hsearch.rds
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/Meta/links.rds
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/Meta/nsInfo.rds
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/Meta/package.rds
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/NAMESPACE
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/R/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/R/SparkR
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/R/SparkR.rdb
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/R/SparkR.rdx
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/help/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/help/AnIndex
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/help/SparkR.rdb
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/help/SparkR.rdx
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/help/aliases.rds
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/help/paths.rds
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/html/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/html/00Index.html
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/html/R.css
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/profile/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/profile/general.R
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/profile/shell.R
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/tests/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/tests/testthat/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/tests/testthat/test_basic.R
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/worker/
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/worker/daemon.R
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/SparkR/worker/worker.R
# spark-3.3.1-bin-hadoop3-scala2.13/R/lib/sparkr.zip
# spark-3.3.1-bin-hadoop3-scala2.13/README.md
# spark-3.3.1-bin-hadoop3-scala2.13/RELEASE
# spark-3.3.1-bin-hadoop3-scala2.13/bin/
# spark-3.3.1-bin-hadoop3-scala2.13/bin/beeline
# spark-3.3.1-bin-hadoop3-scala2.13/bin/beeline.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/docker-image-tool.sh
# spark-3.3.1-bin-hadoop3-scala2.13/bin/find-spark-home
# spark-3.3.1-bin-hadoop3-scala2.13/bin/find-spark-home.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/load-spark-env.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/load-spark-env.sh
# spark-3.3.1-bin-hadoop3-scala2.13/bin/pyspark
# spark-3.3.1-bin-hadoop3-scala2.13/bin/pyspark.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/pyspark2.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/run-example
# spark-3.3.1-bin-hadoop3-scala2.13/bin/run-example.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-class
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-class.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-class2.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-shell
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-shell.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-shell2.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-sql
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-sql.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-sql2.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-submit
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-submit.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/spark-submit2.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/sparkR
# spark-3.3.1-bin-hadoop3-scala2.13/bin/sparkR.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/bin/sparkR2.cmd
# spark-3.3.1-bin-hadoop3-scala2.13/conf/
# spark-3.3.1-bin-hadoop3-scala2.13/conf/fairscheduler.xml.template
# spark-3.3.1-bin-hadoop3-scala2.13/conf/log4j2.properties.template
# spark-3.3.1-bin-hadoop3-scala2.13/conf/metrics.properties.template
# spark-3.3.1-bin-hadoop3-scala2.13/conf/spark-defaults.conf.template
# spark-3.3.1-bin-hadoop3-scala2.13/conf/spark-env.sh.template
# spark-3.3.1-bin-hadoop3-scala2.13/conf/workers.template
# spark-3.3.1-bin-hadoop3-scala2.13/data/
# spark-3.3.1-bin-hadoop3-scala2.13/data/graphx/
# spark-3.3.1-bin-hadoop3-scala2.13/data/graphx/followers.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/graphx/users.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/als/
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/als/sample_movielens_ratings.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/als/test.data
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/gmm_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/license.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/kittens/
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/kittens/29.5.a_b_EGDP022204.jpg
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/kittens/54893.jpg
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/kittens/DP153539.jpg
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/kittens/DP802813.jpg
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/kittens/not-image.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/license.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/multi-channel/
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/multi-channel/BGRA.png
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/multi-channel/BGRA_alpha_60.png
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/multi-channel/chr30.4.184.jpg
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/images/origin/multi-channel/grayscale.jpg
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/kmeans_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/pagerank_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/pic_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/ridge-data/
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/ridge-data/lpsa.data
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_binary_classification_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_fpgrowth.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_isotonic_regression_libsvm_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_kmeans_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_lda_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_lda_libsvm_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_libsvm_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_linear_regression_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_movielens_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_multiclass_classification_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/sample_svm_data.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/mllib/streaming_kmeans_data_test.txt
# spark-3.3.1-bin-hadoop3-scala2.13/data/streaming/
# spark-3.3.1-bin-hadoop3-scala2.13/data/streaming/AFINN-111.txt
# spark-3.3.1-bin-hadoop3-scala2.13/examples/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/jars/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/jars/scopt_2.13-3.7.1.jar
# spark-3.3.1-bin-hadoop3-scala2.13/examples/jars/spark-examples_2.13-3.3.1.jar
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/JavaHdfsLR.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/JavaLogQuery.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/JavaPageRank.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/JavaSparkPi.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/JavaStatusTrackerDemo.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/JavaTC.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/JavaWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaAFTSurvivalRegressionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaALSExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaBinarizerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaBisectingKMeansExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaBucketedRandomProjectionLSHExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaBucketizerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaChiSqSelectorExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaChiSquareTestExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaCorrelationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaCountVectorizerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaDCTExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaDecisionTreeClassificationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaDecisionTreeRegressionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaDocument.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaElementwiseProductExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaEstimatorTransformerParamExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaFMClassifierExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaFMRegressorExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaFPGrowthExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaFeatureHasherExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaGaussianMixtureExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaGeneralizedLinearRegressionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaGradientBoostedTreeClassifierExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaGradientBoostedTreeRegressorExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaImputerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaIndexToStringExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaInteractionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaIsotonicRegressionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaKMeansExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaLDAExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaLabeledDocument.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaLinearRegressionWithElasticNetExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaLinearSVCExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaLogisticRegressionSummaryExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaLogisticRegressionWithElasticNetExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaMaxAbsScalerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaMinHashLSHExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaMinMaxScalerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaModelSelectionViaCrossValidationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaModelSelectionViaTrainValidationSplitExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaMulticlassLogisticRegressionWithElasticNetExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaMultilayerPerceptronClassifierExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaNGramExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaNaiveBayesExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaNormalizerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaOneHotEncoderExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaOneVsRestExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaPCAExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaPipelineExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaPolynomialExpansionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaPowerIterationClusteringExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaPrefixSpanExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaQuantileDiscretizerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaRFormulaExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaRandomForestClassifierExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaRandomForestRegressorExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaRobustScalerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaSQLTransformerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaStandardScalerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaStopWordsRemoverExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaStringIndexerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaSummarizerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaTfIdfExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaTokenizerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaUnivariateFeatureSelectorExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaVarianceThresholdSelectorExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorAssemblerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorIndexerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorSizeHintExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaVectorSlicerExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/ml/JavaWord2VecExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaALS.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaAssociationRulesExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaBinaryClassificationMetricsExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaBisectingKMeansExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaChiSqSelectorExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaCorrelationsExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaDecisionTreeClassificationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaDecisionTreeRegressionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaElementwiseProductExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaGaussianMixtureExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaGradientBoostingClassificationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaGradientBoostingRegressionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaHypothesisTestingExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaHypothesisTestingKolmogorovSmirnovTestExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaIsotonicRegressionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaKMeansExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaKernelDensityEstimationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaLBFGSExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaLatentDirichletAllocationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaLogisticRegressionWithLBFGSExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaMultiLabelClassificationMetricsExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaMulticlassClassificationMetricsExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaNaiveBayesExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaPCAExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaPowerIterationClusteringExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaPrefixSpanExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaRandomForestClassificationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaRandomForestRegressionExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaRankingMetricsExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaRecommendationExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaSVDExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaSVMWithSGDExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaSimpleFPGrowth.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaStratifiedSamplingExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaStreamingTestExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/mllib/JavaSummaryStatisticsExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/JavaSQLDataSourceExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/JavaSparkSQLExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedScalar.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedTypedAggregation.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/JavaUserDefinedUntypedAggregation.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/hive/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/hive/JavaSparkHiveExample.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/streaming/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredComplexSessionization.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredKafkaWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredKerberizedKafkaWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredNetworkWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredNetworkWordCountWindowed.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/sql/streaming/JavaStructuredSessionization.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaCustomReceiver.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaDirectKafkaWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaDirectKerberizedKafkaWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaNetworkWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaQueueStream.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaRecord.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaRecoverableNetworkWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaSqlNetworkWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/java/org/apache/spark/examples/streaming/JavaStatefulNetworkWordCount.java
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/als.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/avro_inputformat.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/kmeans.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/logistic_regression.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/__init__,py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/aft_survival_regression.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/als_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/binarizer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/bisecting_k_means_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/bucketed_random_projection_lsh_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/bucketizer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/chi_square_test_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/chisq_selector_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/correlation_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/count_vectorizer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/cross_validator.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/dataframe_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/dct_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/decision_tree_classification_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/decision_tree_regression_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/elementwise_product_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/estimator_transformer_param_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/feature_hasher_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/fm_classifier_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/fm_regressor_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/fpgrowth_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/gaussian_mixture_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/generalized_linear_regression_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/gradient_boosted_tree_classifier_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/gradient_boosted_tree_regressor_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/imputer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/index_to_string_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/interaction_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/isotonic_regression_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/kmeans_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/lda_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/linear_regression_with_elastic_net.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/linearsvc.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/logistic_regression_summary_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/logistic_regression_with_elastic_net.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/max_abs_scaler_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/min_hash_lsh_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/min_max_scaler_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/multiclass_logistic_regression_with_elastic_net.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/multilayer_perceptron_classification.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/n_gram_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/naive_bayes_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/normalizer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/one_vs_rest_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/onehot_encoder_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/pca_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/pipeline_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/polynomial_expansion_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/power_iteration_clustering_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/prefixspan_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/quantile_discretizer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/random_forest_classifier_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/random_forest_regressor_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/rformula_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/robust_scaler_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/sql_transformer.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/standard_scaler_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/stopwords_remover_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/string_indexer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/summarizer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/tf_idf_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/tokenizer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/train_validation_split.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/univariate_feature_selector_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/variance_threshold_selector_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/vector_assembler_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/vector_indexer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/vector_size_hint_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/vector_slicer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/ml/word2vec_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/binary_classification_metrics_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/bisecting_k_means_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/correlations.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/correlations_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/decision_tree_classification_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/decision_tree_regression_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/elementwise_product_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/fpgrowth_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/gaussian_mixture_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/gaussian_mixture_model.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/gradient_boosting_classification_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/gradient_boosting_regression_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/hypothesis_testing_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/hypothesis_testing_kolmogorov_smirnov_test_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/isotonic_regression_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/k_means_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/kernel_density_estimation_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/kmeans.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/latent_dirichlet_allocation_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/linear_regression_with_sgd_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/logistic_regression.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/logistic_regression_with_lbfgs_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/multi_class_metrics_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/multi_label_metrics_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/naive_bayes_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/normalizer_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/pca_rowmatrix_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/power_iteration_clustering_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/random_forest_classification_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/random_forest_regression_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/random_rdd_generation.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/ranking_metrics_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/recommendation_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/regression_metrics_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/sampled_rdds.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/standard_scaler_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/stratified_sampling_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/streaming_k_means_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/streaming_linear_regression_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/summary_statistics_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/svd_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/svm_with_sgd_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/tf_idf_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/word2vec.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/mllib/word2vec_example.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/pagerank.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/parquet_inputformat.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/pi.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sort.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/arrow.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/basic.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/datasource.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/hive.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/streaming/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/streaming/__init__,py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/streaming/structured_kafka_wordcount.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/streaming/structured_network_wordcount.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/streaming/structured_network_wordcount_windowed.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/sql/streaming/structured_sessionization.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/status_api_demo.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/hdfs_wordcount.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/network_wordcount.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/network_wordjoinsentiments.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/queue_stream.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/recoverable_network_wordcount.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/sql_network_wordcount.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/streaming/stateful_network_wordcount.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/transitive_closure.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/python/wordcount.py
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/RSparkSQLExample.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/data-manipulation.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/dataframe.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/als.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/bisectingKmeans.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/decisionTree.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/fmClassifier.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/fmRegressor.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/fpm.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/gaussianMixture.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/gbt.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/glm.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/isoreg.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/kmeans.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/kstest.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/lda.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/lm_with_elastic_net.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/logit.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/ml.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/mlp.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/naiveBayes.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/powerIterationClustering.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/prefixSpan.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/randomForest.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/survreg.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/ml/svmLinear.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/streaming/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/r/streaming/structured_network_wordcount.R
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/META-INF/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/META-INF/services/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/META-INF/services/org.apache.spark.sql.SparkSessionExtensionsProvider
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/META-INF/services/org.apache.spark.sql.jdbc.JdbcConnectionProvider
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/dir1/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/dir1/dir2/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/dir1/dir2/file2.parquet
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/dir1/file1.parquet
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/dir1/file3.json
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/employees.json
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/full_user.avsc
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/kv1.txt
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/people.csv
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/people.json
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/people.txt
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/user.avsc
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/users.avro
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/users.orc
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/resources/users.parquet
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/AccumulatorMetricsTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/BroadcastTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/DFSReadWriteTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/DriverSubmissionTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/ExceptionHandlingTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/GroupByTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/HdfsTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/LocalALS.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/LocalFileLR.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/LocalKMeans.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/LocalLR.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/LocalPi.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/LogQuery.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/MiniReadWriteTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/MultiBroadcastTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SimpleSkewedGroupByTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SkewedGroupByTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SparkALS.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SparkHdfsLR.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SparkKMeans.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SparkLR.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SparkPageRank.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SparkPi.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SparkRemoteFileTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/SparkTC.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/extensions/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/extensions/AgeExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/extensions/SessionExtensionsWithLoader.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/extensions/SessionExtensionsWithoutLoader.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/extensions/SparkSessionExtensionsTest.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/AggregateMessagesExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/Analytics.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/ComprehensiveExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/ConnectedComponentsExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/LiveJournalPageRank.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/PageRankExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/SSSPExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/SynthBenchmark.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/graphx/TriangleCountingExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/ml/
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/ml/AFTSurvivalRegressionExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/ml/ALSExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/ml/BinarizerExample.scala
# spark-3.3.1-bin-hadoop3-scala2.13/examples/src/main/scala/org/apache/spark/examples/ml/BisectingKMeansExample.scala
# ...
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/observation.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/_typing/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/_typing/__init__.pyi
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/_typing/protocols/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/_typing/protocols/__init__.pyi
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/_typing/protocols/frame.pyi
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/_typing/protocols/series.pyi
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/conversion.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/functions.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/functions.pyi
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/group_ops.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/map_ops.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/serializers.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/typehints.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/types.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/pandas/utils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/readwriter.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/session.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/sql_formatter.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/streaming.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_arrow.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_arrow_map.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_catalog.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_column.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_conf.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_context.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_dataframe.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_datasources.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_functions.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_group.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_cogrouped_map.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_grouped_map.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_map.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_udf.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_udf_grouped_agg.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_udf_scalar.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_udf_typehints.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_udf_typehints_with_future_annotations.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_pandas_udf_window.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_readwriter.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_serde.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_session.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_streaming.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_types.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_udf.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_udf_profiler.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/test_utils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/typing/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/typing/test_column.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/typing/test_dataframe.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/typing/test_functions.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/typing/test_readwriter.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/typing/test_session.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/tests/typing/test_udf.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/types.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/udf.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/utils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/sql/window.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/statcounter.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/status.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/storagelevel.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/context.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/dstream.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/kinesis.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/listener.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/tests/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/tests/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/tests/test_context.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/tests/test_dstream.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/tests/test_kinesis.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/tests/test_listener.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/streaming/util.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/taskcontext.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/testing/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/testing/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/testing/mllibutils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/testing/mlutils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/testing/pandasutils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/testing/sqlutils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/testing/streamingutils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/testing/utils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/__init__.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_appsubmit.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_broadcast.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_conf.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_context.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_daemon.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_install_spark.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_join.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_pin_thread.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_profiler.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_rdd.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_rddbarrier.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_readwrite.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_serializers.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_shuffle.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_statcounter.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_taskcontext.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_util.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/test_worker.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/typing/
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/typing/test_context.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/typing/test_core.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/typing/test_rdd.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/tests/typing/test_resultiterable.yml
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/traceback_utils.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/util.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/version.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/pyspark/worker.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/run-tests
# spark-3.3.1-bin-hadoop3-scala2.13/python/run-tests-with-coverage
# spark-3.3.1-bin-hadoop3-scala2.13/python/run-tests.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/setup.cfg
# spark-3.3.1-bin-hadoop3-scala2.13/python/setup.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_coverage/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_coverage/conf/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_coverage/conf/spark-defaults.conf
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_coverage/coverage_daemon.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_coverage/sitecustomize.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/SimpleHTTPServer.py
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/hello/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/hello/hello.txt
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/hello/sub_hello/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/hello/sub_hello/sub_hello.txt
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/ages.csv
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/ages_newlines.csv
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/_SUCCESS
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/b=0/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/b=0/c=0/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/b=0/c=0/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/b=0/c=0/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/b=1/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/b=1/c=1/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/b=1/c=1/.part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc.crc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/orc_partitioned/b=1/c=1/part-r-00000-829af031-b970-49d6-ad39-30460a0be2c8.orc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/_SUCCESS
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/_common_metadata
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/_metadata
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2014/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2014/month=9/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/.part-r-00008.gz.parquet.crc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2014/month=9/day=1/part-r-00008.gz.parquet
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/.part-r-00002.gz.parquet.crc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/.part-r-00004.gz.parquet.crc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/part-r-00002.gz.parquet
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=25/part-r-00004.gz.parquet
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/.part-r-00005.gz.parquet.crc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=10/day=26/part-r-00005.gz.parquet
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=9/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/.part-r-00007.gz.parquet.crc
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/parquet_partitioned/year=2015/month=9/day=1/part-r-00007.gz.parquet
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/people.json
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/people1.json
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/people_array.json
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/people_array_utf16le.json
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/streaming/
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/streaming/text-test.txt
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/sql/text-test.txt
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/userlib-0.1.zip
# spark-3.3.1-bin-hadoop3-scala2.13/python/test_support/userlibrary.py
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/decommission-slave.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/decommission-worker.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/slaves.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/spark-config.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/spark-daemon.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/spark-daemons.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-all.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-history-server.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-master.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-mesos-dispatcher.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-mesos-shuffle-service.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-slave.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-slaves.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-thriftserver.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-worker.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/start-workers.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-all.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-history-server.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-master.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-mesos-dispatcher.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-mesos-shuffle-service.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-slave.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-slaves.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-thriftserver.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-worker.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/stop-workers.sh
# spark-3.3.1-bin-hadoop3-scala2.13/sbin/workers.sh
# spark-3.3.1-bin-hadoop3-scala2.13/yarn/
# spark-3.3.1-bin-hadoop3-scala2.13/yarn/spark-3.3.1-yarn-shuffle.jar
# '\nMain entry point for Spark functionality. \nA SparkContext represents the connection to a Spark cluster, and can be used to create RDDs, \naccumulators and broadcast variables on that cluster.\nOnly one SparkContext may be active per JVM. \nYou must stop() the active SparkContext before creating a new one.\n'

# %% [markdown]
# ## Загружаем набор данных

# %% [markdown]
# Predict survival on the Titanic
# * survival - Survival	0 = No, 1 = Yes
# * pclass - Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# * sex	- Sex
# * Age	- Age in years
# * sibsp	- # of siblings / spouses aboard the Titanic
# * parch	- # of parents / children aboard the Titanic
# * ticket - Ticket number
# * fare -	Passenger fare
# * cabin	- Cabin number
# * embarked - Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton

# %%
# !wget https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# Out:
# --2022-11-09 16:47:12--  https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  58.89K  --.-KB/s    in 0.001s
#
# 2022-11-09 16:47:12 (52.4 MB/s) - ‘titanic.csv’ saved [60302/60302]

# %% [markdown]
# ## Практика 1. Загрузите файл titanic.csv и выведите его командой show

# %%
df = spark.read.csv('titanic.csv', inferSchema=True, header=True)
df.count()
# Out:
# 891

# %%
df.summary().show()
# Out:
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+
# |summary|      PassengerId|           Survived|            Pclass|                Name|   Sex|               Age|             SibSp|              Parch|            Ticket|             Fare|Cabin|Embarked|
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+
# |  count|              891|                891|               891|                 891|   891|               714|               891|                891|               891|              891|  204|     889|
# |   mean|            446.0| 0.3838383838383838| 2.308641975308642|                null|  null| 29.69911764705882|0.5230078563411896|0.38159371492704824|260318.54916792738| 32.2042079685746| null|    null|
# | stddev|257.3538420152301|0.48659245426485753|0.8360712409770491|                null|  null|14.526497332334035|1.1027434322934315| 0.8060572211299488|471609.26868834975|49.69342859718089| null|    null|
# |    min|                1|                  0|                 1|"Andersson, Mr. A...|female|              0.42|                 0|                  0|            110152|              0.0|  A10|       C|
# |    25%|              223|                  0|                 2|                null|  null|              20.0|                 0|                  0|           19996.0|           7.8958| null|    null|
# |    50%|              446|                  0|                 3|                null|  null|              28.0|                 0|                  0|          236171.0|          14.4542| null|    null|
# |    75%|              669|                  1|                 3|                null|  null|              38.0|                 1|                  0|          347743.0|             31.0| null|    null|
# |    max|              891|                  1|                 3|van Melkebeke, Mr...|  male|              80.0|                 8|                  6|         WE/P 5735|         512.3292|    T|       S|
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+

# %% [markdown]
# ## Посмотрим общую статистику по нашему датафрейму
# Для этого воспользуемся командой describe

# %%
df.describe().show()
# Out:
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+
# |summary|      PassengerId|           Survived|            Pclass|                Name|   Sex|               Age|             SibSp|              Parch|            Ticket|             Fare|Cabin|Embarked|
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+
# |  count|              891|                891|               891|                 891|   891|               714|               891|                891|               891|              891|  204|     889|
# |   mean|            446.0| 0.3838383838383838| 2.308641975308642|                null|  null| 29.69911764705882|0.5230078563411896|0.38159371492704824|260318.54916792738| 32.2042079685746| null|    null|
# | stddev|257.3538420152301|0.48659245426485753|0.8360712409770491|                null|  null|14.526497332334035|1.1027434322934315| 0.8060572211299488|471609.26868834975|49.69342859718089| null|    null|
# |    min|                1|                  0|                 1|"Andersson, Mr. A...|female|              0.42|                 0|                  0|            110152|              0.0|  A10|       C|
# |    max|              891|                  1|                 3|van Melkebeke, Mr...|  male|              80.0|                 8|                  6|         WE/P 5735|         512.3292|    T|       S|
# +-------+-----------------+-------------------+------------------+--------------------+------+------------------+------------------+-------------------+------------------+-----------------+-----+--------+

# %% [markdown]
# ## Практика 2. Удалим малоинформативные колонки
# Колонка с идентификатором пассажира (PassengerId), именем (Name), информация о родственниках (SibSp, Parch),номер билета (Ticket) и информация о каюте (Cabin) кажутся малоинформативными для первой версии модели. Удалим их при помощи команды select

# %%
df = df.select('Survived', 'Pclass', 'Sex', 'Age','Fare','Embarked')
df.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f08e58006a08> in <module>
# ----> 1 df = df.select('Survived', 'Pclass', 'Sex', 'Age','Fare','Embarked')
#       2 df.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Практика 3. Колонки Age и Embarked содержат пропущенные значения.
# Пропуски надо заполнить
# Для поля Age предлагается заполнить пропуски средним значением возвраста (информация по нему есть в describe)
# Для поля Embarked самым частым вариантом (надо сгруппировать данные и посчитать какой порт самый частый)
# Затем при помощи команды:
#
# ```
# df_filtered = df_filtered.na.fill({'Age': XX, 'Embarked': YY})
# ```
#
# устранить пропуски

# %% [markdown]
# ## Работа со строковыми колонками
# У нас осталось 2 колонки, содержащих строковые данные:
# * Sex
# * Embarked
# Первую мы преобразуем в 0 и 1
# Вторую закодируем по принципу OneHot
#
# Для этого нам помогут специальные классы в PySpark:
# * StringIndexer - https://spark.apache.org/docs/latest/ml-features#stringindexer
# * OneHotEncoderEstimator - https://spark.apache.org/docs/latest/ml-features#onehotencoder

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder

# %%
indexer = StringIndexer(inputCol='Sex', outputCol='SexInd')
indexerTrained = indexer.fit(df_filtered)
df_features = indexerTrained.transform(df_filtered)

# %%
indexerTrained.labels
# Out:
# ['male', 'female']

# %%
df_features.show()
# Out:
# +-----------+--------+------+------+----+-------+--------+------+
# |PassengerId|Survived|Pclass|   Sex| Age|   Fare|Embarked|SexInd|
# +-----------+--------+------+------+----+-------+--------+------+
# |          1|       0|     3|  male|22.0|   7.25|       S|   0.0|
# |          2|       1|     1|female|38.0|71.2833|       C|   1.0|
# |          3|       1|     3|female|26.0|  7.925|       S|   1.0|
# |          4|       1|     1|female|35.0|   53.1|       S|   1.0|
# |          5|       0|     3|  male|35.0|   8.05|       S|   0.0|
# |          6|       0|     3|  male|29.7| 8.4583|       Q|   0.0|
# |          7|       0|     1|  male|54.0|51.8625|       S|   0.0|
# |          8|       0|     3|  male| 2.0| 21.075|       S|   0.0|
# |          9|       1|     3|female|27.0|11.1333|       S|   1.0|
# |         10|       1|     2|female|14.0|30.0708|       C|   1.0|
# |         11|       1|     3|female| 4.0|   16.7|       S|   1.0|
# |         12|       1|     1|female|58.0|  26.55|       S|   1.0|
# |         13|       0|     3|  male|20.0|   8.05|       S|   0.0|
# |         14|       0|     3|  male|39.0| 31.275|       S|   0.0|
# |         15|       0|     3|female|14.0| 7.8542|       S|   1.0|
# |         16|       1|     2|female|55.0|   16.0|       S|   1.0|
# |         17|       0|     3|  male| 2.0| 29.125|       Q|   0.0|
# |         18|       1|     2|  male|29.7|   13.0|       S|   0.0|
# |         19|       0|     3|female|31.0|   18.0|       S|   1.0|
# |         20|       1|     3|female|29.7|  7.225|       C|   1.0|
# +-----------+--------+------+------+----+-------+--------+------+
# only showing top 20 rows

# %% [markdown]
# ## Практика 4.
# Преобразуйте колонку Embarked.
# Сначала надо при помощи StringIndexer преобразовать колонку Embarked в колонку EmbarkedInd с цифровыми кодами
# Затем сделать OneHotEncoder, который колонку EmbarkedInd превратит в колонку EmbarkedOhe. Обратите внимание у OneHotEncoder'а нет метода fit. Его можно сразу применять методом transform

# %% [markdown]
# ## Практика 5. Дальше нужно собрать все признаки в единый вектор для работы машинного обучения.
# Для этого используется VectorAssembler
# https://spark.apache.org/docs/latest/ml-features.html#vectorassembler

# %% [markdown]
# ## Повторимость
# Часто нам нужно все указанные шаги по подготовке признаков делать не один раз, а несколько - для предсказания каждого нового значения.
# Тогда их логично объединить в Pipeline преобразования и применять как единую операцию
#
# https://spark.apache.org/docs/latest/ml-pipeline.html

# %%
from pyspark.ml import Pipeline

# %%
pipeline = Pipeline(stages = 
[
  StringIndexer(inputCol='Sex', outputCol='SexInd'),
  StringIndexer(inputCol='Embarked', outputCol='EmbarkedInd'),
  OneHotEncoder(inputCol='EmbarkedInd', outputCol = 'EmbarkedOhe'),
  VectorAssembler(inputCols=['Pclass', 'Age', 'Fare', 'SexInd', 'EmbarkedOhe'], outputCol='Features')
]
)

# %%
pipelineTrained = pipeline.fit(df_filtered)

# %%
pipelineTrained.transform(df_filtered).show()
# Out:
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+
# |PassengerId|Survived|Pclass|   Sex| Age|   Fare|Embarked|SexInd|EmbarkedInd|  EmbarkedOhe|            Features|
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+
# |          1|       0|     3|  male|22.0|   7.25|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,22.0,7.25,0....|
# |          2|       1|     1|female|38.0|71.2833|       C|   1.0|        1.0|(2,[1],[1.0])|[1.0,38.0,71.2833...|
# |          3|       1|     3|female|26.0|  7.925|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,26.0,7.925,1...|
# |          4|       1|     1|female|35.0|   53.1|       S|   1.0|        0.0|(2,[0],[1.0])|[1.0,35.0,53.1,1....|
# |          5|       0|     3|  male|35.0|   8.05|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,35.0,8.05,0....|
# |          6|       0|     3|  male|29.7| 8.4583|       Q|   0.0|        2.0|    (2,[],[])|[3.0,29.7,8.4583,...|
# |          7|       0|     1|  male|54.0|51.8625|       S|   0.0|        0.0|(2,[0],[1.0])|[1.0,54.0,51.8625...|
# |          8|       0|     3|  male| 2.0| 21.075|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,2.0,21.075,0...|
# |          9|       1|     3|female|27.0|11.1333|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,27.0,11.1333...|
# |         10|       1|     2|female|14.0|30.0708|       C|   1.0|        1.0|(2,[1],[1.0])|[2.0,14.0,30.0708...|
# |         11|       1|     3|female| 4.0|   16.7|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,4.0,16.7,1.0...|
# |         12|       1|     1|female|58.0|  26.55|       S|   1.0|        0.0|(2,[0],[1.0])|[1.0,58.0,26.55,1...|
# |         13|       0|     3|  male|20.0|   8.05|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,20.0,8.05,0....|
# |         14|       0|     3|  male|39.0| 31.275|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,39.0,31.275,...|
# |         15|       0|     3|female|14.0| 7.8542|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,14.0,7.8542,...|
# |         16|       1|     2|female|55.0|   16.0|       S|   1.0|        0.0|(2,[0],[1.0])|[2.0,55.0,16.0,1....|
# |         17|       0|     3|  male| 2.0| 29.125|       Q|   0.0|        2.0|    (2,[],[])|[3.0,2.0,29.125,0...|
# |         18|       1|     2|  male|29.7|   13.0|       S|   0.0|        0.0|(2,[0],[1.0])|[2.0,29.7,13.0,0....|
# |         19|       0|     3|female|31.0|   18.0|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,31.0,18.0,1....|
# |         20|       1|     3|female|29.7|  7.225|       C|   1.0|        1.0|(2,[1],[1.0])|[3.0,29.7,7.225,1...|
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+
# only showing top 20 rows

# %%
df_features = pipelineTrained.transform(df_filtered)

# %% [markdown]
# ## Разобьем данные на данные для обучения и проверки

# %%
train, test = df_features.randomSplit([0.8, 0.2], seed=12345)

# %%
train.show()
# Out:
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+
# |PassengerId|Survived|Pclass|   Sex| Age|   Fare|Embarked|SexInd|EmbarkedInd|  EmbarkedOhe|            Features|
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+
# |          1|       0|     3|  male|22.0|   7.25|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,22.0,7.25,0....|
# |          2|       1|     1|female|38.0|71.2833|       C|   1.0|        1.0|(2,[1],[1.0])|[1.0,38.0,71.2833...|
# |          3|       1|     3|female|26.0|  7.925|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,26.0,7.925,1...|
# |          4|       1|     1|female|35.0|   53.1|       S|   1.0|        0.0|(2,[0],[1.0])|[1.0,35.0,53.1,1....|
# |          6|       0|     3|  male|29.7| 8.4583|       Q|   0.0|        2.0|    (2,[],[])|[3.0,29.7,8.4583,...|
# |          7|       0|     1|  male|54.0|51.8625|       S|   0.0|        0.0|(2,[0],[1.0])|[1.0,54.0,51.8625...|
# |         10|       1|     2|female|14.0|30.0708|       C|   1.0|        1.0|(2,[1],[1.0])|[2.0,14.0,30.0708...|
# |         11|       1|     3|female| 4.0|   16.7|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,4.0,16.7,1.0...|
# |         12|       1|     1|female|58.0|  26.55|       S|   1.0|        0.0|(2,[0],[1.0])|[1.0,58.0,26.55,1...|
# |         13|       0|     3|  male|20.0|   8.05|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,20.0,8.05,0....|
# |         14|       0|     3|  male|39.0| 31.275|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,39.0,31.275,...|
# |         15|       0|     3|female|14.0| 7.8542|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,14.0,7.8542,...|
# |         19|       0|     3|female|31.0|   18.0|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,31.0,18.0,1....|
# |         20|       1|     3|female|29.7|  7.225|       C|   1.0|        1.0|(2,[1],[1.0])|[3.0,29.7,7.225,1...|
# |         21|       0|     2|  male|35.0|   26.0|       S|   0.0|        0.0|(2,[0],[1.0])|[2.0,35.0,26.0,0....|
# |         22|       1|     2|  male|34.0|   13.0|       S|   0.0|        0.0|(2,[0],[1.0])|[2.0,34.0,13.0,0....|
# |         23|       1|     3|female|15.0| 8.0292|       Q|   1.0|        2.0|    (2,[],[])|[3.0,15.0,8.0292,...|
# |         24|       1|     1|  male|28.0|   35.5|       S|   0.0|        0.0|(2,[0],[1.0])|[1.0,28.0,35.5,0....|
# |         25|       0|     3|female| 8.0| 21.075|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,8.0,21.075,1...|
# |         26|       1|     3|female|38.0|31.3875|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,38.0,31.3875...|
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Создадим и обучим модель логистической регрессии

# %%
from pyspark.ml.classification import LogisticRegression

# %%
lr = LogisticRegression(featuresCol = 'Features', labelCol = 'Survived')
lrModel = lr.fit(train)

# %%
train_res = lrModel.transform(train)
test_res = lrModel.transform(test)

# %%
train_res.show()
# Out:
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+--------------------+--------------------+----------+
# |PassengerId|Survived|Pclass|   Sex| Age|   Fare|Embarked|SexInd|EmbarkedInd|  EmbarkedOhe|            Features|       rawPrediction|         probability|prediction|
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+--------------------+--------------------+----------+
# |          1|       0|     3|  male|22.0|   7.25|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,22.0,7.25,0....|[2.28851114991778...|[0.90792105716095...|       0.0|
# |          2|       1|     1|female|38.0|71.2833|       C|   1.0|        1.0|(2,[1],[1.0])|[1.0,38.0,71.2833...|[-2.7781883655360...|[0.05851427934696...|       1.0|
# |          3|       1|     3|female|26.0|  7.925|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,26.0,7.925,1...|[-0.2278559064623...|[0.44328120664877...|       1.0|
# |          4|       1|     1|female|35.0|   53.1|       S|   1.0|        0.0|(2,[0],[1.0])|[1.0,35.0,53.1,1....|[-2.3011033373266...|[0.09103162430914...|       1.0|
# |          6|       0|     3|  male|29.7| 8.4583|       Q|   0.0|        2.0|    (2,[],[])|[3.0,29.7,8.4583,...|[1.80901484451616...|[0.85924276715902...|       0.0|
# |          7|       0|     1|  male|54.0|51.8625|       S|   0.0|        0.0|(2,[0],[1.0])|[1.0,54.0,51.8625...|[0.98376257620647...|[0.72785415540926...|       0.0|
# |         10|       1|     2|female|14.0|30.0708|       C|   1.0|        1.0|(2,[1],[1.0])|[2.0,14.0,30.0708...|[-2.4179487911329...|[0.08181421148198...|       1.0|
# |         11|       1|     3|female| 4.0|   16.7|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,4.0,16.7,1.0...|[-0.9522344640157...|[0.27843567531198...|       1.0|
# |         12|       1|     1|female|58.0|  26.55|       S|   1.0|        0.0|(2,[0],[1.0])|[1.0,58.0,26.55,1...|[-1.5663859028402...|[0.17273222036830...|       1.0|
# |         13|       0|     3|  male|20.0|   8.05|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,20.0,8.05,0....|[2.22266150811849...|[0.90226614408165...|       0.0|
# |         14|       0|     3|  male|39.0| 31.275|       S|   0.0|        0.0|(2,[0],[1.0])|[3.0,39.0,31.275,...|[2.88830284465179...|[0.94726516641129...|       0.0|
# |         15|       0|     3|female|14.0| 7.8542|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,14.0,7.8542,...|[-0.6292853610493...|[0.34767259767317...|       1.0|
# |         19|       0|     3|female|31.0|   18.0|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,31.0,18.0,1....|[-0.0475353833513...|[0.48811839139734...|       1.0|
# |         20|       1|     3|female|29.7|  7.225|       C|   1.0|        1.0|(2,[1],[1.0])|[3.0,29.7,7.225,1...|[-0.7060761840071...|[0.33046643907266...|       1.0|
# |         21|       0|     2|  male|35.0|   26.0|       S|   0.0|        0.0|(2,[0],[1.0])|[2.0,35.0,26.0,0....|[1.53117970131334...|[0.82217885303143...|       0.0|
# |         22|       1|     2|  male|34.0|   13.0|       S|   0.0|        0.0|(2,[0],[1.0])|[2.0,34.0,13.0,0....|[1.48083608046249...|[0.81469883250828...|       0.0|
# |         23|       1|     3|female|15.0| 8.0292|       Q|   1.0|        2.0|    (2,[],[])|[3.0,15.0,8.0292,...|[-1.3342049239307...|[0.20846467209891...|       1.0|
# |         24|       1|     1|  male|28.0|   35.5|       S|   0.0|        0.0|(2,[0],[1.0])|[1.0,28.0,35.5,0....|[0.09292837955486...|[0.52321539056191...|       0.0|
# |         25|       0|     3|female| 8.0| 21.075|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,8.0,21.075,1...|[-0.8127682155135...|[0.30730091966554...|       1.0|
# |         26|       1|     3|female|38.0|31.3875|       S|   1.0|        0.0|(2,[0],[1.0])|[3.0,38.0,31.3875...|[0.20398066326032...|[0.55081908072569...|       0.0|
# +-----------+--------+------+------+----+-------+--------+------+-----------+-------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %% [markdown]
# ## Оценим качество
# Для оценки качества предсказания в spark реализованно несколько классов
# Если мы решаем задачу бинарной классификации (то есть классов - 2), то нам подойдет BinaryCLassificationEvaluator, а если классов больше 2-х, то MulticlassClassificationEvaluator

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# %%
ev = BinaryClassificationEvaluator(labelCol='Survived')

# %%
ev.evaluate(train_res)
# Out:
# 0.8603479853479851

# %%
ev.evaluate(test_res)
# Out:
# 0.8184473654645547

# %% [markdown]
# ## Практика 6. Обучите модель дерева решений и оцените его качество
# https://spark.apache.org/docs/latest/ml-classification-regression.html#decision-tree-classifier

# %% [markdown]
# ## Домашнее задание
# Обучите модель классификации для цветков Iris'а
#
# Примерная последовательность действий:
# 1. Взять данные - https://drive.google.com/file/d/18ksAxTxBkp15LToEg46BHhwp3sPIoeUU/view?usp=sharing
# 2. Загрузить в pyspark
# 3. При помощи VectorAssembler преобразовать все колонки с признаками в одну (использовать PipeLine - опционально)
# 4. Разбить данные на train и test
# 5. Создать модель логистической регресии или модель дерева и обучить ее
# 6. Воспользоваться MulticlassClassificationEvaluator для оценки качества на train и test множестве
