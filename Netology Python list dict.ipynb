# %% [markdown]
# # Практика 2
# Теория: Типы данных и циклы. Часть 2
#
# Булыгин Олег:
# * [LinkedIn](linkedin.com/in/obulygin)
# * [Мой канал в ТГ по Python](https://t.me/pythontalk_ru)

# %% [markdown]
# 1.   Пару полезностей
# 2.   list comprehension
# 3.   Словари
# 4.   dict comprehension
# 5.   Множества

# %% [markdown]
# Как исключить дубли из последовательности элементов без множеств

# %%
some_list = [1, 21, 3, 4, 45, 56456, 46, 5, 5, 5, 6]
res = []

for el in some_list:
    if el not in res:
      res.append(el)

res
# Out:
# [1, 21, 3, 4, 45, 56456, 46, 5, 6]

# %%
for number in range(1, 20):
    print(number)

# %%
list(range(1, 10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# Напишем программу для проверки логина и пароля
#
# 1) логин и пароль пользователя хранится в переменной
#
# 2) будем давать пользователю k попыток на ввод логина и пароля
#
# 3) если после трех попыток вверного ввода не было, то заблокируем вход - вывести на экран сообщение "Вход заблокирован"
#
# 4) если пароль и логин были введены верно, то вывести на экран сообщение "Добро пожаловать!"

# %%
login_correct = 'admin'
pswd_correct = 'admin'
k = 3
for i in range(0, k):
    login = input('Ввелите логин')
    pswd = input('Введите пароль')
    if login != login_correct or pswd != pswd_correct:
        k -= 1
        print(f'Осталось {k} попытки')
    else:
        print('Добро пожаловать!')
        break
else:
    print('Вход заблокирован')

# %%
{'user1': 'sdegsg', 'user_2': 'sdgsdg'}

# %% [markdown]
# Как можно "разгладить" список. Задачка на мышление
# Должен получится результат:
#
# `['Екатеринбург', 'Москва', 'Санкт-Петербург', 'Норильск', 'Пермь', 'Астрахань']`

# %%
my_list = [['Екатеринбург', 'Москва'], ['Санкт-Петербург', 'Норильск'], ['Пермь', 'Астрахань']]

# %%
res = []

for el in my_list:
    for i in el:
        res.append(i)
res
# Out:
# ['Екатеринбург', 'Москва', 'Санкт-Петербург', 'Норильск', 'Пермь', 'Астрахань']

# %%
res = []

for el in my_list:
    res += el
res
# Out:
# ['Екатеринбург', 'Москва', 'Санкт-Петербург', 'Норильск', 'Пермь', 'Астрахань']

# %%
sum([34, 43345, 346346])
# Out:
# 389725

# %%
sum(my_list, [])
# Out:
# ['Екатеринбург', 'Москва', 'Санкт-Петербург', 'Норильск', 'Пермь', 'Астрахань']

# %%
# ?sum

# %% [markdown]
# Решим задачу с диагональной матрицей в одну строку

# %%
data = [
    [13, 25, 23, 34],
    [45, 32, 44, 47],
    [12, 33, 23, 95],
    [13, 53, 34, 35]
]

# %%
# в прошлый раз было вот такое решение
result = 0
index = 0
for row in data:
    result += row[index]
    index += 1
print(result)
# Out:
# 103

# %%
list(enumerate(data))
# Out:
# [(0, [13, 25, 23, 34]),
#  (1, [45, 32, 44, 47]),
#  (2, [12, 33, 23, 95]),
#  (3, [13, 53, 34, 35])]

# %%
sum([row[index] for index, row in enumerate(data)])
# Out:
# 103

# %%
sum([row[2] for row in data])
# Out:
# 124

# %%
sum([row[2] for row in data])
# Out:
# 124

# %% [markdown]
# Выведем информацию о странах и столициах в виде:
#  `The capital of ... is ...`

# %%
europe = {'spain': {'capital': 'madrid'},
           'france': {'capital': 'paris'},
           'germany': {'capital': 'berlin'},
           'norway': {'capital': 'oslo'}}

# %%
for country, info in europe.items():
    # print(country)
    # print(info)
    print(f'The capital of {country.title()} is {info["capital"].title()}')
# Out:
# The capital of Spain is Madrid
# The capital of France is Paris
# The capital of Germany is Berlin
# The capital of Norway is Oslo

# %%
my_str = 'hello  World'

print(my_str.title())
print(my_str.capitalize())
# Out:
# Hello  World
# Hello  world

# %%
# for el in some_list:
#     res = {}

# %% [markdown]
# Посчитаем средний возраст в коллективе

# %%
people = {1: {'name': 'Oleg', 'age': '29', 'sex': 'Male'},
          2: {'name': 'Kate', 'age': '21', 'sex': 'Female'},
          3: {'name': 'Liza', 'age': '24', 'sex': 'Female'},
          4: {'name': 'Pavel', 'age': '36', 'sex': 'Male'}}

# %%
age = 0

for person in people.values():
    age += int(person['age'])
print(age / len(people))
# Out:
# 27.5

# %%
sum([int(person["age"]) for person in people.values()]) / len(people)
# Out:
# 27.5

# %% [markdown]
# Удалим из словаря все пустые элементы (со значением None)

# %%
my_dict = {
    'id1': 123456, 
    'id2': 654321, 
    'id3': None,
    'id4': 777777
}

# %%
res = {}

for key, value in my_dict.items():
    if value is not None:
        res[key] = value
print(res)
# Out:
# {'id1': 123456, 'id2': 654321, 'id4': 777777}

# %%
{key:value for key, value in my_dict.items() if value is not None}
# Out:
# {'id1': 123456, 'id2': 654321, 'id4': 777777}

# %% [markdown]
# Посчитаем сколько раз каждое слово встречалось в тексте и выведем информацию в виде:
# `"слово": "количество вхождений" `

# %%
some_oxy_text = '''
Весь мой рэп, если коротко, про то, что
Уж который год который город под подошвой
В гору, когда прет. Потом под гору, когда тошно
Я не то, что Гулливер, но все же город под подошвой
Город под подошвой, город под подошвой
Светофоры, госпошлины, сборы и таможни
Я не знаю, вброд или на дно эта дорожка
Ты живешь под каблуком, у меня - город под подошвой
'''

# %%
res = {}

splitted_text = some_oxy_text.lower().replace('-', '').split()

for word in splitted_text:
    word = word.strip(',.!?:;')
    res.setdefault(word, 0)
    res[word] += 1
for word, count in res.items():
    print(f'{word}: {count}')
# Out:
# весь: 1
# мой: 1
# рэп: 1
# если: 1
# коротко: 1
# про: 1
# то: 2
# что: 2
# уж: 1
# который: 2
# год: 1
# город: 5
# под: 7
# подошвой: 5
# в: 1
# гору: 2
# когда: 2
# прет: 1
# потом: 1
# тошно: 1
# я: 2
# не: 2
# гулливер: 1
# но: 1
# все: 1
# же: 1
# светофоры: 1
# госпошлины: 1
# сборы: 1
# и: 1
# таможни: 1
# знаю: 1
# вброд: 1
# или: 1
# на: 1
# дно: 1
# эта: 1
# дорожка: 1
# ты: 1
# живешь: 1
# каблуком: 1
# у: 1
# меня: 1

# %%
text_cleaned = [word.strip(',.!?') for word in some_oxy_text.lower().replace('-', '').split()]
for word in set(text_cleaned): # перебор только уникальных слов
    print(f'{word}: {text_cleaned.count(word)}')
# Out:
# в: 1
# я: 2
# на: 1
# прет: 1
# но: 1
# сборы: 1
# не: 2
# про: 1
# дно: 1
# каблуком: 1
# рэп: 1
# тошно: 1
# вброд: 1
# и: 1
# то: 2
# ты: 1
# весь: 1
# эта: 1
# уж: 1
# который: 2
# таможни: 1
# если: 1
# коротко: 1
# госпошлины: 1
# гору: 2
# знаю: 1
# под: 7
# меня: 1
# дорожка: 1
# у: 1
# год: 1
# или: 1
# когда: 2
# же: 1
# что: 2
# светофоры: 1
# город: 5
# все: 1
# живешь: 1
# подошвой: 5
# гулливер: 1
# потом: 1
# мой: 1

# %%
my_dict.get('id436')

# %%
# ?dict.get

# %%
my_dict['id56']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-d6f300113243> in <module>
# ----> 1 my_dict['id56']
#
# KeyError: 'id56'

# %% [markdown]
# Проблема изменение длины объекта во время итерации по нему

# %% [markdown]
# Дан список с визитами по городам и странам.
# Напишем код, который возвращает отфильтрованный список `geo_logs`, содержащий только визиты из России.

# %%
geo_logs = [
    {'visit1': ['Москва', 'Россия']},
    {'visit2': ['Дели', 'Индия']},
    {'visit3': ['Владимир', 'Россия']},
    {'visit4': ['Лиссабон', 'Португалия']},
    {'visit5': ['Париж', 'Франция']},
    {'visit7': ['Тула', 'Россия']},
    {'visit9': ['Курск', 'Россия']},
    {'visit10': ['Архангельск', 'Россия']}
]

# %%
for log in geo_logs:
    for el in log.values():
        if 'Россия' not in el:
            geo_logs.remove(log)
geo_logs
# Out:
# [{'visit1': ['Москва', 'Россия']},
#  {'visit3': ['Владимир', 'Россия']},
#  {'visit5': ['Париж', 'Франция']},
#  {'visit7': ['Тула', 'Россия']},
#  {'visit9': ['Курск', 'Россия']},
#  {'visit10': ['Архангельск', 'Россия']}]

# %%
res = []

for log in geo_logs:
    print(list(log.values())[0])

# res
# Out:
# ['Москва', 'Россия']
# ['Дели', 'Индия']
# ['Владимир', 'Россия']
# ['Лиссабон', 'Португалия']
# ['Париж', 'Франция']
# ['Тула', 'Россия']
# ['Курск', 'Россия']
# ['Архангельск', 'Россия']

# %%
res = []

for log in geo_logs:
      if 'Россия' in list(log.values())[0]:
          res.append(log)

res
# Out:
# [{'visit1': ['Москва', 'Россия']},
#  {'visit3': ['Владимир', 'Россия']},
#  {'visit7': ['Тула', 'Россия']},
#  {'visit9': ['Курск', 'Россия']},
#  {'visit10': ['Архангельск', 'Россия']}]

# %%
geo_logs = [
    {'visit1': ['Москва', 'Россия']},
    {'visit2': ['Дели', 'Индия']},
    {'visit3': ['Владимир', 'Россия']},
    {'visit4': ['Лиссабон', 'Португалия']},
    {'visit5': ['Париж', 'Франция']},
    {'visit7': ['Тула', 'Россия']},
    {'visit9': ['Курск', 'Россия']},
    {'visit10': ['Архангельск', 'Россия']}
]

geo_logs_copy = geo_logs.copy()

for log in geo_logs_copy:
      if 'Россия' not in list(log.values())[0]:
          geo_logs.remove(log)

geo_logs
# Out:
# [{'visit1': ['Москва', 'Россия']},
#  {'visit3': ['Владимир', 'Россия']},
#  {'visit7': ['Тула', 'Россия']},
#  {'visit9': ['Курск', 'Россия']},
#  {'visit10': ['Архангельск', 'Россия']}]

# %% [markdown]
# Посмотрим, как знание сложных структур может помочь в задачах, приближенных к реальным

# %% [markdown]
# Поищем сообщества в социальной сети

# %%
params = {
    'q': 'python',
    'access_token': token,
    'v':'5.131',
    'count': 300
}
req = requests.get('https://api.vk.com/method/groups.search', params).json()

# %%
print(req)

# %%
pprint(req)

# %%
target_groups = req['response']['items']
target_groups

# %%
# преобразуем список всех id в строку (в таком виде принимает данные параметр fields)
target_group_ids = ','.join([str(group['id']) for group in target_groups])
print(target_group_ids)
# Out:
# 152111071,52104930,177962775,149218373,172288069,194576836,42565717,45964980,174948538,96469126,3183750,206098555,41943023,38080744,193480984,174586137,64524646,138576816,8056712,13765414,148374908,210778798,26227,142410745,179798747,209530570,11899736,215764152,195434119,210592365,85364050,163790384,125409792,185123800,196149658,69235007,172171969,185939737,205121478,191744477,212013249,161474904,189204591,41069912,2579743,178774705,181513077,107124511,204178374,156528136,24847633,97789166,69108280,51370544,216228113,215673094,215226384,107257659,198034337,12299085,215597448,63204808,1879,211980580,183738581,158994985,186684823,215725952,216109660,140154120,211044581,82087650,163875533,147351723,206321561,21036475,85529744,89085936,174522765,99411738,55702386,200550131,203955768,85879138,193555507,197837687,109938878,162585822,213302573,212765563,180288349,204886867,149009466,35155841,16790049,189747450,214777622,37392018,1540917,140886058,7929793,96545411,195194058,203595919,126628102,80460037,205988839,183184920,96761545,196848333,203721374,183439669,136323479,190825223,26332,212510051,185716562,208934704,213893107,125626212,164946472,152376762,192003943,173695051,507513,43690334,79303962,44437312,193182824,98833453,156325271,94809790,177545838,186562266,52291665,209077931,92411699,181671682,206641201,27975363,209559357,165919087,62844165,196767,197554506,73929027,178733625,213594387,200274205,21403140,150837225,196955683,132490011,75976428,162386559,117030524,53216579,204828666,124718901,44698473,205923789,207899503,212212944,103517508,142919317,85963264,135015138,77012164,195677045,192400515,117210834,102016896,141757687,204658300,163948932,414329,75836319,177184688,197569538,163284622,190885232,153764049,74011926,2512258,210297172,208747394,96806600,205591291,186894419,104403202,181442365,46069336,134675739,63390879,213921955,198014326,41070201,67578212,198405911,97159757,149694058,205690224,165150893,28184653,197381624,168459177,96572266,55578525,51355222,106798928,139463015,161179205,194689015,73284245,111958866,76184733,135173221,196439569,210590348,173104996,5519824,168419860,125911892,11499223,72768613,61224212,154462513,34256705,24614902,138093012,93497035,213812788,213686980,20659396,204728634,192660227,71439824,116615094,199844948,72486321,125748921,195403091,188670953,38028675,67238154,169081344,9673377,68237396,204650054,181634513,149701538,212187812,66818424,203391541,174192876,183785667,187488772,98444608,196217008,193009291,198755832,152466989,105205241,154241977,103770831,64973098,72413171,216233959,74383639,42699073,103975571,198876517,133190725,49141997,82481391,213275638,174978164,163242932,101849308,181854671,120569845,215988719,210910093,194243820,208755554,134202833,123256340,200545069,78137512,185859318,112775373,186053875,73834539,193284770,171101991,192300300,181733460,132431530,70751932,4137091

# %%
params = {
    'access_token': token,
    'v':'5.131',
    'group_ids': target_group_ids,
    'fields':  'members_count,activity,description'

}
req = requests.get('https://api.vk.com/method/groups.getById', params)

pprint(req.json())

# %% [markdown]
# Посчитаем количество лайков в сообщениях

# %%
params = {
    'access_token': token,
    'v':'5.131',
    'q': 'Нетология',
    'start_from': '',
    'count': 200,
    'extended': 1
}   
res = []
while True:
    result = requests.get('https://api.vk.com/method/newsfeed.search', params)
    time.sleep(0.33)
    res += result.json()['response']['items']
    if 'next_from' in result.json()['response'].keys():
        params['start_from'] = result.json()['response']['next_from']
    else:
        break

# %%
print(type(res))
print(len(res))
# Out:
# <class 'list'>
# 938

# %%
pprint(res[0])

# %%
likes_count = 0
reposts_count = 0
for post in res:
    likes_count += post['likes']['count']
    reposts_count += post['reposts']['count']

print(likes_count)
print(reposts_count)
# Out:
# 8006
# 2440

# %%
[{}, [], {}]

# %%
# .copy()
# .deepcopy()

# %%
people = {1: {'name': 'Oleg', 'age': '29', 'sex': 'Male'},
          2: {'name': 'Kate', 'age': '21', 'sex': 'Female'},
          3: {'name': 'Liza', 'age': '24', 'sex': 'Female'},
          4: {'name': 'Pavel', 'age': '36', 'sex': 'Male'}}

people_2 = {5: {'name': 'Oleg', 'age': '29', 'sex': 'Male'},
          6: {'name': 'Kate', 'age': '21', 'sex': 'Female'},
          7: {'name': 'Liza', 'age': '24', 'sex': 'Female'},
          8: {'name': 'Pavel', 'age': '36', 'sex': 'Male'}}

res = {**people, **people_2}
max_key = max(people)
# for people_2 range(max_key, len())
res
# Out:
# {1: {'name': 'Oleg', 'age': '29', 'sex': 'Male'},
#  2: {'name': 'Kate', 'age': '21', 'sex': 'Female'},
#  3: {'name': 'Liza', 'age': '24', 'sex': 'Female'},
#  4: {'name': 'Pavel', 'age': '36', 'sex': 'Male'},
#  5: {'name': 'Oleg', 'age': '29', 'sex': 'Male'},
#  6: {'name': 'Kate', 'age': '21', 'sex': 'Female'},
#  7: {'name': 'Liza', 'age': '24', 'sex': 'Female'},
#  8: {'name': 'Pavel', 'age': '36', 'sex': 'Male'}}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3dae89239c97> in <module>
# ----> 1 people + people_2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
# ?dict.update

# %%
cook_book = {
  'салат': [
     {'ingridient_name': 'сыр', 'quantity': 50, 'measure': 'гр'},
     {'ingridient_name': 'томаты', 'quantity': 2, 'measure': 'шт'},
     {'ingridient_name': 'огурцы', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'маслины', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'оливковое масло', 'quantity': 20, 'measure': 'мл'},
     {'ingridient_name': 'салат', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'перец', 'quantity': 20, 'measure': 'гр'}
    ],
  'пицца': [
     {'ingridient_name': 'сыр', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'колбаса', 'quantity': 30, 'measure': 'гр'},
     {'ingridient_name': 'бекон', 'quantity': 30, 'measure': 'гр'},
     {'ingridient_name': 'оливки', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'томаты', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'тесто', 'quantity': 100, 'measure': 'гр'},   
    ],
  'лимонад': [
     {'ingridient_name': 'лимон', 'quantity': 1, 'measure': 'шт'},
     {'ingridient_name': 'вода', 'quantity': 200, 'measure': 'мл'},
     {'ingridient_name': 'сахар', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'лайм', 'quantity': 20, 'measure': 'гр'},    
    ]
}

person = 5

shop_dict = {}

for dish in cook_book.values():
    for ingr in dish:
        # print(ingr)
        key = (ingr['ingridient_name'], ingr['measure'])
        shop_dict.setdefault(key, 0)
        shop_dict[key] += ingr['quantity'] * person


shop_dict
# Out:
# {('сыр', 'гр'): 350,
#  ('томаты', 'шт'): 10,
#  ('огурцы', 'гр'): 100,
#  ('маслины', 'гр'): 50,
#  ('оливковое масло', 'мл'): 100,
#  ('салат', 'гр'): 50,
#  ('перец', 'гр'): 100,
#  ('колбаса', 'гр'): 150,
#  ('бекон', 'гр'): 150,
#  ('оливки', 'гр'): 50,
#  ('томаты', 'гр'): 100,
#  ('тесто', 'гр'): 500,
#  ('лимон', 'шт'): 5,
#  ('вода', 'мл'): 1000,
#  ('сахар', 'гр'): 50,
#  ('лайм', 'гр'): 100}
