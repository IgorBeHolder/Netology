# %% [markdown]
# ## `Comprehensive Pandas overview`
# best to run in Colab

# %%
# %pip install google.colab

# %%
# !pip install --upgrade pip
# %pip install --upgrade pip
# %conda install --upgrade pip
# %pip upgrade --all
#or update
# %conda upgrade tornado
# %conda install prompt_toolkit.formatted_text -U --force-reinstall

# %%
# %pip install prompt_toolkit.formatted_text
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
pd.__version__

# some code masked as it runs only in Colab
# Out:
# '1.5.3'

# %%
# import google 
# from google.colab import output

# %%
# #@title Helper Functions

# def pandas_to_html(obj, ordering=False):
#   import pandas as pd
#   if type(obj) == pd.core.series.Series:
#     if obj.name != None:
#       obj = pd.DataFrame(obj)#, columns=[' '])
#     else:
#       obj = pd.DataFrame(obj, columns=[' '])
  
#   class_name = 'pandas_table'
#   if obj.shape[0] > 10:
#     class_name += '_long'
#   else:
#     class_name += '_short'

#   if ordering:
#     class_name += '_ordered'
#   else:
#     class_name += '_unordered'


#   main_str = '''
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
#   <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.10.21/css/jquery.dataTables.css">
#   <script type="text/javascript" charset="utf8" src="https://cdn.datatables.net/1.10.21/js/jquery.dataTables.js"></script>
#   ''' + obj.to_html(classes=[class_name, 'cell-border']) + '''
#   <script>
#   $(document).ready( function () {
#       $('.pandas_table_long_ordered').DataTable({"autoWidth": false});
#       $('.pandas_table_long_ordered').removeClass("pandas_table_long_ordered");
#       $('.pandas_table_short_ordered').DataTable({"autoWidth": false, "paging":false, "searching":false, "info":false});
#       $('.pandas_table_short_ordered').removeClass("pandas_table_short_ordered");

#       $('.pandas_table_long_unordered').DataTable({"autoWidth": false, "ordering":false, "paging":true});
#       $('.pandas_table_long_unordered').removeClass("pandas_table_long_unordered");
#       $('.pandas_table_short_unordered').DataTable({"autoWidth": false, "paging":false, "searching":false, "info":false, "ordering":false});
#       $('.pandas_table_short_unordered').removeClass("pandas_table_short_unordered");
#   } );
#   </script>
#   '''
#   return main_str

# def display_pandas(obj, ordering=False):
#   import IPython
#   from google.colab import output
#   display(IPython.display.HTML(pandas_to_html(obj, ordering)))

# str_style_bigtbl = '''
# <style>
# .bigtable {
#   border-collapse: collapse;
# }

# .bigtd {
#   border: 3px solid #d4d4d3ff;
#   min-width:50%;
#   min-width:50%;
#   height: 30px;
#   position: relative; 
#   text-align:center; 
#   color: #474747;
#   font-size:15px;
#   font-weight: bolder;
#   padding: 19px;
# }

# </style>
# '''

# def envelope_tbl(lst):
#   result = '<table class="bigtable">\n'
#   for row in lst:
#     result += '<tr>\n\t'
#     for e in row:
#       if isinstance(e, dict):
#         result += '<td class="bigtd"'
#         for key in e:
#           if key != 'text':
#             result += str(key) + '="' + str(e[key]) + '" '
#         result += '><div width="40px">' + str(e['text']) + '</div></td>'
#       else:
#         result += '<td class="bigtd">' + str(e) + '</td>'
#     result += '\n</tr>\n'
#   result += '</table>'
#   return result

# def draw_tbl(lst):
#   result = envelope_tbl(lst)
#   import IPython
#   from google.colab import output
#   display(IPython.display.HTML(str_style_bigtbl + result))

# %%
# !pip install google.colab
# from google.colab import output

# %%
data = pd.DataFrame(
    {
        'user_id': [11, 22, 55, 11, 77],
        'source': ['ad', 'yandex', 'email', 'google', 'ad']
    }
)
data
# Out:
#    user_id  source
# 0       11      ad
# 1       22  yandex
# 2       55   email
# 3       11  google
# 4       77      ad

# %% [markdown]
# # Introducing Pandas Objects

# %% [markdown]
# ## The Pandas Series Object

# %% [markdown]
# Somewhat similar to `numpy.array`

# %%
import pandas as pd

data = pd.Series([0.25, 0.5, 0.75, 1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
print('data.values : ', data.values)
print('data.index : ', data.index)
print('data[1] : ', data[1])
# Out:
# data.values :  [0.25 0.5  0.75 1.  ]
# data.index :  RangeIndex(start=0, stop=4, step=1)
# data[1] :  0.5

# %%
pd.DataFrame(data)
# Out:
#       0
# 0  0.25
# 1  0.50
# 2  0.75
# 3  1.00

# %%
pd.DataFrame(data[1:3])
# Out:
#       0
# 1  0.50
# 2  0.75

# %% [markdown]
# `numpy.array` has implicitly (не явно) defined index, while `pandas.Series` -- explicitly (явно)

# %%
data_char = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a', 'b', 'c', 'd'])
data_num = pd.Series([0.25, 0.5, 0.75, 1.0], index=[2, 5, 3, 7])

# draw_tbl([['char index', 'numeric index'],
#           [pandas_to_html(data_char), pandas_to_html(data_num)],
#           ["data_char['b'] : " + str(data_char['b']), "data_num[5] : " + str(data_num[5])]])

# %%
data_char, data_char['b']
# Out:
# (a    0.25
#  b    0.50
#  c    0.75
#  d    1.00
#  dtype: float64,
#  0.5)

# %%
data_num,data_num[5]
# Out:
# (2    0.25
#  5    0.50
#  3    0.75
#  7    1.00
#  dtype: float64,
#  0.5)

# %% [markdown]
# `Series` as Python dictionary

# %%
import pandas as pd

population_dict = {'California': 38332521,
                   'Texas'     : 26448193,
                   'New York'  : 19651127,
                   'Florida'   : 19552860,
                   'Illinois'  : 12882135}
population = pd.Series(population_dict)
# draw_tbl([['population', "population['Texas':'Florida']"],
#           [pandas_to_html(population), pandas_to_html(population['Texas':'Florida'])]])
# print("population['California']: ", population['California'])

# %%
population['Texas':'Florida']
# Out:
# Texas       26448193
# New York    19651127
# Florida     19552860
# dtype: int64

# %%
population['California']
# Out:
# 38332521

# %%
# draw_tbl([["pd.Series([2, 4, 6])", "pd.Series(5, index=[100, 200, 300])",
#            "pd.Series({2:'a', 1:'b', 3:'c'})", "pd.Series({2:'a', 1:'b', 3:'c'}, index=[3, 2])"],
#           [pandas_to_html(pd.Series([2, 4, 6])), pandas_to_html(pd.Series(5, index=[100, 200, 300])),
#            pandas_to_html(pd.Series({2:'a', 1:'b', 3:'c'})), pandas_to_html(pd.Series({2:'a', 1:'b', 3:'c'}, index=[3, 2]))]])

# %%
pd.Series([2, 4, 6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
pd.Series(5, index=[100, 200, 300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd.Series({2:'a', 1:'b', 3:'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
pd.Series({2:'a', 1:'b', 3:'c'}, index=[3, 2])
# Out:
# 3    c
# 2    a
# dtype: object

# %% [markdown]
# ## The Pandas DataFrame Object

# %%
import pandas as pd

population_dict = {'California': 38332521, 'Texas': 26448193, 'New York': 19651127,'Florida': 19552860, 'Illinois': 12882135}
population = pd.Series(population_dict)
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297, 'Florida': 170312, 'Illinois': 149995}
area = pd.Series(area_dict)
states = pd.DataFrame({'population': population, 'area': area})
area_column = states['area']

# draw_tbl([['states', "states['area']"],
#           [pandas_to_html(states), pandas_to_html(area_column)]])

# %%
states
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
states['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
states.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
states.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %%
# From a single Series object.
popuation_series = pd.DataFrame(population, columns=['population'])
# display_pandas(popuation_series)
popuation_series
# Out:
#             population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %%
np.array([population, area])
# Out:
# array([[38332521, 26448193, 19651127, 19552860, 12882135],
#        [  423967,   695662,   141297,   170312,   149995]])

# %%
# pop_df = pd.DataFrame(np.array([population, area]).transpose(), columns= ['population','area'], index= states.index)
pop_df = pd.DataFrame({'population':population,'area':area})
pop_df
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
# From a list of dicts.
data = [{'a': i, 'b': 2 * i} for i in range(5)]
df1 = pd.DataFrame(data)
df1
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4
# 3  3  6
# 4  4  8

# %%
# From a list of dicts with MISSING data
df2 = pd.DataFrame([{'a': 1, 'b': 2}, {'b': 3, 'c': 4}])
df2
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %%
# From a NumPy structured array.
A = np.zeros(4, dtype=[('A', 'i8'), ('B', 'f8')]) # integer8 float8
df3 = pd.DataFrame(A, index= ['a','c','zz','555'])
df3
# Out:
#      A    B
# a    0  0.0
# c    0  0.0
# zz   0  0.0
# 555  0  0.0

# %%
df3['A']
# Out:
# a      0
# c      0
# zz     0
# 555    0
# Name: A, dtype: int64

# %%
df3.loc['555',:]
# Out:
# A    0.0
# B    0.0
# Name: 555, dtype: float64

# %%
# From a dictionary of Series objects.
df3 = pd.DataFrame({'population': population, 'area': area})
df3
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
# From a two-dimensional NumPy array.
df4 = pd.DataFrame(np.random.rand(3, 2), columns=['foo', 'bar'], index=['a', 'b', 'c'])
df4
# Out:
#         foo       bar
# a  0.278365  0.903285
# b  0.495617  0.546813
# c  0.730702  0.409953

# %% [markdown]
# ## The Pandas Index Object

# %%
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Int64Index([2, 3, 5, 7, 11], dtype='int64')

# %%
ind[1]
# Out:
# 3

# %%
ind[::2]
# Out:
# Int64Index([2, 5, 11], dtype='int64')

# %%
print(ind.size, ind.shape, ind.ndim, ind.dtype)
# Out:
# 5 (5,) 1 int64

# %%
print("index is IMMUTABLE, ERROR should be generated")
# ind[1] = 0
# Out:
# index is IMMUTABLE, ERROR should be generated

# %%
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])

offset =22

# intersection
# print(indA & indB) 
print(f'{"intersection:".ljust(offset)}',indA.intersection(indB))

# union
print(f'{"union:".ljust(offset)}',indA.union(indB))
# print(indA | indB) 

# symmetric difference: XOR symmetric_difference contains elements that appear in either
# idx1 or idx2 but not both. Equivalent to the Index created by 'union' idx1.difference(idx2) | idx2.difference(idx1) with duplicates dropped.
print(f'{"symmetric_difference:".ljust(offset)}',indA.symmetric_difference(indB))
# print(indA ^ indB) 

# difference:   Return a new Index with elements of index not in other.
print(f'{"difference:".ljust(offset)}',indA.difference(indB))
# Out:
# intersection:          Int64Index([3, 5, 7], dtype='int64')
# union:                 Int64Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')
# symmetric_difference:  Int64Index([1, 2, 9, 11], dtype='int64')
# difference:            Int64Index([1, 9], dtype='int64')

# %% [markdown]
# # Data Indexing and Selection

# %% [markdown]
# ## Data Selection in Series

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a', 'b', 'c', 'd'])
# old_data = pandas_to_html(data)
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['e'] = 12.0
data
# Out:
# a     0.25
# b     0.50
# c     0.75
# d     1.00
# e    12.00
# dtype: float64

# %%
data['b']
# Out:
# 0.5

# %%
'a' in data
# Out:
# True

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
data.keys
# Out:
# <bound method Series.keys of a     0.25
# b     0.50
# c     0.75
# d     1.00
# e    12.00
# dtype: float64>

# %%
data.values
# Out:
# array([ 0.25,  0.5 ,  0.75,  1.  , 12.  ])

# %%
list(data.items())
# Out:
# [('a', 0.25), ('b', 0.5), ('c', 0.75), ('d', 1.0), ('e', 12.0)]

# %%
# slicing by explicit index
# final index is included in the slice
df1 = data['a':'c']
df1
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %%
# slicing by implicit integer index
# final index is excluded from the slice
df2 = data[0:2]
df2
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
# masking
df1 = data[(data > 0.3) & (data < 0.8)]
df1
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
# fancy indexing
df2 = data[['a', 'e']]
df2
# Out:
# a     0.25
# e    12.00
# dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data = pd.Series(['a','aa' , 'b', 'c'], index=[1, 2, 3, 5])
data
# Out:
# 1     a
# 2    aa
# 3     b
# 5     c
# dtype: object

# %%
# draw_tbl([['original', 'explicit', 'implicit'],
#           [{'text': pandas_to_html(data), 'rowspan':4}, 'data.loc[1:3]', 'data[1:3] OR data.iloc[1:3]'],
#           [ pandas_to_html(data.loc[1:3]), pandas_to_html(data.iloc[1:3])],
#           ['data[1] OR data.loc[1]', 'data.iloc[1]'],
#           [str(data.loc[1]), str(data.iloc[1])]])

# %%
data.loc[1:3] # locate by label
# Out:
# 1     a
# 2    aa
# 3     b
# dtype: object

# %%
data.iloc[1:3] # Purely integer-location based indexing for selection by position (from 0 to length-1 of the axis)
# Out:
# 2    aa
# 3     b
# dtype: object

# %%
data[1:3] == data.iloc[1:3]
# Out:
# 2    True
# 3    True
# dtype: bool

# %% [markdown]
# ## Data Selection in DataFrame

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.area is data['area']
# Out:
# True

# %%
# conflicts with pop() method of DataFrame
data.pop is data['pop']
# Out:
# False

# %%
# adding new column + elementwise operations
data['density'] = data['pop'] / data['area'] 
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %%
data.T
# Out:
#            California         Texas      New York       Florida      Illinois
# area     4.239670e+05  6.956620e+05  1.412970e+05  1.703120e+05  1.499950e+05
# pop      3.833252e+07  2.644819e+07  1.965113e+07  1.955286e+07  1.288214e+07
# density  9.041393e+01  3.801874e+01  1.390767e+02  1.148061e+02  8.588376e+01

# %%
data.values
# Out:
# array([[4.23967000e+05, 3.83325210e+07, 9.04139261e+01],
#        [6.95662000e+05, 2.64481930e+07, 3.80187404e+01],
#        [1.41297000e+05, 1.96511270e+07, 1.39076746e+02],
#        [1.70312000e+05, 1.95528600e+07, 1.14806121e+02],
#        [1.49995000e+05, 1.28821350e+07, 8.58837628e+01]])

# %%
data.values[0]
# Out:
# array([4.23967000e+05, 3.83325210e+07, 9.04139261e+01])

# %%
data.loc[:'Florida', :'pop']
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860

# %%
data.iloc[:3, :2]
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127

# %%
# fancy indexing + masking
df = data.loc[data.density > 100, ['pop', 'density']] 
df
# Out:
#                pop     density
# New York  19651127  139.076746
# Florida   19552860  114.806121

# %%
# modification
data.iloc[0, 2] = 999999
data.loc['Texas', 'area'] = 15000
data
# Out:
#               area       pop        density
# California  423967  38332521  999999.000000
# Texas        15000  26448193      38.018740
# New York    141297  19651127     139.076746
# Florida     170312  19552860     114.806121
# Illinois    149995  12882135      85.883763

# %%
print('while indexing refers to columns, slicing and masking refer to rows')

data[1:3]
# Out:
# while indexing refers to columns, slicing and masking refer to rows
#             area       pop     density
# Texas      15000  26448193   38.018740
# New York  141297  19651127  139.076746

# %%
data['Florida':'Illinois']
# Out:
#             area       pop     density
# Florida   170312  19552860  114.806121
# Illinois  149995  12882135   85.883763

# %%
data[data.density > 100]
# Out:
#               area       pop        density
# California  423967  38332521  999999.000000
# New York    141297  19651127     139.076746
# Florida     170312  19552860     114.806121

# %% [markdown]
# # Operating on Data in Pandas

# %% [markdown]
# | Python Operator | Pandas Method(s)                      |
# |-----------------|---------------------------------------|
# | ``+``           | ``add()``                             |
# | ``-``           | ``sub()``, ``subtract()``             |
# | ``*``           | ``mul()``, ``multiply()``             |
# | ``/``           | ``truediv()``, ``div()``, ``divide()``|
# | ``//``          | ``floordiv()``                        |
# | ``%``           | ``mod()``                             |
# | ``**``          | ``pow()``                             |

# %% [markdown]
# ## Ufuncs: Index Preservation

# %%
s1 = pd.Series(np.random.randint(0, 10, 4))
s1
# Out:
# 0    4
# 1    1
# 2    2
# 3    6
# dtype: int64

# %%
s2 = np.exp(s1) #Calculate the exponential of all elements in the input array
s2
# Out:
# 0     54.598150
# 1      2.718282
# 2      7.389056
# 3    403.428793
# dtype: float64

# %%
df1 = pd.DataFrame(np.random.randint(0, 10, (7, 4)), columns=['A', 'B', 'C', 'D']) # (7,4)- shape
df1
# Out:
#    A  B  C  D
# 0  6  1  2  0
# 1  0  0  2  2
# 2  1  8  0  6
# 3  4  9  6  4
# 4  7  7  2  8
# 5  1  0  5  1
# 6  6  9  7  6

# %%
df2 = np.sin(df1 * np.pi / 4)
df2
# Out:
#               A             B         C             D
# 0 -1.000000e+00  7.071068e-01  1.000000  0.000000e+00
# 1  0.000000e+00  0.000000e+00  1.000000  1.000000e+00
# 2  7.071068e-01 -2.449294e-16  0.000000 -1.000000e+00
# 3  1.224647e-16  7.071068e-01 -1.000000  1.224647e-16
# 4 -7.071068e-01 -7.071068e-01  1.000000 -2.449294e-16
# 5  7.071068e-01  0.000000e+00 -0.707107  7.071068e-01
# 6 -1.000000e+00  7.071068e-01 -0.707107 -1.000000e+00

# %% [markdown]
# ## UFuncs: Index Alignment

# %%
area = pd.Series({'Alaska': 1723337, 'Texas': 695662, 'California': 423967}, name='area')
population = pd.Series({'California': 38332521, 'Texas': 26448193, 'New York': 19651127}, name='population')

# missing data is correctly handled (idexes merged)
df1 = population / area 
df1
# Out:
# Alaska              NaN
# California    90.413926
# New York            NaN
# Texas         38.018740
# dtype: float64

# %%
# draw_tbl([['area', "population", 'population / area '],
#           [pandas_to_html(area), pandas_to_html(population), pandas_to_html(df1)]])

# %%
df = pd.DataFrame({'area':{'Alaska': 1723337, 'Texas': 695662, 'California': 423967},
                    'population':{'California': 38332521, 'Texas': 26448193, 'New York': 19651127}})
df
# Out:
#                  area  population
# Alaska      1723337.0         NaN
# Texas        695662.0  26448193.0
# California   423967.0  38332521.0
# New York          NaN  19651127.0

# %%
# df['density'] = df.population / df.area
df['density'] = population / area
df
# Out:
#                  area  population    density
# Alaska      1723337.0         NaN        NaN
# Texas        695662.0  26448193.0  38.018740
# California   423967.0  38332521.0  90.413926
# New York          NaN  19651127.0        NaN

# %%
# Index
# At least one has value   | 
area.index.union(population.index)
# Out:
# Index(['Alaska', 'California', 'New York', 'Texas'], dtype='object')

# %%
# Index
# Both have values  &
area.index.intersection( population.index)
# Out:
# Index(['Texas', 'California'], dtype='object')

# %%
A = pd.Series([2, 4, 6], index=[0, 1, 2])
B = pd.Series([1, 3, 5], index=[1, 2, 3])

# NaN for missing operands
s1 = A + B 
s1
# Out:
# 0    NaN
# 1    5.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
print(A,'\n',B)
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64
#  1    1
# 2    3
# 3    5
# dtype: int64

# %%
# treat missing vals as zeros
s2 = A.add(B, fill_value=0) 
s2
# Out:
# 0    2.0
# 1    5.0
# 2    9.0
# 3    5.0
# dtype: float64

# %%
A = pd.DataFrame(np.random.randint(0, 20, (2, 2)), columns=list('AB'))
B = pd.DataFrame(np.random.randint(0, 10, (3, 3)), columns=list('BAC'))
A
# Out:
#    A   B
# 0  1  19
# 1  0  19

# %%
B
# Out:
#    B  A  C
# 0  4  3  3
# 1  3  7  7
# 2  8  5  5

# %%
df1 = A + B
df1
# Out:
#      A     B   C
# 0  4.0  23.0 NaN
# 1  7.0  22.0 NaN
# 2  NaN   NaN NaN

# %%
A
# Out:
#    A   B
# 0  1  19
# 1  0  19

# %%
A.stack() # Stack the prescribed level(s) from columns to index.    COLUMNS to INDEX
# Out:
# 0  A     1
#    B    19
# 1  A     0
#    B    19
# dtype: int64

# %%
# fill missing data with mean value in A
fill = A.stack().mean()   
fill
# Out:
# 9.75

# %%
df2 = A.add(B, fill_value=fill)
df2
# Out:
#        A      B      C
# 0   4.00  23.00  12.75
# 1   7.00  22.00  16.75
# 2  14.75  17.75  14.75

# %% [markdown]
# ## Ufuncs: Operations Between DataFrame and Series

# %%
A = np.random.randint(10, size=(5, 4))
df = pd.DataFrame(A, columns=list('QRST')) 
df
# Out:
#    Q  R  S  T
# 0  6  6  2  9
# 1  2  3  2  8
# 2  6  7  1  9
# 3  1  8  1  4
# 4  5  2  5  2

# %%
# broadcasting (row-wise)
df1 = df - df.iloc[1]
df1
# Out:
#    Q  R  S  T
# 0  4  3  0  1
# 1  0  0  0  0
# 2  4  4 -1  1
# 3 -1  5 -1 -4
# 4  3 -1  3 -6

# %%
# broadcasting (column-wise)
df2 = df.subtract(df['R'], axis=0) 
df2
# Out:
#    Q  R  S  T
# 0  0  0 -4  3
# 1 -1  0 -1  5
# 2 -1  0 -6  2
# 3 -7  0 -7 -4
# 4  3  0  3  0

# %%
halfrow = df2.iloc[4, ::2]
halfrow
# Out:
# Q    3
# S    3
# Name: 4, dtype: int64

# %%
halfrow.S
# Out:
# 3

# %%
# auto-alignment
# df2.Q - halfrow.Q
# df2.S - halfrow.S
df2 = df2 - halfrow 
df2
# Out:
#       Q   R     S   T
# 0  -3.0 NaN  -7.0 NaN
# 1  -4.0 NaN  -4.0 NaN
# 2  -4.0 NaN  -9.0 NaN
# 3 -10.0 NaN -10.0 NaN
# 4   0.0 NaN   0.0 NaN

# %% [markdown]
# # Handling Missing Data

# %% [markdown]
# **Approaches:**
# * masking
# * sentinel value
#
# Pandas chose to use sentinels for missing data, and further chose to use two already-existing Python null values: the special floatingpoint `NaN` value, and the Python `None` object.

# %% [markdown]
# **Upcasting conventions**
#
# |Typeclass     | Conversion When Storing NAs | NA Sentinel Value      |
# |--------------|-----------------------------|------------------------|
# | ``floating`` | No change                   | ``np.nan``             |
# | ``object``   | No change                   | ``None`` or ``np.nan`` |
# | ``integer``  | Cast to ``float64``         | ``np.nan``             |
# | ``boolean``  | Cast to ``object``          | ``None`` or ``np.nan`` |

# %% [markdown]
# - ``isnull()``: Generate a boolean mask indicating missing values
# - ``notnull()``: Opposite of ``isnull()``
# - ``dropna()``: Return a filtered version of the data
# - ``fillna()``: Return a copy of the data with missing values filled or imputed
#
# **Note:** ``None`` and ``NaN`` as essentially interchangeable for indicating missing or null values

# %% [markdown]
# ## Operating on Null Values

# %%
s = pd.Series([1, np.nan, 'hello', None])
s1 = s.isnull()
s1
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s2 = s[s.notnull()]
s3 = s.dropna()

# draw_tbl([['s', "s.isnull()", "s[s.notnull()]", "s.dropna()"],
#           [pandas_to_html(s), pandas_to_html(s1), pandas_to_html(s2), pandas_to_html(s3)]])

# %%
df = pd.DataFrame([[1,      np.nan, 2],
                   [2,      3,      5],
                   [np.nan, 4,      6]])

df1 = df.dropna()
df2 = df.dropna(axis='columns')

draw_tbl([['df', "df.dropna()", "df.dropna(axis='columns')"],
          [pandas_to_html(df), pandas_to_html(df1), pandas_to_html(df2)]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 8
#       5 df1 = df.dropna()
#       6 df2 = df.dropna(axis='columns')
# ----> 8 draw_tbl([['df', "df.dropna()", "df.dropna(axis='columns')"],
#       9           [pandas_to_html(df), pandas_to_html(df1), pandas_to_html(df2)]])
#
# NameError: name 'draw_tbl' is not defined

# %%
df[3] = np.nan

# drop columns that are all nans
df1 = df.dropna(axis='columns', how='all') 

# keep rows that contain at least 3 elements
df2 = df.dropna(axis='rows', thresh=3) 

draw_tbl([['df', "df.dropna(axis='columns', how='all')", "df.dropna(axis='rows', thresh=3)"],
          [pandas_to_html(df), pandas_to_html(df1), pandas_to_html(df2)]])

# %%
s = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))

# fill nans with zeros
s1 = s.fillna(0) 

# forward-fill
s2 = s.fillna(method='ffill')

# back-fill
s3 = s.fillna(method='bfill')

draw_tbl([['s', "s.fillna(0)", "s.fillna(method='ffill')", "s.fillna(method='bfill')"],
          [pandas_to_html(s), pandas_to_html(s1), pandas_to_html(s2), pandas_to_html(s3)]])

# %%
df1 = df.fillna(method='ffill', axis=1)
df2 = df.fillna(method='ffill', axis=0)

draw_tbl([['df', "df.fillna(method='ffill', axis=1)", "df.fillna(method='ffill', axis=0)"],
          [pandas_to_html(df), pandas_to_html(df1), pandas_to_html(df2)]])

# %% [markdown]
# #Hierarchical Indexing

# %% [markdown]
# ##A Multiply Indexed Series

# %% [markdown]
# Suppose we want to index data by two keys. We want to have the ability to filter by any of these keys.

# %%
import numpy as np
import pandas as pd

#bad way
index = [('California', 2000), ('California', 2010),
         ('New York',   2000), ('New York',   2010),
         ('Texas',      2000), ('Texas',      2010)]
populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]
               
pop = pd.Series(populations, index=index)

# filtering becomes inconvenient
pop_filtered = pop[[i for i in pop.index if i[1] == 2010]] 

draw_tbl([['pop', 'pop_filtered'],
          [pandas_to_html(pop), pandas_to_html(pop_filtered)]])

# %%
# The better way: Pandas MultiIndex
index = pd.MultiIndex.from_tuples(index)

# apply multiindex
pop = pop.reindex(index)

# easy filtering
pop_filtered = pop[:, 2010]

draw_tbl([['pop', 'pop_filtered'],
          [pandas_to_html(pop), pandas_to_html(pop_filtered)]])

# %%
pop_df = pop.unstack()  # as 2D
pop_st = pop_df.stack() # as multiindex

draw_tbl([['pop_df = pop.unstack() # as 2D', 'pop_df.stack() # as multiindex'],
          [pandas_to_html(pop_df), pandas_to_html(pop_st)]])

# %%
# add column
pop_df = pd.DataFrame({'total': pop,
                       'under18': [9267089, 9284094,
                                   4687374, 4318033,
                                   5906301, 6879014]})

# apply universal function
f_u18 = pop_df['under18'] / pop_df['total']

# present as 2D
ustack = f_u18.unstack()

draw_tbl([['pop_df', "pop_df['under18'] / pop_df['total']", 'unstacked'],
          [pandas_to_html(pop_df), pandas_to_html(f_u18), pandas_to_html(ustack)]])

# %% [markdown]
# ##Methods of MultiIndex Creation

# %% [markdown]
# Method | Code
# ---|---
# Simply pass a list of two or more index arrays to the constructor | `pd.DataFrame(np.random.rand(4, 2), index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]], columns=['data1', 'data2'])`
# From arrays/lists | `pd.MultiIndex.from_arrays([['a', 'a', 'b', 'b'], [1, 2, 1, 2]])`
# From tuples | `pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1), ('b', 2)])`
# Generating all combinations | `pd.MultiIndex.from_product([['a', 'b'], [1, 2]])`
# With one-hot encoding | `pd.MultiIndex(levels=[['a', 'b'], [1, 2]], codes=[[0, 0, 1, 1], [0, 1, 0, 1]])`

# %%
import pandas as pd
import numpy as np

index = [('California', 2000), ('California', 2010),
         ('New York', 2000),   ('New York', 2010),
         ('Texas', 2000),      ('Texas', 2010)]
index = pd.MultiIndex.from_tuples(index)

populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]
pop = pd.Series(populations, index=index)

pop.index.names = ['state', 'year']

display_pandas(pop)

# %%
# Multiindexes for rows and columns

# hierarchical indices and columns
index = pd.MultiIndex.from_product([[2013, 2014], [1, 2]], names=['year', 'visit'])
columns = pd.MultiIndex.from_product([['Bob', 'Guido', 'Sue'], ['HR', 'Temp']], names=['subject', 'type'])

# mock some data
data = np.round(np.random.randn(4, 6), 1)
data[:, ::2] *= 10
data += 37

# create the DataFrame
health_data = pd.DataFrame(data, index=index, columns=columns)

draw_tbl([['health_data', "health_data['Guido']"],
          [pandas_to_html(health_data), pandas_to_html(health_data['Guido'])]])

# %% [markdown]
# ##Indexing and Slicing a MultiIndex

# %%
import pandas as pd
import numpy as np

index = [('California', 2000), ('California', 2010),
         ('New York', 2000),   ('New York', 2010),
         ('Texas', 2000),      ('Texas', 2010)]
index = pd.MultiIndex.from_tuples(index)

populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]
pop = pd.Series(populations, index=index)
pop.name = 'population'

pop.index.names = ['state', 'year']

draw_tbl([['pop', "pop['California']", "pop.loc['California':'New York']", "pop[:, 2000]"],
          [{'text': pandas_to_html(pop), 'rowspan':3}, 
           pandas_to_html(pop['California']), 
           pandas_to_html(pop.loc['California':'New York']),
           pandas_to_html(pop[:, 2000])],
          ["pop['California', 2000]", "pop[pop > 22000000]", "pop[['California', 'Texas']]"],
          [pop['California', 2000],
           pandas_to_html(pop[pop > 22000000]), 
           pandas_to_html(pop[['California', 'Texas']])]])

# %%
# hierarchical indices and columns
index = pd.MultiIndex.from_product([[2013, 2014, 2015], [1, 2]],
names=['year', 'visit'])
columns = pd.MultiIndex.from_product([['Bob', 'Guido', 'Sue'], ['HR', 'Temp']],
names=['subject', 'type'])
# mock some data
data = np.round(np.random.randn(6, 6), 1)
data[:, ::2] *= 10
data += 37
# create the DataFrame
health_data = pd.DataFrame(data, index=index, columns=columns)

draw_tbl([['health_data', "health_data['Guido', 'HR']", "health_data.loc[:, ('Bob', 'HR')"],
          [pandas_to_html(health_data), 
           pandas_to_html(health_data['Guido', 'HR']), 
           pandas_to_html(health_data.loc[:, ('Bob', 'HR')])]])

# %%
# ERROR SHOULD BE GENERATED, no slices in tuples
health_data.loc[(:, 1), (:, 'HR')]

# %%
# workaround
idx = pd.IndexSlice
sliced = health_data.loc[idx[:, 1], idx[:, 'HR']]

display_pandas(sliced)

# %% [markdown]
# ##Rearranging Multi-Indices

# %% [markdown]
# Many of the MultiIndex slicing operations will fail if the index is not sorted!

# %%
import pandas as pd
import numpy as np

index = pd.MultiIndex.from_product([['a', 'c', 'b'], [1, 2]])
data = pd.Series(np.random.rand(6), index=index)
data.index.names = ['char', 'int']
display_pandas(data)

# %%
print("ERROR SHOULD BE GENERATED")
try:
  data['a':'b'] # Trying to slice data
except KeyError as e:
  print(type(e))
  print(e)

# %%
data = data.sort_index() # now can be sliced data['a':'b'] 

draw_tbl([['data.sort_index()', "data['a':'b']"],
          [pandas_to_html(data), 
           pandas_to_html(data['a':'b'])]])

# %%
index = [('California', 2000), ('California', 2010),
         ('New York', 2000),   ('New York', 2010),
         ('Texas', 2000),      ('Texas', 2010)]
index = pd.MultiIndex.from_tuples(index)

populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]
pop = pd.Series(populations, index=index)

pop.index.names = ['state', 'year']

pop_flat = pop.reset_index(name='population')
restored = pop_flat.set_index(['state', 'year']) 


draw_tbl([['pop', "pop.unstack(level=0)", "pop.unstack(level=1)"],
          [pandas_to_html(pop), 
           pandas_to_html(pop.unstack(level=0)),
           pandas_to_html(pop.unstack(level=1))],
          ["pop.unstack().stack()", "flat = pop.reset_index(name='population')", "flat.set_index(['state', 'year'])"],
          [pandas_to_html(pop.unstack().stack()),
           pandas_to_html(pop.reset_index(name='population')),
           pandas_to_html(restored)]])

# %% [markdown]
# ##Data Aggregations on Multi-Indices

# %%
# hierarchical indices and columns
index = pd.MultiIndex.from_product([[2013, 2014], [1, 2]],
names=['year', 'visit'])
columns = pd.MultiIndex.from_product([['Bob', 'Guido', 'Sue'], ['HR', 'Temp']],
names=['subject', 'type'])
# mock some data
data = np.round(np.random.randn(4, 6), 1)
data[:, ::2] *= 10
data += 37
# create the DataFrame
health_data = pd.DataFrame(data, index=index, columns=columns)
data_mean = health_data.groupby(level='year').mean()

draw_tbl([['health_data', "data_mean = health_data.mean(level='year') # mean over visits", "data_mean.mean(axis=1, level='type') # mean over columns"],
          [pandas_to_html(health_data), 
           pandas_to_html(health_data.groupby(level='year').mean()),
           pandas_to_html(data_mean.groupby(axis=1, level='type').mean())]])

# %% [markdown]
# #Combining Datasets

# %% [markdown]
# ##Simple Concatenation with pd.concat

# %%
import pandas as pd
import numpy as np

ser1 = pd.Series(['A', 'B', 'C'], index=[1, 2, 3])
ser2 = pd.Series(['D', 'E', 'F'], index=[4, 5, 6])
con = pd.concat([ser1, ser2])


draw_tbl([['ser1', "ser2", "pd.concat([ser1, ser2])"],
          [pandas_to_html(ser1), pandas_to_html(ser2), pandas_to_html(con)]])

# %%
import pandas as pd
import numpy as np

def make_df(cols, ind):
  """Quickly make a DataFrame"""
  data = {c: [str(c) + str(i) for i in ind] for c in cols}
  return pd.DataFrame(data, ind)

df1 = make_df('AB', [1, 2])
df2 = make_df('AB', [3, 4])
con = pd.concat([df1, df2])
app = df1.append(df2)

draw_tbl([['df1', "df2", "pd.concat([df1, df2])", "df1.append(df2) # shorthand for pd.concat([df1, df2]), does not modify the original object!"],
          [pandas_to_html(df1), pandas_to_html(df2), pandas_to_html(con), pandas_to_html(app)]])

# %%
df3 = make_df('AB', [0, 1])
df4 = make_df('CD', [0, 1])
con = pd.concat([df3, df4], axis=1)

draw_tbl([['df3', "df4", "pd.concat([df3, df4], axis=1)"],
          [pandas_to_html(df3), pandas_to_html(df4), pandas_to_html(con)]])

# %%
x = make_df('AB', [0, 1])
y = make_df('AB', [2, 3])
y.index = x.index # make duplicate indices!
con = pd.concat([x, y])

# this is valid within DataFrames, but the outcome is often undesirable

draw_tbl([[{'text': 'indices are duplicated!', 'colspan':2}, 'this is valid within DataFrames, but the outcome is often undesirable'],
          ['x', "y", "pd.concat([x, y])"],
          [pandas_to_html(x), pandas_to_html(y), pandas_to_html(con)]])

# %%
# Catching the repeats as an error
try:
  pd.concat([x, y], verify_integrity=True)
except ValueError as e:
  print("ValueError:", e)

# %%
# Ignoring the index
con_no_index =  pd.concat([x, y], ignore_index=True)
con_multi_index = pd.concat([x, y], keys=['x', 'y'])

draw_tbl([[{'text': 'indices are duplicated!', 'colspan':2}, 'drop old index', 'use MultiIndex'],
          ['x', "y", " pd.concat([x, y], ignore_index=True)", "pd.concat([x, y], keys=['x', 'y'])"],
          [pandas_to_html(x), pandas_to_html(y), pandas_to_html(con_no_index), pandas_to_html(con_multi_index)]])

# %%
# note the different set of column names
df5 = make_df('ABC', [1, 2])
df6 = make_df('BCD', [3, 4])
con = pd.concat([df5, df6], sort=True)
con_inner = pd.concat([df5, df6], sort=True, join='inner')

draw_tbl([['x', "y", "pd.concat([x, y], ignore_index=True) # simple concat", "pd.concat([df5, df6], sort=True, join='inner') # retain intersecting columns only"],
          [pandas_to_html(df5), pandas_to_html(df6), pandas_to_html(con), pandas_to_html(con_inner)]])

# %% [markdown]
# ##Categories of Joins

# %%
import pandas as pd
import numpy as np

# One-to-one joins
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
                    'hire_date': [2004, 2008, 2012, 2014]})
merge = pd.merge(df1, df2)

# merge in general discards the index, except in the special case of merges by index
draw_tbl([[{'text':"One-to-one join (merge in general discards the index, except in the special case of merges by index)", 'colspan':3}],
          ['df1', "df2", "pd.merge(df1, df2)"],
          [pandas_to_html(df1), pandas_to_html(df2), pandas_to_html(merge)]])

# %%
# Many-to-one joins (one of the two key columns contains duplicate entries)
df3 = pd.merge(df1, df2)
df4 = pd.DataFrame({'group': ['Accounting', 'Engineering', 'HR'],
                    'supervisor': ['Carly', 'Guido', 'Steve']})
merge = pd.merge(df3, df4)

draw_tbl([[{'text':"Many-to-one joins (one of the two key columns contains duplicate entries)", 'colspan':3}],
          ['df3', "df4", "pd.merge(df3, df4)"],
          [pandas_to_html(df3), pandas_to_html(df4), pandas_to_html(merge)]])

# %%
# Many-to-many joins
df5 = pd.DataFrame({'group': ['Accounting', 'Accounting',
                    'Engineering', 'Engineering', 'HR', 'HR'],
                    'skills': ['math', 'spreadsheets', 'coding', 'linux',
                               'spreadsheets', 'organization']})
merge = pd.merge(df1, df5)

draw_tbl([[{'text':"Many-to-many joins", 'colspan':3}],
          ['df1', "df5", "pd.merge(df1, df5)"],
          [pandas_to_html(df1), pandas_to_html(df5), pandas_to_html(merge)]])

# %% [markdown]
# ##Specification of the Merge Key

# %%
# explicitly specify the name of the key column
merge = pd.merge(df1, df2, on='employee')

draw_tbl([[{'text':"explicitly specify the name of the key column", 'colspan':3}],
          ['df1', "df2", "pd.merge(df1, df2, on='employee')"],
          [pandas_to_html(df1), pandas_to_html(df2), pandas_to_html(merge)]])

# %%
# merge when 2 columns having different names but same meaning
df3 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'salary': [70000, 80000, 120000, 90000]})
merge = pd.merge(df1, df3, left_on="employee", right_on="name")

draw_tbl([[{'text':"merge when 2 columns having different names but same meaning", 'colspan':3}],
          ['df1', "df3", "pd.merge(df1, df3, left_on='employee', right_on='name')"],
          [pandas_to_html(df1), pandas_to_html(df3), pandas_to_html(merge)]])

# %%
# drop redundant column
merge = pd.merge(df1, df3, left_on='employee', right_on='name').drop('name', axis=1)

draw_tbl([[{'text':"merge when 2 columns having different names but same meaning AND drop redundant column", 'colspan':3}],
          ['df1', "df3", "pd.merge(df1, df3, left_on='employee', right_on='name').drop('name', axis=1)"],
          [pandas_to_html(df1), pandas_to_html(df3), pandas_to_html(merge)]])

# %%
# merge on an index
df1a = df1.set_index('employee')
df2a = df2.set_index('employee')
merge = pd.merge(df1a, df2a, left_index=True, right_index=True)
merge_short = df1a.join(df2a)


draw_tbl([[{'text':"merge on an index", 'colspan':4}],
          ["df1a = df1.set_index('employee')", "df2.set_index('employee')", "pd.merge(df1a, df2a, left_index=True, right_index=True)", "df1a.join(df2a)"],
          [pandas_to_html(df1a), pandas_to_html(df2a), pandas_to_html(merge), pandas_to_html(merge_short)]])

# %%
# mix indices and columns
merge = pd.merge(df1a, df3, left_index=True, right_on='name')

draw_tbl([[{'text':"mix indices and columns", 'colspan':3}],
          ['df1a', "df3", "pd.merge(df1a, df3, left_index=True, right_on='name')"],
          [pandas_to_html(df1a), pandas_to_html(df3), pandas_to_html(merge)]])

# %% [markdown]
# ##Specifying Set Arithmetic for Joins

# %%
#@title Joining tables
# %%html 

<svg width="264.77mm" height="63.267mm" version="1.1" viewBox="0 0 264.77 63.267" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
 <g transform="translate(-51.954 -23.287)">
  <g fill="none" stroke="#dcdcdc" stroke-width="1.065">
   <g stroke-linecap="square" stroke-linejoin="round">
    <rect x="52.486" y="28.828" width="57.364" height="9.6217"/>
    <rect x="52.486" y="38.45" width="57.364" height="9.6217"/>
    <rect x="52.486" y="48.072" width="57.364" height="9.6217"/>
    <rect x="52.486" y="57.694" width="57.364" height="9.6217"/>
   </g>
   <path d="m98.274 28.647v38.27"/>
  </g>
  <g font-family="'Courier New'" font-weight="bold" letter-spacing="0px" stroke-width=".26458" word-spacing="0px">
   <text x="102.13203" y="35.93951" fill="#969696" font-size="7.1506px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="102.13203" y="35.93951" fill="#969696" font-family="'Courier New'" font-size="7.1506px" font-weight="bold" stroke-width=".26458" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">A</tspan></text>
   <text x="102.32169" y="45.64587" fill="#969696" font-size="7.1506px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="102.32169" y="45.64587" fill="#969696" font-family="'Courier New'" font-size="7.1506px" font-weight="bold" stroke-width=".26458" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">B</tspan></text>
   <text x="102.06989" y="55.334389" fill="#da9696" font-size="7.1506px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="102.06989" y="55.334389" fill="#da9696" font-family="'Courier New'" font-size="7.1506px" font-weight="bold" stroke-width=".26458" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">C</tspan></text>
   <text x="102.33717" y="64.822456" fill="#da9696" font-size="7.1506px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="102.33717" y="64.822456" fill="#da9696" font-family="'Courier New'" font-size="7.1506px" font-weight="bold" stroke-width=".26458" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">D</tspan></text>
  </g>
  <g>
   <path d="m84.005 29.167v38.27" fill="none" stroke="#dcdcdc" stroke-width="1.065"/>
   <path d="m68.886 28.978v38.27" fill="none" stroke="#dcdcdc" stroke-width="1.065"/>
   <g id="content" transform="matrix(.44052 0 0 -.44052 33.322 337.82)" fill-opacity=".79227" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" stroke-width="0" ns0:preamble="default_packages.tex" ns0:text="index\n" xml:space="preserve"><path d="m150.48 711.52-1.4-0.11v-0.31c0.65 0 0.74-0.06 0.74-0.55v-2.67c0-0.45-0.11-0.45-0.78-0.45v-0.3c0.32 0.01 0.86 0.03 1.1 0.03 0.35 0 0.7-0.02 1.04-0.03v0.3c-0.66 0-0.7 0.05-0.7 0.44z"/><path d="m150.52 713.24v0.03l-0.01 0.03v0.06l-0.01 0.02-0.02 0.06-0.02 0.04-0.01 0.03-0.01 0.02-0.02 0.02-0.01 0.02-0.02 0.02-0.01 0.02-0.02 0.02-0.02 0.01-0.02 0.02-0.02 0.01-0.02 0.02-0.02 0.01-0.03 0.01-0.06 0.03-0.03 0.01-0.02 0.01h-0.03l-0.02 0.01h-0.08c-0.31 0-0.53-0.27-0.53-0.53s0.22-0.52 0.53-0.52c0.28 0 0.53 0.21 0.53 0.52z"/><path d="m152.58 710.54v-2.66c0-0.45-0.11-0.45-0.78-0.45v-0.3c0
83 0.03 0.28 0 0.7-0.02 0.94-0.03v0.3c-0.22 0.03-0.29 0.16-0.29 0.31 0 0.22 0.29 0.55 0.9 1.26l0.76-0.99c0.08-0.11 0.21-0.27 0.21-0.33 0-0.09-0.09-0.24-0.36-0.25v-0.3c0.3 0.01 0.86 0.03 1.08 0.03 0.26 0 0.65-0.01 0.95-0.03v0.3c-0.53 0-0.72 0.02-0.94 0.31z"/></g>
  </g>
  <g fill="none" stroke="#dcdcdc" stroke-width="1.065">
   <g stroke-linecap="square" stroke-linejoin="round">
    <rect transform="scale(-1,1)" x="-179.38" y="28.78" width="57.364" height="9.6217"/>
    <rect x="122.01" y="38.402" width="57.364" height="9.6217"/>
    <rect transform="scale(-1,1)" x="-179.38" y="48.024" width="57.364" height="9.6217"/>
    <rect transform="scale(-1,1)" x="-179.38" y="57.645" width="57.364" height="9.6217"/>
   </g>
   <path d="m133.59 28.599v38.27"/>
  </g>
  <g font-family="'Courier New'" font-weight="bold" letter-spacing="0px" stroke-width=".26458" word-spacing="0px">
   <text x="126.08839" y="36.025002" fill="#da9696" font-size="7.1506px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="126.08839" y="36.025002" fill="#da9696" font-family="'Courier New'" font-size="7.1506px" font-weight="bold" stroke-width=".26458" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">C</tspan></text>
   <g font-size="7.1506px">
    <text x="126.27807" y="45.731361" fill="#da9696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="126.27807" y="45.731361" fill="#da9696" font-family="'Courier New'" font-size="7.1506px" font-weight="bold" stroke-width=".26458" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">D</tspan></text>
    <text x="126.02627" y="55.419876" fill="#969696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="126.02627" y="55.419876" fill="#969696" font-family="'Courier New'" font-size="7.1506px" font-weight="bold" stroke-width=".26458" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">E</tspan></text>
    <text x="126.29356" y="64.907936" fill="#969696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="126.29356" y="64.907936" fill="#969696" font-family="'Courier New'" font-size="7.1506px" font-weight="bold" stroke-width=".26458" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">F</tspan></text>
   </g>
  </g>
  <g>
   <path d="m154.54 28.985v38.27" fill="none" stroke="#dcdcdc" stroke-width="1.065"/>
   <g transform="matrix(.44052 0 0 -.44052 57.054 337.89)" fill-opacity=".79227" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" stroke-width="0" ns0:preamble="default_packages.tex" ns0:text="index\n" xml:space="preserve"><path d="m150.48 711.52-1.4-0.11v-0.31c0.65 0 0.74-0.06 0.74-0.55v-2.67c0-0.45-0.11-0.45-0.78-0.45v-0.3c0.32 0.01 0.86 0.03 1.1 0.03 0.35 0 0.7-0.02 1.04-0.03v0.3c-0.66 0-0.7 0.05-0.7 0.44z"/><path d="m150.52 713.24v0.03l-0.01 0.03v0.06l-0.01 0.02-0.02 0.06-0.02 0.04-0.01 0.03-0.01 0.02-0.02 0.02-0.01 0.02-0.02 0.02-0.01 0.02-0.02 0.02-0.02 0.01-0.02 0.02-0.02 0.01-0.02 0.02-0.02 0.01-0.03 0.01-0.06 0.03-0.03 0.01-0.02 0.01h-0.03l-0.02 0.01h-0.08c-0.31 0-0.53-0.27-0.53-0.53s0.22-0.52 0.53-0.52c0.28 0 0.53 0.21 0.53 0.52z"/><path d="m152.58 710.54v-2.66c0-0.45-0.11-0.45-0.78-0.45v-0.3c0
-0.35l1.83-2.76-1.63-2.4c-0.14-0.2-0.44-0.66-1.45-0.66v-0.3c0.36 0.01 0.78 0.03 1.11 0.03 0.37 0 0.92 0 1.28-0.03v0.3c-0.46 0.01-0.63 0.28-0.63 0.46 0 0.09 0.03 0.13 0.1 0.24l1.41 2.08 1.58-2.37c0.02-0.04 0.05-0.08 0.05-0.11 0-0.12-0.22-0.29-0.65-0.3v-0.3c0.35 0.03 1.08 0.03 1.45 0.03 0.42 0 0.88-0.01 1.3-0.03v0.3h-0.19c-0.52 0-0.73 0.05-0.94 0.36z" stroke-width="0"/><path d="m213.74 712.59 0.03 0.05 0.08 0.1 0.03 0.05 0.08 0.08 0.05 0.04 0.12 0.09 0.05 0.03 0.04 0.03 0.04 0.02 0.05 0.02 0.08 0.04 0.05 0.01 0.04 0.01 0.04 0.02 0.05 0.01 0.04 0.01h0.04l0.08 0.02h0.08l0.04 0.01h0.16v0.31c-0.30997-0.02-0.69997-0.03-0.96997-0.03-0.31 0-0.89 0.02-1.15 0.03v-0.31c0.41 0 0.57-0.19 0.57-0.39 0-0.11-0.06-0.23-0.1-0.29l-1.65-2.67-1.8 2.93c-0.07 0.1-0.07 0.12-0.07 0.17 0 0.21 0.25 0.25 0.7 0.25v0.31c-0.36-0.03-1.09-0.03-1.48-0.03-0.42 0-0.88 0.01-1.3 0.03v-0.31h0.18c0.68 0 0.76-0.11 0.92-0.37l2.1-3.39v-1.94c0-0.36-0.03-0.47-0.79-0.47h-0.24v-0.3c0.36 0.03 1.06 0.03 1.45 0.03s1.1 0 1.46-0.03v0.3h-0.23c-0.77 0-0.8 0.1-0.8 0.49v1.92z" fill-rule="evenodd" stroke-miterlimit="10.433" stroke-width="0"/><g fill="none" stroke="#dcdcdc" stroke-miterlimit="4" stroke-width="2.6828"><g stroke-linecap="square" stroke-linejoin="round"><rect transform="scale(1,-1)" x="316.38" y="-700.96" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="316.38" y="-676.72" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="316.38" y="-652.48" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="316.38" y="-628.24" width="144.5" height="24.238"/></g><path d="m431.72 701.41v-96.406"/></g><g font-family="'Courier New'" font-weight="bold" letter-spacing="0px" stroke="none" stroke-width=".66651" word-spacing="0px"><text transform="scale(1 -1)" x="441.44238" y="-683.04425" fill="#969696" font-size="18.013px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="441.44238" y="-683.04425" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">A</tspan></text><g font-size="18.013px">
<text transform="scale(1 -1)" x="441.92017" y="-658.59308" fill="#969696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="441.92017" y="-658.59308" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">B</tspan></text>
<text transform="scale(1 -1)" x="441.28586" y="-634.18689" fill="#da9696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="441.28586" y="-634.18689" fill="#da9696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">C</tspan></text>
<text transform="scale(1 -1)" x="441.95917" y="-610.28564" fill="#da9696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="441.95917" y="-610.28564" fill="#da9696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">D</tspan></text></g></g><g fill="none" stroke="#dcdcdc" stroke-miterlimit="4" stroke-width="2.6828">
<path d="m395.78 700.1v-96.406"/><path d="m357.69 700.58v-96.406"/><g stroke-linecap="square" stroke-linejoin="round"><rect transform="scale(-1)" x="-576.23" y="-653.48" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="431.72" y="-629.25" width="144.5" height="24.238"/><rect transform="scale(-1)" x="-576.23" y="-605.01" width="144.5" height="24.238"/><rect transform="scale(-1)" x="-576.23" y="-580.77" width="144.5" height="24.238"/></g><path d="m460.89 653.94v-96.406"/></g><text transform="scale(1 -1)" x="441.83511" y="-586.37653" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" letter-spacing="0px" stroke="none" stroke-width=".66651" word-spacing="0px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="441.83511" y="-586.37653" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">E</tspan></text>
<text transform="scale(1 -1)" x="442.50842" y="-562.47528" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" letter-spacing="0px" stroke="none" stroke-width=".66651" word-spacing="0px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="442.50842" y="-562.47528" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal
stroke-linecap="square" stroke-linejoin="round" stroke-opacity=".27451" stroke-width="2.0153"/></g><path transform="matrix(.66651 0 0 -.66651 -89.421 714.57)" d="m699.24 76.07c-7.3009 4.3213-12.633 11.508-17.435 18.384-14.373 21.346-15.183 50.739-1.8314 72.767 4.9347 8.011 10.926 15.974 18.838 21.151 6.2139-4.1219 11.197-10.161 15.733-16.066 7.1622-10.97 12.806-23.522 12.448-36.888 0.58041-10.784-0.60492-21.807-5.591-31.541-4.6336-10.857-12.442-20.196-21.462-27.671-0.21203-0.11384-0.45831-0.19382-0.7002-0.13534z" fill="#005bff" fill-opacity=".098039" stroke="none"/></g></g>
 </g>
</svg>

# %%
import pandas as pd
import numpy as np

# inner join = intersection
df6 = pd.DataFrame({'name': ['Peter', 'Paul', 'Mary'],
                    'food': ['fish', 'beans', 'bread']},
                    columns=['name', 'food'])
df7 = pd.DataFrame({'name': ['Mary', 'Joseph'],
                    'drink': ['wine', 'beer']},
                     columns=['name', 'drink'])
merge = pd.merge(df6, df7)
merge_exp = pd.merge(df6, df7, how='inner')

draw_tbl([[{'text':"inner join = intersection", 'colspan':4}],
          ['df1a', "df3", "pd.merge(df6, df7)", "pd.merge(df6, df7, how='inner') # explicit declaration of method"],
          [pandas_to_html(df6), pandas_to_html(df7), pandas_to_html(merge), pandas_to_html(merge_exp)]])

# %%
#@title Left Join
# %%html 

<svg width="218.4mm" height="58.397mm" version="1.1" viewBox="0 0 218.4 58.397" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
 <g transform="translate(-55.09 -25.751)">
  <g transform="matrix(.45332 0 0 -.45332 -10.894 340.12)" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" stroke-width="3.309" ns0:preamble="default_packages.tex" ns0:text="col.1 col.2 col.3 col.A col.B\n" xml:space="preserve"><g transform="matrix(.8757 0 0 .8757 216.95 73.166)" fill-rule="evenodd" stroke-miterlimit="10.433" stroke-width="5.6679" ns0:preamble="default_packages.tex" ns0:text="XY\n" xml:space="preserve"><g fill="none" stroke="#dcdcdc" stroke-miterlimit="4" stroke-width="2.6828"><g stroke-linecap="square" stroke-linejoin="round"><rect transform="scale(1,-1)" x="-80.178" y="-707.02" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="-80.178" y="-682.78" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="-80.178" y="-658.54" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="-80.178" y="-634.3" width="144.5" height="24.238"/></g><path d="m35.164 707.47v-96.406"/></g><g font-family="'Courier New'" font-weight="bold" letter-spacing="0px" stroke="none" stroke-width=".66651" word-spacing="0px"><text transform="scale(1 -1)" x="44.88348" y="-689.1037" fill="#969696" font-size="18.013px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="44.88348" y="-689.1037" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">A</tspan></text><g font-size="18.013px">
<text transform="scale(1 -1)" x="45.361263" y="-664.65253" fill="#969696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="45.361263" y="-664.65253" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">B</tspan></text>
<text transform="scale(1 -1)" x="44.726955" y="-640.24634" fill="#da9696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="44.726955" y="-640.24634" fill="#da9696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">C</tspan></text>
<text transform="scale(1 -1)" x="45.400265" y="-616.34509" fill="#da9696" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="45.400265" y="-616.34509" fill="#da9696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">D</tspan></text></g></g><g fill="none" stroke="#dcdcdc" stroke-miterlimit="4" stroke-width="2.6828">
<path d="m-0.77951 706.16v-96.406"/><path d="m-38.866 706.64v-96.406"/><g stroke-linecap="square" stroke-linejoin="round"><rect transform="scale(-1)" x="-179.67" y="-658.25" width="144.5" height="22.942"/><rect transform="scale(1,-1)" x="35.164" y="-635.31" width="144.5" height="24.238"/><rect transform="scale(-1)" x="-179.67" y="-611.07" width="144.5" height="24.238"/><rect transform="scale(-1)" x="-179.67" y="-586.83" width="144.5" height="24.238"/></g><path d="m64.326 660v-96.406"/></g><text transform="scale(1 -1)" x="45.276211" y="-592.43597" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" letter-spacing="0px" stroke="none" stroke-width=".66651" word-spacing="0px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="45.276211" y="-592.43597" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">E</tspan></text>
<text transform="scale(1 -1)" x="45.94952" y="-568.53473" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" letter-spacing="0px" stroke="none" stroke-width=".66651" word-spacing="0px" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal;line-height:1.25" xml:space="preserve"><tspan x="45.94952" y="-568.53473" fill="#969696" font-family="'Courier New'" font-size="18.013px" font-weight="bold" stroke-width=".66651" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">F</tspan></text>
<path d="m117.1 659.03v-96.406" fill="none" stroke="#dcdcdc" stroke-miterlimit="4" stroke-width="2.6828"/><rect transform="scale(1,-1)" x="-79.9" y="-706.89" width="259.33" height="95.997" fill="#006ea4" fill-opacity=".058824" stroke="#005bff" stroke-linecap="square" stroke-linejoin="round" stroke-miterlimit="4" stroke-opacity=".17391" stroke-width="2.0153"/><g fill="none" stroke="#005bdc" stroke-miterlimit="4"><g stroke-opacity=".17255"><path d="m117.1 705.89v-93.99" stroke-width="2.6828"/><path d="m-38.866 705.87v-93.974" stroke-width="2.6828"/><path d="m-0.77951 705.89v-93.987" stroke-width="2.6828"/><path d="m35.164 705.78v-93.886" stroke-width="2.6828"/><path d="m178.41 635.28h-257.32" stroke-width="2.6828"/></g><ellipse transform="scale(1,-1)" cx="412.03" cy="-626.36" rx="55.612" ry="50.664" stroke-linecap="square" stroke-linejoin="round" stroke-opacity=".27451" stroke-width="2.0153"/><g stroke-opacity=".17255"><path d="m64.326 705.85v-93.886" stroke-width="2.6828"/><path d="m178.43 658.48h-257.32" stroke-width="2.6828"/><path d="m178.37 682.72h-257.32" stroke-width="2.6828"/></g></g><ellipse transform="scale(1,-1)" cx="340.87" cy="-626.59" rx="55.612" ry="50.664" fill="#005bff" fill-opacity=".098039" stroke="#005bdc" stroke-linecap="square" stroke-linejoin="round" stroke-miterlimit="4" stroke-opacity=".27451" stroke-width="2.0153"/><g fill="#000000" font-family="Verdana" font-size="13.243px" letter-spacing="0px" stroke="none" stroke-width="3.7777" word-spacing="0px"><text transform="scale(1 -1)" x="75.898346" y="-689.55743" style="line-height:1.25" xml:space="preserve"><tspan x="75.898346" y="-689.55743" fill="#005bff" fill-opacity=".44444" font-family="'Courier New'" font-size="13.243px" font-weight="bold" stroke-width="3.7777" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">null</tspan></text><g fill-rule="evenodd" stroke-miterlimit="10.433">
<text transform="scale(1 -1)" x="134.72403" y="-689.5968" style="line-height:1.25" xml:space="preserve"><tspan x="134.72403" y="-689.5968" fill="#005bff" fill-opacity=".44444" font-family="'Courier New'" font-size="13.243px" font-weight="bold" stroke-width="3.7777" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">null</tspan></text>
<text transform="scale(1 -1)" x="134.84184" y="-665.44312" style="line-height:1.25" xml:space="preserve"><tspan x="134.84184" y="-665.44312" fill="#005bff" fill-opacity=".44444" font-family="'Courier New'" font-size="13.243px" font-weight="bold" stroke-width="3.7777" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">null</tspan></text>
<text transform="scale(1 -1)" x="75.812469" y="-665.32526" style="line-height:1.25" xml:space="preserve"><tspan x="75.812469" y="-665.32526" fill="#005bff" fill-opacity=".44444" font-family="'Courier New'" font-size="13.243px" font-weight="bold" stroke-width="3.7777" style="font-feature-settings:normal;font-variant-caps:normal;font-variant-ligatures:normal;font-variant-numeric:normal">null</tspan></text>
</g></g></g></g>
 </g>
</svg>

# %%
# augment left table with intersection
merge = pd.merge(df6, df7, how='left')

draw_tbl([[{'text':"augment left table with intersection", 'colspan':3}],
          ['df6', "df7", "pd.merge(df6, df7, how='left')"],
          [pandas_to_html(df6), pandas_to_html(df7), pandas_to_html(merge)]])

# %%
#@title Outer Join
# %%html

<svg width="218.4mm" height="58.397mm" version="1.1" viewBox="0 0 218.4 58.397" xmlns="http://www.w3.org/2000/svg" xmlns:ns0="http://www.iki.fi/pav/software/textext/">
 <g transform="translate(-55.09 -25.751)">
  <g transform="matrix(.45332 0 0 -.45332 -10.894 340.12)" fill-rule="evenodd" stroke="#000" stroke-miterlimit="10.433" stroke-width="3.309" ns0:preamble="default_packages.tex" ns0:text="col.1 col.2 col.3 col.A col.B\n" xml:space="preserve"><g transform="matrix(.8757 0 0 .8757 216.95 73.166)" fill-rule="evenodd" stroke-miterlimit="10.433" stroke-width="5.6679" ns0:preamble="default_packages.tex" ns0:text="XY\n" xml:space="preserve"><g fill="none" stroke="#dcdcdc" stroke-miterlimit="4" stroke-width="2.6828"><g stroke-linecap="square" stroke-linejoin="round"><rect transform="scale(1,-1)" x="-80.178" y="-707.02" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="-80.178" y="-682.78" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="-80.178" y="-658.54" width="144.5" height="24.238"/><rect transform="scale(1,-1)" x="-80.178" y="-634.3" width="144.5" height="24.238"/></g><path d="m35.164 707.47v-96.406"/></g><g font-family="'Courier New'" font-weight="bold" letter-spacing="0px" stroke="none" stroke-width=".66651" word-spacing="0
 </g>
</svg>

# %%
# outer join = union
merge = pd.merge(df6, df7, how='outer')

draw_tbl([[{'text':"outer join = union", 'colspan':3}],
          ['df6', "df7", "pd.merge(df6, df7, how='outer')"],
          [pandas_to_html(df6), pandas_to_html(df7), pandas_to_html(merge)]])

# %% [markdown]
# ##Overlapping Column Names: The suffixes Keyword

# %%
# note 'rank' is conflicting!
df8 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'rank': [1, 2, 3, 4]})
df9 = pd.DataFrame({'name': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'rank': [3, 1, 4, 2]})
merge = pd.merge(df8, df9, on="name")
merge_suff = pd.merge(df8, df9, on="name", suffixes=["_L", "_R"])

draw_tbl([[{'text':"note 'rank' is conflicting!", 'colspan':4}],
          ['df1a', "df3", "pd.merge(df8, df9, on='name')", "pd.merge(df8, df9, on='name', suffixes=['_L', '_R']) # control suffixes 'by hands'"],
          [pandas_to_html(df8), pandas_to_html(df9), pandas_to_html(merge), pandas_to_html(merge_suff)]])

# %% [markdown]
# #Aggregation and Grouping

# %% [markdown]
# ##Simple Aggregation in Pandas

# %% [markdown]
# | Aggregation              | Description                     |
# |--------------------------|---------------------------------|
# | ``count()``              | Total number of items           |
# | ``first()``, ``last()``  | First and last item             |
# | ``mean()``, ``median()`` | Mean and median                 |
# | ``min()``, ``max()``     | Minimum and maximum             |
# | ``std()``, ``var()``     | Standard deviation and variance |
# | ``mad()``                | Mean absolute deviation         |
# | ``prod()``               | Product of all items            |
# | ``sum()``                | Sum of all items                |

# %%
import numpy as np

rng = np.random.RandomState(42)
ser = pd.Series(rng.rand(5))

draw_tbl([['ser', "ser.sum()", "ser.mean()"],
          [pandas_to_html(ser), ser.sum(), ser.mean()]])

# %%
df = pd.DataFrame({'A': rng.rand(5), 'B': rng.rand(5)})

draw_tbl([['df', "df.mean()", "df.mean(axis='columns')"],
          [pandas_to_html(df), pandas_to_html(df.mean()), pandas_to_html(df.mean(axis='columns'))]])

# %%
import seaborn as sns

planets = sns.load_dataset('planets')
display_pandas(planets, ordering=True)

# few common aggregates at once
summary = planets.dropna().describe()
print('SUMMARY:')
display_pandas(summary)

# %% [markdown]
# ##GroupBy: Split, Apply, Combine

# %% [markdown]
# ![suport points](https://raw.githubusercontent.com/fbeilstein/machine_learning/master/lecture_04_pandas/split_apply_combine.png)

# %% [markdown]
# * The split step involves breaking up and grouping a DataFrame depending on the
# value of the specified key.
# * The apply step involves computing some function, usually an aggregate, transfor‐
# mation, or filtering, within the individual groups.
# * The combine step merges the results of these operations into an output array.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'], 'data': range(6)}, columns=['key', 'data'])

split = df.groupby('key')
apply_combine1 = split.sum()
apply_combine2 = split.std()


draw_tbl([['df', "df.groupby('key').sum()", "df.groupby('key').std()"],
          [pandas_to_html(df), pandas_to_html(apply_combine1), pandas_to_html(apply_combine2)]])

# %%
# no actual computation occurs
# this is only intermittent object for lazy evaluation
df.groupby('key')

# %%
planets.groupby('method')

# %%
planets.groupby('method')['orbital_period']

# %%
import seaborn as sns

planets = sns.load_dataset('planets')

split = planets.groupby('method')
apply_combine_1 = split['orbital_period']
apply_combine_2 = apply_combine_1.median()

display_pandas(apply_combine_2)

# %%
# Iteration over groups
for (method, group) in planets.groupby('method'):
  print("{0:30s} shape={1}".format(method, group.shape))

# %%
# Dispatch methods (method not explicitly implemented by the GroupBy object will be passed through and called on the groups)
planets.groupby('method')['year'].describe().unstack()

split = planets.groupby('method')
apply_combine_1 = split['year']
apply_combine_2 = apply_combine_1.describe()
apply_combine_3 = apply_combine_2.unstack()

display_pandas(apply_combine_3)

# %%
import numpy as np
import pandas as pd

rng = np.random.RandomState(0)
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data1': range(6),
                   'data2': rng.randint(0, 10, 6)},
columns = ['key', 'data1', 'data2'])

# Aggregation
split = df.groupby('key')
aggregate = split.aggregate(['min', np.median, max])
aggregate2 = split.aggregate({'data1': 'min', 'data2': 'max'})

draw_tbl([['df', "<div style='width:500px;'>df.groupby('key').aggregate(['min', np.median, max])</div>", "df.groupby('key').aggregate({'data1': 'min', 'data2': 'max'})"],
          [pandas_to_html(df), pandas_to_html(aggregate), pandas_to_html(aggregate2)]])

# %%
# Filtering
def filter_func(x):
  return x['data2'].std() > 4

filtered = df.groupby('key').filter(filter_func)

draw_tbl([['df', "df.groupby('key').filter(filter_func) # filtering"],
          [pandas_to_html(df), pandas_to_html(filtered)]])

# %%
# Transformation
transformed = df.groupby('key').transform(lambda x: x - x.mean())

draw_tbl([['df', "df.groupby('key').transform(lambda x: x - x.mean()) # transformation"],
          [pandas_to_html(df), pandas_to_html(transformed)]])

# %%
# The apply() method
def norm_by_data2(x):
  # x is a DataFrame of group values
  x['data1'] /= x['data2'].sum()
  return x

transformed = df.groupby('key').apply(norm_by_data2)

draw_tbl([['df', "df.groupby('key').apply(norm_by_data2) # transformation"],
          [pandas_to_html(df), pandas_to_html(transformed)]])

# %%
# Specifying the split key as A list, array, series, or index providing the grouping keys
L = [0, 1, 0, 1, 2, 0]

process = df.groupby(L).sum()

for_view = pd.Series(L)

draw_tbl([['df', "L # shown as series", "df.groupby(L).sum()"],
          [pandas_to_html(df), pandas_to_html(for_view), pandas_to_html(process)]])

# %%
# Specifying the split key as A dictionary or series mapping index to group
df2 = df.set_index('key')
mapping = {'A': 'vowel', 
           'B': 'consonant', 
           'C': 'consonant'}

split = df2.groupby(mapping)
process = split.sum()

draw_tbl([['df2', "df2.groupby(mapping).sum()"],
          [pandas_to_html(df2), pandas_to_html(process)]])

# %%
# Specifying the split key as Any Python function
split = df2.groupby(str.lower)
process = split.mean()

draw_tbl([['df2', "df2.groupby(mapping).sum()"],
          [pandas_to_html(df2), pandas_to_html(process)]])

# %%
# Specifying the split key as A list of valid keys

split = df2.groupby([str.lower, mapping])
process = split.mean()

draw_tbl([['df2', "df2.groupby([str.lower, mapping]).sum()"],
          [pandas_to_html(df2), pandas_to_html(process)]])

# %% [markdown]
# #Pivot Tables

# %% [markdown]
# A pivot table is a table of statistics that summarizes the data of a more extensive table (such as from a database, spreadsheet, or business intelligence program). This summary might include sums, averages, or other statistics, which the pivot table groups together in a meaningful way.
#
# Pivot tables are a technique in data processing. They arrange and rearrange (or "pivot") statistics in order to draw attention to useful information.
#
# You may think of pivot tables as essentially a multidimensional version of GroupBy aggregation. That is, you split-apply-combine, but both the split and the combine happen across not a one-dimensional index, but across a two-dimensional grid.

# %% [markdown]
# ##Pivot Table Syntax

# %%
import numpy as np
import pandas as pd
import seaborn as sns

titanic = sns.load_dataset('titanic')

draw_tbl([['titanic dataset'], [pandas_to_html(titanic)]])

# %%
titanic_pivot1 = titanic.pivot_table('survived', index='sex', columns='class')
age = pd.cut(titanic['age'], [0, 18, 80]) # bin the age using the pd.cut function
titanic_pivot2 = titanic.pivot_table('survived', ['sex', age], 'class')
# compute total, add name for total
titanic_pivot5 = titanic.pivot_table('survived', index='sex', columns='class', margins=True, margins_name='people')

draw_tbl([["titanic.pivot_table('survived', index='sex', columns='class')", 
           "age = pd.cut(titanic['age'], [0, 18, 80])<br>titanic.pivot_table('survived', ['sex', age], 'class')", 
           "titanic.pivot_table('survived', index='sex', columns='class', margins=True, margins_name='people')"],
          [pandas_to_html(titanic_pivot1), pandas_to_html(titanic_pivot2), pandas_to_html(titanic_pivot5)]])

# %%
fare = pd.qcut(titanic['fare'], 2)
titanic_pivot3 = titanic.pivot_table('survived', ['sex', age], [fare, 'class'])
# find mean fare but sum the sirvivals
titanic_pivot4 = titanic.pivot_table(index='sex', columns='class', aggfunc={'survived':sum, 'fare':'mean'})


draw_tbl([["fare = pd.qcut(titanic['fare'], 2)')<br>titanic.pivot_table('survived', ['sex', age], [fare, 'class'])", 
           "titanic.pivot_table(index='sex', columns='class', aggfunc={'survived':sum, 'fare':'mean'})"],
          [pandas_to_html(titanic_pivot3), pandas_to_html(titanic_pivot4)]])

# %% [markdown]
# #Vectorized String Operations

# %% [markdown]
# Nearly all Python's built-in string methods are mirrored by a Pandas vectorized string method. Here is a list of Pandas ``str`` methods that mirror Python string methods:
#
# |             |                  |                  |                  |
# |-------------|------------------|------------------|------------------|
# |``len()``    | ``lower()``      | ``translate()``  | ``islower()``    |
# |``ljust()``  | ``upper()``      | ``startswith()`` | ``isupper()``    |
# |``rjust()``  | ``find()``       | ``endswith()``   | ``isnumeric()``  |
# |``center()`` | ``rfind()``      | ``isalnum()``    | ``isdecimal()``  |
# |``zfill()``  | ``index()``      | ``isalpha()``    | ``split()``      |
# |``strip()``  | ``rindex()``     | ``isdigit()``    | ``rsplit()``     |
# |``rstrip()`` | ``capitalize()`` | ``isspace()``    | ``partition()``  |
# |``lstrip()`` |  ``swapcase()``  |  ``istitle()``   | ``rpartition()`` |

# %% [markdown]
# In addition, there are several methods that accept regular expressions to examine the content of each string element, and follow some of the API conventions of Python's built-in ``re`` module:
#
# | Method | Description |
# |--------|-------------|
# | ``match()`` | Call ``re.match()`` on each element, returning a boolean. |
# | ``extract()`` | Call ``re.match()`` on each element, returning matched groups as strings.|
# | ``findall()`` | Call ``re.findall()`` on each element |
# | ``replace()`` | Replace occurrences of pattern with some other string|
# | ``contains()`` | Call ``re.search()`` on each element, returning a boolean |
# | ``count()`` | Count occurrences of pattern|
# | ``split()``   | Equivalent to ``str.split()``, but accepts regexps |
# | ``rsplit()`` | Equivalent to ``str.rsplit()``, but accepts regexps |

# %% [markdown]
# Finally, there are some miscellaneous methods that enable other convenient operations:
#
# | Method | Description |
# |--------|-------------|
# | ``get()`` | Index each element |
# | ``slice()`` | Slice each element|
# | ``slice_replace()`` | Replace slice in each element with passed value|
# | ``cat()``      | Concatenate strings|
# | ``repeat()`` | Repeat values |
# | ``normalize()`` | Return Unicode form of string |
# | ``pad()`` | Add whitespace to left, right, or both sides of strings|
# | ``wrap()`` | Split long strings into lines with length less than a given width|
# | ``join()`` | Join strings in each element of the Series with passed separator|
# | ``get_dummies()`` | extract dummy variables as a dataframe |

# %% [markdown]
# ##Pandas String Methods

# %%
# Pandas contains vectorized string operations and correctly handles missing data
import pandas as pd

data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
names = pd.Series(data)

draw_tbl([["names",
           "names.str.capitalize()"],
          [pandas_to_html(names), 
           pandas_to_html(names.str.capitalize())]])

# %%
import numpy as np
import pandas as pd

monte = pd.Series(['Graham Chapman', 'John Cleese', 'Terry Gilliam',
                   'Eric Idle', 'Terry Jones', 'Michael Palin'])

draw_tbl([["monte",
           "monte.str.lower()",
           "monte.str.len()",
           "monte.str.startswith('T')",
           "monte.str.split()",
           "monte.str.extract('([A-Za-z]+)')",
           "monte.str.findall(r'^[^AEIOU].*[^aeiou]$')",
           "monte.str[0:3]",
           "monte.str.split().str.get(-1)"],
          [pandas_to_html(monte), 
           pandas_to_html(monte.str.lower()), 
           pandas_to_html(monte.str.len()), 
           pandas_to_html(monte.str.startswith('T')), 
           pandas_to_html(monte.str.split()), 
           pandas_to_html(monte.str.extract('([A-Za-z]+)')),
           pandas_to_html(monte.str.findall(r'^[^AEIOU].*[^aeiou]$')),
           pandas_to_html(monte.str[0:3]),
           pandas_to_html(monte.str.split().str.get(-1))]])

# %%
# indicator variables
# A = "born in America," B = "born in the United Kingdom,"
# C = "likes cheese,"    D = "likes spam"
full_monte = pd.DataFrame({'name': monte,
                           'info': ['B|C|D', 'B|D', 'A|C', 'B|D', 'B|C', 'B|C|D']})
full_monte

draw_tbl([["full_monte",
           "full_monte['info'].str.get_dummies('|')"],
          [pandas_to_html(full_monte), 
           pandas_to_html(full_monte['info'].str.get_dummies('|'))]])

# %% [markdown]
# #Working with Time Series

# %% [markdown]
# |Code    | Meaning     | Time span (relative) | Time span (absolute)   |
# |--------|-------------|----------------------|------------------------|
# | ``Y``  | Year	       | ± 9.2e18 years       | [9.2e18 BC, 9.2e18 AD] |
# | ``M``  | Month       | ± 7.6e17 years       | [7.6e17 BC, 7.6e17 AD] |
# | ``W``  | Week	       | ± 1.7e17 years       | [1.7e17 BC, 1.7e17 AD] |
# | ``D``  | Day         | ± 2.5e16 years       | [2.5e16 BC, 2.5e16 AD] |
# | ``h``  | Hour        | ± 1.0e15 years       | [1.0e15 BC, 1.0e15 AD] |
# | ``m``  | Minute      | ± 1.7e13 years       | [1.7e13 BC, 1.7e13 AD] |
# | ``s``  | Second      | ± 2.9e12 years       | [ 2.9e9 BC, 2.9e9 AD]  |
# | ``ms`` | Millisecond | ± 2.9e9 years        | [ 2.9e6 BC, 2.9e6 AD]  |
# | ``us`` | Microsecond | ± 2.9e6 years        | [290301 BC, 294241 AD] |
# | ``ns`` | Nanosecond  | ± 292 years          | [ 1678 AD, 2262 AD]    |
# | ``ps`` | Picosecond  | ± 106 days           | [ 1969 AD, 1970 AD]    |
# | ``fs`` | Femtosecond | ± 2.6 hours          | [ 1969 AD, 1970 AD]    |
# | ``as`` | Attosecond  | ± 9.2 seconds        | [ 1969 AD, 1970 AD]    |

# %% [markdown]
# **Frequencies and offsets**
#
# | Code   | Description         | Code   | Description          |
# |--------|---------------------|--------|----------------------|
# | ``D``  | Calendar day        | ``B``  | Business day         |
# | ``W``  | Weekly              |        |                      |
# | ``M``  | Month end           | ``BM`` | Business month end   |
# | ``Q``  | Quarter end         | ``BQ`` | Business quarter end |
# | ``A``  | Year end            | ``BA`` | Business year end    |
# | ``H``  | Hours               | ``BH`` | Business hours       |
# | ``T``  | Minutes             |        |                      |
# | ``S``  | Seconds             |        |                      |
# | ``L``  | Milliseonds         |        |                      |
# | ``U``  | Microseconds        |        |                      |
# | ``N``  | nanoseconds         |        |                      |
#
#
# by adding suffix ``S`` we mark any of these as a beginning
#
# | Code    | Description            || Code    | Description            |
# |---------|------------------------||---------|------------------------|
# | ``MS``  | Month start            ||``BMS``  | Business month start   |
# | ``QS``  | Quarter start          ||``BQS``  | Business quarter start |
# | ``AS``  | Year start             ||``BAS``  | Business year start    |

# %% [markdown]
# ##Dates and Times in Python

# %%
from datetime import datetime
datetime(year=2015, month=7, day=4)

# %%
from dateutil import parser
# parses many formats
date = parser.parse("4th of July, 2015")
date

# %%
date.strftime('%A')

# %%
import numpy as np
# numpy datetime, input format fixed!
date = np.array('2015-07-04', dtype=np.datetime64)
date

# %%
date + np.arange(12)

# %%
# day-based
np.datetime64('2015-07-04')

# %%
# minute-based
np.datetime64('2015-07-04 12:00')

# %%
# nanosecond-based
np.datetime64('2015-07-04 12:59:59.50', 'ns')

# %%
import pandas as pd
# pandas can parse
date = pd.to_datetime("4th of July, 2015")
date

# %%
date.strftime('%A')

# %%
# pandas can use numpy-style operations
date + pd.to_timedelta(np.arange(12), 'D')

# %% [markdown]
# ##Pandas Time Series: Indexing by Time

# %%
index = pd.DatetimeIndex(['2014-07-04', '2014-08-04', '2015-07-04', '2015-08-04'])
data = pd.Series([0, 1, 2, 3], index=index)

draw_tbl([["data", "data['2014-07-04':'2015-07-04']", "data['2015']"],
          [pandas_to_html(data), 
           pandas_to_html(data['2014-07-04':'2015-07-04']),
           pandas_to_html(data['2015'])]])

# %% [markdown]
# ##Pandas Time Series Data Structures

# %%
import pandas as pd

dates = pd.to_datetime([datetime(2015, 7, 3), '4th of July, 2015',
'2015-Jul-6', '07-07-2015', '20150708'])
dates

# %%
dates.to_period('D')

# %%
dates - dates[0]

# %%
# generate ranges
pd.date_range('2015-07-03', '2015-07-10')

# %%
pd.date_range('2015-07-03', periods=8)

# %%
pd.date_range('2015-07-03', periods=8, freq='H')

# %%
pd.period_range('2015-07', periods=8, freq='M')

# %%
pd.timedelta_range(0, periods=10, freq='H')

# %% [markdown]
# ##Frequencies and Offsets

# %%
pd.timedelta_range(0, periods=9, freq="2H30T")

# %%
from pandas.tseries.offsets import BDay
pd.date_range('2015-07-01', periods=5, freq=BDay())

# %% [markdown]
# #High-Performance Pandas: eval() and query()

# %% [markdown]
# ##Motivating query() and eval(): Compound Expressions

# %%
import numpy as np
rng = np.random.RandomState(42)
x = rng.rand(10**6)
y = rng.rand(10**6)
# %timeit x + y

# %%
# %timeit np.fromiter((xi + yi for xi, yi in zip(x, y)), dtype=x.dtype, count=len(x))

# %%
# every intermediate step is explicitly allocated in memory!
# %timeit (x > 0.5) & (y < 0.5)

# %%
tmp1 = (x > 0.5)
tmp2 = (y < 0.5)

# %timeit tmp1 & tmp2

# %%
mask = (x > 0.5) & (y < 0.5)

import numexpr
mask_numexpr = numexpr.evaluate('(x > 0.5) & (y < 0.5)')
np.allclose(mask, mask_numexpr)

# %%
# %timeit numexpr.evaluate('(x > 0.5) & (y < 0.5)')

# %% [markdown]
# ##pandas.eval() for Efficient Operations

# %%
import pandas as pd
nrows, ncols = 100000, 100
rng = np.random.RandomState(42)
df1, df2, df3, df4 = (pd.DataFrame(rng.rand(nrows, ncols)) for i in range(4))

# %%
# %timeit df1 + df2 + df3 + df4

# %%
# %timeit pd.eval('df1 + df2 + df3 + df4')

# %%
np.allclose(df1 + df2 + df3 + df4, pd.eval('df1 + df2 + df3 + df4'))

# %%
# Arithmetic operators
df1, df2, df3, df4, df5 = (pd.DataFrame(rng.randint(0, 1000, (100, 3))) for i in range(5))
result1 = -df1 * df2 / (df3 + df4) - df5
result2 = pd.eval('-df1 * df2 / (df3 + df4) - df5')
np.allclose(result1, result2)

# %%
# Comparison operators
result1 = (df1 < df2) & (df2 <= df3) & (df3 != df4)
result2 = pd.eval('df1 < df2 <= df3 != df4')
np.allclose(result1, result2)

# %%
# Bitwise operators
result1 = (df1 < 0.5) & (df2 < 0.5) | (df3 < df4)
result2 = pd.eval('(df1 < 0.5) & (df2 < 0.5) | (df3 < df4)')
np.allclose(result1, result2)

# %%
result3 = pd.eval('(df1 < 0.5) and (df2 < 0.5) or (df3 < df4)')
np.allclose(result1, result3)

# %%
# Object attributes and indices
result1 = df2.T[0] + df3.iloc[1]
result2 = pd.eval('df2.T[0] + df3.iloc[1]')
np.allclose(result1, result2)

# %% [markdown]
# ##DataFrame.eval() for Column-Wise Operations

# %%
import pandas as pd
import numpy as np

rng = np.random.RandomState(0)
df = pd.DataFrame(rng.rand(1000, 3), columns=['A', 'B', 'C'])
df.head()

# %%
result1 = (df['A'] + df['B']) / (df['C'] - 1)
result2 = pd.eval("(df.A + df.B) / (df.C - 1)")
np.allclose(result1, result2)

# %%
result3 = df.eval('(A + B) / (C - 1)')
np.allclose(result1, result3)

# %%
df.head()

# %%
# new column added
df.eval('D = (A + B) / C', inplace=True)
df.head()

# %%
# column D modified
df.eval('D = (A - B) / C', inplace=True)
df.head()

# %%
# work with local Python variables
column_mean = df.mean(1)
result1 = df['A'] + column_mean
result2 = df.eval('A + @column_mean')
np.allclose(result1, result2)
# NOTE: @ works only for DataFrame.eval(), not pandas.eval() !

# %% [markdown]
# ##DataFrame.query() Method

# %%
result1 = df[(df.A < 0.5) & (df.B < 0.5)]
result2 = pd.eval('df[(df.A < 0.5) & (df.B < 0.5)]')
np.allclose(result1, result2)

# %%
# NOTE: cannot be expressed through DataFrame.eval()
#       but DataFrame.query() saves the day
result2 = df.query('A < 0.5 and B < 0.5')
np.allclose(result1, result2)

# %%
Cmean = df['C'].mean()
result1 = df[(df.A < Cmean) & (df.B < Cmean)]
result2 = df.query('A < @Cmean and B < @Cmean')
np.allclose(result1, result2)

# %% [markdown]
# ##Performance: When to Use These Functions

# %%
# LARGE DataFrames - use eval()
# small DataFrames - use traditional syntax
# LARGE or small in terms of L1/L2 cache size and size of tmp objects
# check size as
df.values.nbytes
