# %% [markdown]
# > Игорь Сорочан DSU-31
# # Домашнее задание `"Центральная предельная теорема и статистика"`

# %% [markdown]
# ## Задание.

# %% [markdown]
# В этом задании нужно убедиться, что ЦПТ действительно работает.
#
# Создайте случайную величину из [любого выбранного вами распределения](https://docs.scipy.org/doc/scipy/reference/stats.html), для разных значений `n` сгенерируйте 1000 выборок размера `n`. Постройте гистрограммы средних этих выборок и сделайте выводы.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### `Continuous distributions in statistics`
# ![](https://bernard-mlab.com/images/common-distribution_huec055ab3bd48482f92384431f8f73d3e_75898_900x500_fit_box_2.png)

# %% [markdown]
# Let's choose highly skewed distribution, for example Log Normal.

# %%
loc, scale, s = 50, 10, 0.8
# rv = sts.norm(loc=loc, scale=scale)### YOUR CODE HERE
rv = sts.lognorm(s, scale=scale)
sample = rv.rvs(size=1000)

# %% [markdown]
# ### `Visualization of distribution`

# %%
x = np.linspace(0,80,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=100, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.9, linewidth = 1, color = "r")
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
sample.mean()
# Out:
# 13.690284877543458

# %%
n1 = [2, 20, 100, 500 ]        
list_=[]

samples_count = 10000  
for k in range(len(n1)):
    a1 = np.array([])  
    for number in range(samples_count): 

        sample1 = rv.rvs(size=n1[k])             
        a1 = np.append(a1, sample1.mean())   
    list_.append(a1)

# %%
fig, ax = plt.subplots(figsize=(10,6))
for k in range(len(n1)):
    label_1 = 'sample of ' + str(n1[k]) + ' histogram' 

    sns.histplot(list_[k],  bins= 50, label=label_1, edgecolor=(1, 1, 1, .4))  
      
plt.axvline(x= sample.mean(), color="b")

plt.legend() 
plt.ylabel('samples means')
plt.xlabel('$x$')
plt.show()

# %% [markdown]
#  ##### `The larger the sample size of a given distribution `
# ```
# * the more normal is the distribution of the sample mean
# * and the less is standard deviation of a sample means
# ```

# %%
# #           loc=mean, scale= std dev
# norm_dist1 = sts.norm(loc=50, scale=10)  # instance of rv_continuous - continuous distribution object
# norm_dist2 = sts.norm(loc=30, scale=10)

# sample1 = norm_dist1.rvs(size=1000) # sample from distribution
# sample2 = norm_dist2.rvs(size=1000)
# xx = np.linspace(0, 9, 1000)

# sns.histplot([sample1, sample2], bins=30, alpha=.5, kde= True, line_kws=dict(linewidth = 3), edgecolor=(1, 1, 1, .4))
# plt.show()
