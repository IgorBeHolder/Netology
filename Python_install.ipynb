# %% [markdown]
# [Installing Python packages in Jupyter Notebooks GitHub](https://github.com/microsoft/vscode-jupyter/wiki/Installing-Python-packages-in-Jupyter-Notebooks)
#
# [Installing Python Packages from a Jupyter Notebook](https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/)
# <h4><code>!pip install</code> vs <code>%pip install</code></h4>
# <p>Any command prefixed with <code>!</code> is treated as a shell command in Jupyter cells. Thus <code>!pip install &lt;module&gt;</code> is treated as a simple shell command that translates to <code>pip install &lt;module&gt;</code>. However the recommendation is to use <code>python -m pip install &lt;module&gt;</code><h4>
#
# To get this desired behavior one must use
# ## <code>%pip install &lt;module&gt;</code></p>
# <h4><code>%conda install</code><h4>
# <p>However when installing packages in Jupyter into a conda environment,
# use of <code>conda install</code> is preferred over <code>pip install</code>. Hence its highly recommended that one use <code>%conda install</code> in jupyter notebooks when dealing with Conda enviornments.</p>
#
# the shell environment in Jupyter notebook matches the Python version used to launch the notebook.

# %%
# !which python
# Out:
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/bin/python

# %%
# !type python  # what is actually executed when you type python in the command line
# !type ls      # his is true of any command you use from the terminal
# !type type    # Even built-in commands like type itself
# !type -a python # -a flag to see optionally all available versions of the command in your current shell environment
# !type -a conda
# Out:
# python is /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/bin/python
# ls is /bin/ls
# type is a shell builtin
# python is /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/bin/python
# python is /Users/velo1/opt/anaconda3/bin/python
# conda is /Users/velo1/opt/anaconda3/bin/conda
# conda is /Users/velo1/opt/anaconda3/condabin/conda

# %%
import sys
sys.path  # The list of paths searched by Python on import is found in sys.path
# Out:
# ['/Users/velo1/SynologyDrive/GIT_syno/Mac/Netology',
#  '/Library/Frameworks/Python.framework/Versions/3.11/lib/python311.zip',
#  '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11',
#  '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload',
#  '',
#  '/Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/lib/python3.11/site-packages']

# %%
import numpy
numpy.__path__  # You can find out which location has been used using the __path__ attribute of an imported module
# Out:
# ['/Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/lib/python3.11/site-packages/numpy']

# %%
'''each Python executable has its own site-packages: 
what this means is that when you install a package, it is associated with particular python executable 
and by default can only be used with that Python installation!
We can see this by printing the sys.path variables for each of the available python executables in my path, 
using Jupyter's delightful ability to mix Python and bash commands in a single code block:'''
paths = !type -a python
for path in set(paths):
    path = path.split()[-1] # get the last word
    print(path)
    # !{path} -c "import sys; print(sys.path)"
    print()
# Out:
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/bin/python
# ['', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python311.zip', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11', '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload', '/Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/lib/python3.11/site-packages']
#
# /Users/velo1/opt/anaconda3/bin/python
# ['', '/Users/velo1/opt/anaconda3/lib/python39.zip', '/Users/velo1/opt/anaconda3/lib/python3.9', '/Users/velo1/opt/anaconda3/lib/python3.9/lib-dynload', '/Users/velo1/opt/anaconda3/lib/python3.9/site-packages', '/Users/velo1/opt/anaconda3/lib/python3.9/site-packages/aeosa']

# %%
# To see the kernels you have available on your system, you can run the following command in the shell:
# !jupyter kernelspec list
# Out:
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Available kernels:
#   python3    /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/share/jupyter/kernels/python3

# %%
# The Python executable being used in the notebook can be determined using
sys.executable
# Out:
# '/Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/bin/python'

# %%
#  to automatically use the correct executable (again using notebook shell syntax):
# !{sys.executable} -m pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.24.3-cp311-cp311-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 1.7 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: numpy
# Successfully installed numpy-1.24.3

# %% [markdown]
# When you run `pip install` or `conda install`, these commands are associated with a particular Python version:
#
# * pip installs packages in the Python in its same path
# * conda installs packages in the current active conda environment

# %%
# %pip install pandas
# %conda install in jupyter notebooks when dealing with Conda enviornments.

# %%
# %%bash
# echo "hello from $BASH"
# Out:
# hello from /bin/bash

# %%
# %%writefile foo.py
print('Hello world')
# Out:
# Overwriting foo.py

# %%
# %run foo
# Out:
# Hello world

# %%
# !python --version
# Out:
# Python 3.11.3

# %%
# dir(__builtin__)

# %%
# ? print

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ### upgrade Python

# %%
# !python --version
# Out:
# Python 3.11.3

# %%
import sys      
sys.executable  # The Python executable being used in the notebook
# Out:
# '/Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/.venv/bin/python'

# %%
# !{sys.executable} -m pip install --upgrade pip    # upgrade pip
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.11/site-packages (23.1.2)

# %% [markdown]
# ### import python packages

# %%
soft_list = {'pandas': 'pd', 'numpy': 'np'}             # list of packages to import
for  package in soft_list.keys():                       # loop over the list
    exec(f'import {package} as {soft_list[package]}')   # import the package
    print(f'{package} imported as {soft_list[package]}  version: {eval(soft_list[package]).__version__}')
# Out:
# pandas imported as pd  version: 2.0.1
# numpy imported as np  version: 1.24.3

# %%
import sys
soft_list = ['pandas',
             'numpy',
             'matplotlib',
             'plotly.express',
             'seaborn',
             'pymorphy2',
             'scikit-learn',
             'scipy',
             'nltk',
             'gensim',
             'torch'
             ]

for k in soft_list:
    # !{sys.executable} -m pip install {k}
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./.venv/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.11/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in ./.venv/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./.venv/lib/python3.11/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: plotly.express in ./.venv/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in ./.venv/lib/python3.11/site-packages (from plotly.express) (2.0.1)
# Requirement already satisfied: plotly>=4.1.0 in ./.venv/lib/python3.11/site-packages (from plotly.express) (5.14.1)
# Requirement already satisfied: statsmodels>=0.9.0 in ./.venv/lib/python3.11/site-packages (from plotly.express) (0.13.5)
# Requirement already satisfied: scipy>=0.18 in ./.venv/lib/python3.11/site-packages (from plotly.express) (1.10.1)
# Requirement already satisfied: patsy>=0.5 in ./.venv/lib/python3.11/site-packages (from plotly.express) (0.5.3)
# Requirement already satisfied: numpy>=1.11 in ./.venv/lib/python3.11/site-packages (from plotly.express) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas>=0.20.0->plotly.express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas>=0.20.0->plotly.express) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.11/site-packages (from pandas>=0.20.0->plotly.express) (2023.3)
# Requirement already satisfied: six in ./.venv/lib/python3.11/site-packages (from patsy>=0.5->plotly.express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in ./.venv/lib/python3.11/site-packages (from plotly>=4.1.0->plotly.express) (8.2.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.11/site-packages (from plotly>=4.1.0->plotly.express) (23.1)
# Requirement already satisfied: seaborn in ./.venv/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in ./.venv/lib/python3.11/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in ./.venv/lib/python3.11/site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in ./.venv/lib/python3.11/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./.venv/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: pymorphy2 in ./.venv/lib/python3.11/site-packages (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in ./.venv/lib/python3.11/site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in ./.venv/lib/python3.11/site-packages (from pymorphy2) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in ./.venv/lib/python3.11/site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy in ./.venv/lib/python3.11/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in ./.venv/lib/python3.11/site-packages (from scipy) (1.24.3)
# Requirement already satisfied: nltk in ./.venv/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in ./.venv/lib/python3.11/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.11/site-packages (from nltk) (2023.3.23)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.11/site-packages (from nltk) (4.65.0)
# Requirement already satisfied: gensim in ./.venv/lib/python3.11/site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in ./.venv/lib/python3.11/site-packages (from gensim) (1.24.3)
# Requirement already satisfied: scipy>=1.7.0 in ./.venv/lib/python3.11/site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in ./.venv/lib/python3.11/site-packages (from gensim) (6.3.0)
# Collecting torch
#   Downloading torch-2.0.0-cp311-none-macosx_10_9_x86_64.whl (139.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 MB 1.6 MB/s eta 0:00:0000:0100:02
# Collecting filelock (from torch)
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting typing-extensions (from torch)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting sympy (from torch)
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 1.6 MB/s eta 0:00:0000:0100:01
# Collecting networkx (from torch)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 980.7 kB/s eta 0:00:00:0100:010m
# Collecting jinja2 (from torch)
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached MarkupSafe-2.1.2-cp311-cp311-macosx_10_9_x86_64.whl (13 kB)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: mpmath, typing-extensions, sympy, networkx, MarkupSafe, filelock, jinja2, torch
# Successfully installed MarkupSafe-2.1.2 filelock-3.12.0 jinja2-3.1.2 mpmath-1.3.0 networkx-3.1 sympy-1.11.1 torch-2.0.0 typing-extensions-4.5.0
