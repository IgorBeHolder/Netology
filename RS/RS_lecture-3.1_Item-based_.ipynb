# %% [markdown]
# ## Item based collaborative filtering

# %%
import os

import pandas as pd
import numpy as np

# from tqdm import tqdm_notebook

# %%
os.chdir(path="/Users/velo1/SynologyDrive/GIT_syno/data/MovieLens _ml-latest-small")
os.getcwd()
links = pd.read_csv("links.csv")
movies = pd.read_csv("movies.csv")
ratings = pd.read_csv("ratings.csv")
tags = pd.read_csv("tags.csv")

# %%
movies.title.nunique()
# Out:
# 9123

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movies_with_ratings = movies.join(
    ratings.set_index("movieId"), on="movieId", how="left"
).reset_index(drop=True)

# %%
films_with_no_ratings = movies_with_ratings[movies_with_ratings['rating'].isna()]
films_with_no_ratings['title'], films_with_no_ratings.shape
# Out:
# (71460           Wild Child, The (Enfant sauvage, L') (1970)
#  71671                  Iron Ladies, The (Satree lek) (2000)
#  73986                                 Scarlet Street (1945)
#  74292                                  Body and Soul (1947)
#  77028                 Story of O, The (Histoire d'O) (1975)
#  77706                              Two-Lane Blacktop (1971)
#  78727                             You Only Live Once (1937)
#  79262                                           Fire (1996)
#  79692                                    Sudden Fear (1952)
#  81324     Intolerance: Love's Struggle Throughout the Ag...
#  81578                         Pickup on South Street (1953)
#  82648                          While the City Sleeps (1956)
#  83104                            Cincinnati Kid, The (1965)
#  83747                                    Black Angel (1946)
#  83748                                 Big Clock, The (1948)
#  84831                                  Stranger, The (1946)
#  86877                                        Berserk (1967)
#  87374     After School Special (a.k.a. Barely Legal) (2003)
#  87716                                  Kiss of Death (1947)
#  87785                          Late Spring (Banshun) (1949)
#  89185                              Facing the Giants (2006)
#  89520     When the Levees Broke: A Requiem in Four Acts ...
#  90936                                Lions For Lambs (2007)
#  90951                       Kansas City Confidential (1952)
#  95433                                      Nightfall (1957)
#  96916                                        Kahaani (2012)
#  97734                             Wish You Were Here (2012)
#  97890                                        Passion (2012)
#  98375                                Springsteen & I (2013)
#  98649                                    Rocket, The (2013)
#  98659                                          Belle (2013)
#  98660                                 Immigrant, The (2013)
#  98708                                 Love God?, The (1969)
#  98844                        White God (Fehér isten) (2014)
#  99022                                           1971 (2014)
#  99026                       White Bird in a Blizzard (2014)
#  99059                            Challenge to Lassie (1949)
#  99285                                          Selma (2014)
#  99486                         The Passionate Plumber (1932)
#  99487                          The Story on Page One (1959)
#  99505     Drunk Stoned Brilliant Dead: The Story of the ...
#  99523                 The Stanford Prison Experiment (2015)
#  99526                                 Stormy Weather (1943)
#  99596                                  Woman in Gold (2015)
#  99610                                 Monkey Kingdom (2015)
#  99615                                A Girl Like Her (2015)
#  99616                                        Grandma (2015)
#  99624                                  Welcome to Me (2014)
#  99802                                    The Gallows (2015)
#  99916                                       February (2015)
#  99946                                          Truth (2015)
#  100004                                The Neon Demon (2016)
#  100025                                The Handmaiden (2016)
#  100047                                         Nerve (2016)
#  100050                    Author: The JT LeRoy Story (2016)
#  100051                            Hell or High Water (2016)
#  100059                                 Shin Godzilla (2016)
#  100061                             The Gay Desperado (1936)
#  100062                                Women of '69, Unboxed
#  Name: title, dtype: object,
#  (59, 6))

# %%
movies_with_ratings.reset_index(drop=True)
movies_with_ratings.dropna(inplace=True)
movies_with_ratings.shape
# Out:
# (100004, 6)

# %%
films_no_rates = movies.title.nunique()-movies_with_ratings.groupby("title").size().shape[0]
films_no_rates
# Out:
# 59

# %%
movies_with_ratings.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating     timestamp
# 0     7.0     3.0  8.518667e+08
# 0     9.0     4.0  9.386292e+08
# 0    13.0     5.0  1.331380e+09
# 0    15.0     2.0  9.979383e+08
# 0    19.0     3.0  8.551901e+08

# %%
num_users = movies_with_ratings.userId.nunique()
num_users
# Out:
# 671

# %%
movie_vector = {}

for movie, group in movies_with_ratings.groupby("title"):
    # initialize the vector with zeros for each film title
    movie_vector[movie] = np.zeros(num_users)

    for i in range(len(group.userId.values)):
        # get the user index for each rating
        u = group.userId.values[i]  # user index
        r = group.rating.values[i]  # which rating user 'u' gave to movie 'title'
        movie_vector[movie][int(u - 1)] = r
movie_vector["Toy Story (1995)"].shape, len(movie_vector)
# Out:
# ((671,), 9064)

# %%
from scipy.spatial.distance import (
    cityblock,
    cosine,
    euclidean,
    hamming,
    jaccard,
    correlation,
)

# %%
movie_vector.keys()
# Out:
# dict_keys(['"Great Performances" Cats (1998)', '$9.99 (2008)', "'Hellboy': The Seeds of Creation (2004)", "'Neath the Arizona Skies (1934)", "'Round Midnight (1986)", "'Salem's Lot (2004)", "'Til There Was You (1997)", "'burbs, The (1989)", "'night Mother (1986)", '(500) Days of Summer (2009)', '*batteries not included (1987)', '...And God Spoke (1993)', '...And Justice for All (1979)', '1-900 (06) (1994)', '10 (1979)', '10 Attitudes (2001)', '10 Cloverfield Lane (2016)', '10 Items or Less (2006)', '10 Things I Hate About You (1999)', '10 Years (2011)', '10,000 BC (2008)', '100 Girls (2000)', '100 Rifles (1969)', '101 Dalmatians (1996)', '101 Dalmatians (One Hundred and One Dalmatians) (1961)', '101 Reykjavik (101 Reykjavík) (2000)', '102 Dalmatians (2000)', '10th Kingdom, The (2000)', '11\'09"01 - September 11 (2002)', '11:14 (2003)', '12 Angry Men (1957)', '12 Angry Men (1997)', '12 Years a Slave (2013)', '127 Hours (2010)', '12:08 East of Bucharest (A fost sau n-a fost?) (2006)', '13 Assassins (Jûsan-nin no shikaku) (2010)', '13 Ghosts (1960)', '13 Going on 30 (2004)', '13 Tzameti (2005)', '13th Warrior, The (1999)', '1408 (2007)', '15 Minutes (2001)', '16 Blocks (2006)', '16 Wishes (2010)', '17 Again (2009)', '18 Again! (1988)', '187 (One Eight Seven) (1997)', '1941 (1979)', '1984 (1956)', '1984 (Nineteen Eighty-Four) (1984)', '1990: The Bronx Warriors (1990: I guerrieri del Bronx) (1982)', '2 Days in New York (2012)', '2 Days in the Valley (1996)', '2 Fast 2 Furious (Fast and the Furious 2, The) (2003)', '2 Guns (2013)', "2 ou 3 choses que je sais d'elle (2 or 3 Things I Know About Her) (1967)", '20 Dates (1998)', '20 Feet from Stardom (Twenty Feet from Stardom) (2013)', '20,000 Leagues Under the Sea (1916)', '20,000 Leagues Under the Sea (1954)', '200 Cigarettes (1999)', '200 Motels (1971)', '2001: A Space Odyssey (1968)', '2010: The Year We Make Contact (1984)', '2012 (2009)', '2046 (2004)', '21 (2008)', '21 Grams (2003)', '21 Jump Street (2012)', '21 Up (1977)', '22 Jump Street (2014)', '23 (23 - Nichts ist so wie es scheint) (1998)', '24 Hour Party People (2002)', '24 Hour Woman, The (1998)', '24: Redemption (2008)', '25 Watts (2001)', '25th Hour (2002)', '27 Dresses (2008)', '28 Days (2000)', '28 Days Later (2002)', '28 Up (1985)', '28 Weeks Later (2007)', '29th and Gay (2005)', '3 Extremes (Three... Extremes) (Saam gaang yi) (2004)', '3 Idiots (2009)', '3 Ninjas (1992)', '3 Ninjas Kick Back (1994)', '3 Ninjas Knuckle Up (1995)', '3 Ninjas: High Noon On Mega Mountain (1998)', '3 Women (Three Women) (1977)', '3 Worlds of Gulliver, The (1960)', '3-Day Weekend (2008)', '3-Iron (Bin-jip) (2004)', '30 Days of Night (2007)', '30 Minutes or Less (2011)', '30 Years to Life (2001)', '300 (2007)', '3000 Miles to Graceland (2001)', '300: Rise of an Empire (2014)', '35 Up (1991)', '36th Chamber of Shaolin, The (Shao Lin san shi liu fang) (Master Killer) (1978)', '39 Steps, The (1935)', '3:10 to Yuma (1957)', '3:10 to Yuma (2007)', '4 Little Girls (1997)', '4 Months, 3 Weeks and 2 Days (4 luni, 3 saptamâni si 2 zile) (2007)', '4 for Texas (1963)', '40 Days and 40 Nights (2002)', '40-Year-Old Virgin, The (2005)', '400 Blows, The (Les quatre cents coups) (1959)', '41-Year-Old Virgin Who Knocked Up Sarah Marshall and Felt Superbad About It, The (2010)', '42 (2013)', '42 Up (1998)', '42nd Street (1933)', '45 Years (2015)', '47 Ronin (2013)', '48 Hrs. (1982)', '49 Up (2005)', '49th Parallel (1941)', '5 Centimeters per Second (Byôsoku 5 senchimêtoru) (2007)', '5,000 Fingers of Dr. T, The (1953)', '50 First Dates (2004)', '50/50 (2011)', '52 Pick-Up (1986)', '54 (1998)', '56 Up (2012)', '5x2 (2004)', '61* (2001)', '6th Day, The (2000)', '6th Man, The (Sixth Man, The) (1997)', '7 Days (Les 7 jours du talion) (2010)', '7 Days in Hell (2015)', '7 Plus Seven (1970)', '71 Fragments of a Chronology of Chance (71 Fragmente einer Chronologie des Zufalls) (1994)', '7th Voyage of Sinbad, The (1958)', '8 1/2 (8½) (1963)', '8 Heads in a Duffel Bag  ...

# %%
my_fav_film = "Fight Club (1999)"

titles = []
distances = []

for key in movie_vector.keys():
    if key != my_fav_film:
        titles.append(key)
        distances.append(correlation(movie_vector[my_fav_film], movie_vector[key]))

best_indexes = np.argsort(distances)[:10]
best_movies = [(titles[i], distances[i]) for i in best_indexes]

for m in best_movies:
    print(m)
# Out:
# ('Memento (2000)', 0.44821852421045094)
# ('Snatch (2000)', 0.4688401152068321)
# ('Matrix, The (1999)', 0.5096430196723449)
# ('American History X (1998)', 0.5140028381513735)
# ('Kill Bill: Vol. 2 (2004)', 0.5279823271731231)
# ('Gladiator (2000)', 0.5395281806512061)
# ('Lord of the Rings: The Fellowship of the Ring, The (2001)', 0.5453568664049451)
# ('Sin City (2005)', 0.5467379177836235)
# ('Kill Bill: Vol. 1 (2003)', 0.5472630201338977)
# ('American Beauty (1999)', 0.5662768086371339)

# %%
my_fav_film = "Fight Club (1999)"

titles = []
distances = []

for key in movie_vector.keys():
    if key != my_fav_film:
        titles.append(key)
        distances.append(jaccard(movie_vector[my_fav_film], movie_vector[key]))

best_indexes = np.argsort(distances)[:10]
best_movies = [(titles[i], distances[i]) for i in best_indexes]

for m in best_movies:
    print(f"{m[0]:<60} jaccard: {m[1]:.3f}")
# Out:
# Matrix, The (1999)                                           jaccard: 0.816
# American Beauty (1999)                                       jaccard: 0.832
# Memento (2000)                                               jaccard: 0.850
# Dark Knight, The (2008)                                      jaccard: 0.852
# American History X (1998)                                    jaccard: 0.860
# Donnie Darko (2001)                                          jaccard: 0.867
# Lord of the Rings: The Fellowship of the Ring, The (2001)    jaccard: 0.869
# Pulp Fiction (1994)                                          jaccard: 0.869
# Gladiator (2000)                                             jaccard: 0.873
# Reservoir Dogs (1992)                                        jaccard: 0.878

# %%
my_fav_film = "Toy Story (1995)"

titles = []
distances = []

for key in movie_vector.keys():
    if key != my_fav_film:
        titles.append(key)
        distances.append(cosine(movie_vector[my_fav_film], movie_vector[key]))

best_indexes = np.argsort(distances)[:10]
best_movies = [(titles[i], distances[i]) for i in best_indexes]

for m in best_movies:
    print(f"{m[0]:<60} Cosine distance: {m[1]:.3f}")
    # print(m[0], f"\tCosine distance: {m[1]:.3f}")
# Out:
# Toy Story 2 (1999)                                           Cosine distance: 0.405
# Star Wars: Episode IV - A New Hope (1977)                    Cosine distance: 0.424
# Forrest Gump (1994)                                          Cosine distance: 0.435
# Independence Day (a.k.a. ID4) (1996)                         Cosine distance: 0.437
# Groundhog Day (1993)                                         Cosine distance: 0.452
# Back to the Future (1985)                                    Cosine distance: 0.463
# Jurassic Park (1993)                                         Cosine distance: 0.465
# Shrek (2001)                                                 Cosine distance: 0.467
# Star Wars: Episode VI - Return of the Jedi (1983)            Cosine distance: 0.471
# Pulp Fiction (1994)                                          Cosine distance: 0.473
