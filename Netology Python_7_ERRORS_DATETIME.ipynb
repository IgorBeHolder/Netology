# %% [markdown]
# # Задача про интервалы дат
# Имеется список отсортированных по возрастанию дат dates_list. А также дата date, которая лежит между минимальным и максимальным значениями из списка dates_list. Вам необходимо определить ближайшие даты в списке dates_list, которые окружают дату date.
#
# Пример:
# ```python
# dates_list = ['2022-01-01', '2022-01-07', '2022-02-23', '2022-03-08', '2022-05-01', '2022-05-09', '2022-06-12']
# date = '2022-04-01'
# ```

# %%
dates_list = ['2022-01-01', '2022-01-07', '2022-02-23', '2022-03-08', '2022-05-01', '2022-05-09', '2022-06-12']
dates_list
# Out:
# ['2022-01-01',
#  '2022-01-07',
#  '2022-02-23',
#  '2022-03-08',
#  '2022-05-01',
#  '2022-05-09',
#  '2022-06-12']

# %%
14.10.22

10.14.22

# %%
'logs_2022-04-01.csv'  # алфавитный порядок совпадает с календарным

# %%
date = '2022-04-01'  # 2022-04-01T19:07:30

# %%
'2022-03-31' < '2022-04-01'
# Out:
# True

# %%
# вариант 1

i = 0
for item in dates_list:
    print(item, dates_list[i+1])
    
    i += 1
# Out:
# 2022-01-01
# 2022-01-07
# 2022-02-23
# 2022-03-08
# 2022-05-01
# 2022-05-09
# 2022-06-12

# %%
for i in range(len(dates_list)):

# %%
date
# Out:
# '2022-04-01'

# %%
# %%time
# вариант 2

for i, item in enumerate(dates_list[:-1]):
    print(i, item, dates_list[i+1])
    
    if item < date < dates_list[i+1]:
        print('Нашлось', item, dates_list[i+1])
        break
# Out:
# 0 2022-01-01 2022-01-07
# 1 2022-01-07 2022-02-23
# 2 2022-02-23 2022-03-08
# 3 2022-03-08 2022-05-01
# Нашлось 2022-03-08 2022-05-01
# CPU times: user 477 µs, sys: 411 µs, total: 888 µs
# Wall time: 552 µs

# %% [markdown]
# # Обработка ошибок
# 1. Текст ошибки указывается в последней строчке
# 2. Все что перед ней - место, где ошибка произошла
# 3. Есть встроенные типы ошибок, но можно создавать и свои

# %% [markdown]
# Некоторые типы ошибок из документации (точнее [перевода](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html)):
# - ZeroDivisionError - деление на ноль
# - ImportError - не удалось импортирование модуля или его атрибута (надо установить эту библиотеку)
# - IndexError - индекс не входит в диапазон элементов.
# - KeyError - несуществующий ключ (в словаре, множестве или другом объекте)
# - MemoryError - недостаточно памяти
# - SyntaxError - синтаксическая ошибка (вы опечатались или не закрыли скобку)
# - TypeError - операция применена к объекту несоответствующего типа
# - ValueError - функция получает аргумент правильного типа, но некорректного значения
# - Warning - предупреждение (текст на красном фоне в юпитере это предупреждение, а не ошибка)

# %%
# эту строку можно перевести в число
some_num = '123'

# %%
float(some_num)

# %%
# а эту уже нет (по крайней мере в десятичном счислении)
ups = '123a'

# %%
# ValueError - тип ошибки, далее пояснение что произошло
# ----> 1 float(ups) - в каком месте кода произошла ошибка
float(ups)

# %% [markdown]
# Пример ошибки внутри функции

# %%
def square_sum(*args):
    total_sum = 0
    for arg in args:
        total_sum += arg**2
    
    return total_sum

# %%
square_sum(1, 2, 3)
# Out:
# 14

# %%
# пытаемся применить к операцию возведения в квадрат к строке
# ----> 1 square_sum(1, 2, '3') - в какой функции произошла ошибка
# ----> 4         total_sum += arg**2 - в какой именно строке произошла ошибка

square_sum(1, 2, '3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-7189647907b6> in <module>
#       3 # ----> 4         total_sum += arg**2 - в какой именно строке произошла ошибка
#       4
# ----> 5 square_sum(1, 2, '3')
#
# <ipython-input-16-45a18875b039> in square_sum(*args)
#       2     total_sum = 0
#       3     for arg in args:
# ----> 4         total_sum += arg**2
#       5
#       6     return total_sum
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# ### План-капкан
# 1. Берем последнюю строчку ошибки и переводим на русский. Ищем строчку кода, где ошибка возникла.
# 2. Поисковики - берем текст ошибки и отправляем в Яндекс/Гугл.
#
# 3. Обратиться к коллегам:
# - (на работе) Обязательно указывайте какую задачу вы изначально решаете (!!!)
# - Уточняйте что значат ваши переменные
# - Уточняйте что за данные вы используете
#
# 4. Воспроизводимый пример
# - Ошибка из-за неправильной последовательности выполнения ячеек.
# - Отправляем коллеге и у него ошибка воспроизводится (ура)
# - Ошибка не воспроизводится

# %%
try:
    # ваш код, где может произойти ошибка
    float('123a')

except:
    # код, который выполняется в случае ошибки

# %%
data = ['90', '60', '90', '240tot']
total_sum = 0

for num in data:
    try:
        total_sum += float(num)

    except:
        print('Ошибка в данных: {}'.format(num))
    
print('Итого', total_sum)

# %% [markdown]
# Как сохранить всю информацию об ошибке?

# %%
# полная версия traceback
import traceback

try:
    float('123fff')

except Exception:
    print(traceback.print_exc())
    
print('Проехали')

# %% [markdown]
# ### Блок finally

# %%
try:
    print(stats["wednesday"])
    
except IndexError:
    print("Ошибка индекса")
    
except KeyError:
    print("Ошибка ключа")
    print(1/0)
    
finally:
    print('Эта строчка будет выполнена всегда')

# %% [markdown]
# ### Более жизненный пример

# %%
from datetime import datetime

# %%
datetime(1, 1, 1)
# Out:
# datetime.datetime(1, 1, 1, 0, 0)

# %%
DATE_FORMATS = ['%d.%m.%y %H:%M', '%d.%m.%YT %H:%M:%S']

# %%
def parse_date(date):
    for date_format in DATE_FORMATS:
        try:
            return datetime.strptime(date, date_format)
        except:
            pass

    # не один формат не подошел
    # если нельзя не расшифровать дату
    raise ValueError(f'Неизвестный формат даты {date}')

# %%
parse_date('05.10.16 23:18')
# Out:
# datetime.datetime(2016, 10, 5, 23, 18)

# %%
parse_date('09.10.2016T 21:40:00')
# Out:
# datetime.datetime(2016, 10, 9, 21, 40)

# %%
parse_date('05.10.16Z23:18')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-a3b3a3b13ced> in <module>
# ----> 1 parse_date('05.10.16Z23:18')
#
# <ipython-input-44-d340eebacbac> in parse_date(date)
#       8     # не один формат не подошел
#       9     # если нельзя не расшифровать дату
# ---> 10     raise ValueError(f'Неизвестный формат даты {date}')
#
# ValueError: Неизвестный формат даты 05.10.16Z23:18

# %%
'20200101201930'

# %%
with open('real_data.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        
        if len(line) == 3:
            date, user_id, value = line
            
            print(date)
            date = parse_date(date)
# Out:
# 05.10.16 23:18
# 09.10.2016T 21:40:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-641ffd122192> in <module>
#       7
#       8             print(date)
# ----> 9             date = parse_date(date)
#
# <ipython-input-33-43e4155693c1> in parse_date(date)
#       1 def parse_date(date):
#       2     # 05.10.16 23:18
# ----> 3     return datetime.strptime(date, '%d.%m.%y %H:%M')
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '09.10.2016T 21:40:00' does not match format '%d.%m.%y %H:%M'

# %% [markdown]
# Чем прекрасен этот файл:
# 1. Даты имеют разный формат: за 8 и 9 октября формат с "09.10.2016 21:40" сменился на "09.10.2016T 21:40:00" (добавилась буква T и секунды). Разработчики объяснили этот тем, что сбились настройки после обновления одной из баз данных.
# 2. У покупок некоторых пользователей неизвестно значение выручки, из-за чего количество столбцов в строке уменьшается на один.
# 3. У некоторых строк реальная сумма покупки умножена на миллион. Так иногда действительно делают, чтобы избежать дробных чисел и работать только с целыми.

# %% [markdown]
# Необходимо посчитать сумму выручки из третьего столбца.

# %% [markdown]
# # Даты

# %%
# иногда импортируют так
import datetime

# %%
# можно и так
import datetime as dt

# %%
# у нас будет вариант покороче (но это не одно и то же)
from datetime import datetime

# %%
date_string = '09.05.2018  09:00'

# %%
# сейчас date_string это просто строка
type(date_string)

# %%
datetime.strptime('09.05.2018 09:00', '%d.%m.%Y %H:%M')

# %%
# https://docs.python.org/3/library/datetime.html

date_datetime = datetime.strptime( date_string, '%d.%m.%Y %H:%M' )
date_datetime

# %%
# теперь можем работать с датами
type(date_datetime)

# %%
# получить номер года и часа
date_datetime.year, date_datetime.hour

# %%
# день недели
date_datetime.weekday()

# %%
# сегодня
datetime.now()

# %% [markdown]
# ### Упражнение
# С помощью метода datetime.strptime переведите строку 'May 25 2017 5:00AM' в формат datetime.

# %% [markdown]
# ### Прибавление интервала к датам

# %%
from datetime import timedelta

# %%
start_date = '2018-01-01'
end_date = '2018-01-07'

# %%
type(start_date)

# %%
start_date_datetime = datetime.strptime(start_date, '%Y-%m-%d')
start_date_datetime

# %%
start_date_datetime + timedelta(days=1)

# %%
start_date_datetime + timedelta(days=-7, minutes=-1)

# %% [markdown]
# ### Перевод обратно в строку

# %%
date = datetime(2018, 9, 1)
date

# %%
date.strftime('%Y-%m-%d')

# %%
date.strftime('%B %d %Y %I:%M%p')

# %%
datetime.now().strftime('%Y-%m-01')

# %%
# как получить первый день месяца

date.strftime('%Y-%m-01')

# %%
start_date = '2018-01-01'
end_date = '2018-01-07'

# %%
start_date, end_date

# %%
start_date_dt = datetime.strptime(start_date, '%Y-%m-%d')
end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')

print(start_date_dt, end_date_dt)

# %%
i = 0

while i < 10:
    # ...
    i += 1
    print(i)

# %%
current_dt = start_date_dt

while current_dt <= end_date_dt:
    print(current_dt.strftime('%Y-%m-%d'))
    
    current_dt += timedelta(days=1)

# %%
current_dt = start_date_dt

while current_dt.strftime('%Y-%m-%d') <= end_date:
    print(current_dt.strftime('%Y-%m-%d'))
    
    current_dt += timedelta(days=1)

# %%
# можно и с помощью list comprehension
[(start_date_dt + timedelta(days=x)).strftime('%Y-%m-%d') for x in range(10)]

# %% [markdown]
# ### Нагрузка на систему по часам

# %%
stats = {}

with open('logs.csv', 'r') as f:
    for line in f:
        line = line.strip()
        print(line)
        
        break
        
        # вычисления нагрузки на систему...
        
# результат
stats

# %% [markdown]
# ###  Unixtime
# Количество секунд, прошедших с 1 января 1970 года по UTC

# %%
import time
from datetime import date
from datetime import datetime

# %%
d = date(2019, 3, 11)

unixtime = time.mktime(d.timetuple())
unixtime

# %%
from datetime import datetime

# %%
datetime.fromtimestamp(1552251600)

# %% [markdown]
# На практике все сложнее https://habr.com/ru/post/452584/
