# %% [markdown]
# # `Searching Notebooks for a Code Snippet`
# From September 2022 I started learning Python online.
# Until everything is settled in my head,
# I am faced with the need to search for my own code snippets among all this variety of information.
# This piece of code will help you look up your Python notebooks.
# It seems to me it's quicker than using a 'grep'.
# You can define a strict search logic or case sensetive one.
# Hope it helps.
# Enjoy)

# %%
from beholder import search_files_for_strings

# Example usage:
search_pattern = "*.ipynb"
search_strings = input("Input search strings separated by whitespace:").split()
results = search_files_for_strings(search_strings, search_pattern, case_sensitive_search=True )
for result in results:
    print(f"{result['file_path']}\nline:{result['line_number']}: {result['line_text']}")
# Out:
# Looking for: ['RNN'] in *.ipynb files
# Include all occurrences: False
# Case sensitive search: True
# Maximum line length to print: 100 characters
# File:          : Search result:
# ................................................................................
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Logres_affair.ipynb
# line:3374: RNN3sZClXIxspERERyD4UbZ7p6Ieb/Hr0nbY/Ev70Fl89AoUrQ5IXsr01ERCSXULjJAoF+N92OOvwnhM+wTT80Ebx8s70mERGR3E
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_A_B_testing_HW.ipynb
# line:928: RNN93UOmpJJA+lFI9+up7SUBQNGJ3WtcOMYWl4ojreiIE7qu/U6qKIt6REDEXUtIka8ctWy5fal8919V2wMWwN09aY3C+H5atqcF
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_A_B_testing_HW.ipynb
# line:1476: RNNknPrBZDP9JJvNpPg/+jKbSYlqJi4yjWOZqUQ01uCsLSemtoywtmYSq49B9TGqv3EDOSOmcHTMdE6kjuwIbgNVe09QNI2NjWfs
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_A_B_testing_HW.ipynb
# line:93699: RNNJoiSEj1NAthbkbjEyR3DEFEblGd1pcXoJPVwF9HDZSNaLZNZr0aI0f3+0625H/XsB6tMPUZdeAQ1Yk645WKuSoN4xgVzXPxqX
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_case_study_linreg_confidence_interval.ipynb
# line:1: RNNKjN0H4HgxbJcr69x3v7oxBMcgu/iIm0RdbyAkFXryanQgFPp8eAExkxY5i9R339kajSOCfSMsMWTMEjSwXRHYhrTi2G0Ny12C
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_abnormal_data_feature_generating.ipynb
# line:650: RNNTT+yatWPofsMhhgmT/6E6Oi9wxJb5LRIbBNtuNa4cPzqoGV9CxHjJbHqzBGTUjk0N2VIr8Hetje6Xmlbu17Zksq/Ft1Loydhh
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_case_study_Darwinbooks_recommend.ipynb
# line:1: RNNmKCpmlR7xUzp8/j6IolC9fPs/j5cuX5+bNm/z1118ANGzYkMGDB6vHExMTDcp//fXX+Pn5MWXKFAD8/Pz47bffGDdu3GPrkZW
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_handling_missing_data.ipynb
# line:1: RNN90kSbLb7br77ru1cOFCDRo0SAkJCVq0aJFGjRpl3oU1cuRITZkyRUVFRXr66aclfX17+bRp07jjCvACTzcGEO4CEnQ2b96sQ4
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Сlustering_inclass.ipynb
# line:1: RNNmzZFq1atcOfOnVy9TyW3sUSVvag4GrndL1FtQ2kXEIhqY6LiaOS2vJTWdwBiL/jIbf6I6stEtQvtu3jk0H5/VF6kSWR6gNyXv
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ABD_22_LABa_Kuzmin_Pandas.ipynb
# line:1: RNNR68Actnt24LqtMGZ6xaKXPOXliCa7sfT2xcDxjFzNocMdTtzLtn7qMoz1Cj8yHLaU8IKVc5S43ARuBfl3nyk1efOjvJ9uEnKT
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Clustering_algorithms_HW.ipynb
# line:96: RNNShmGPsbtEXWg8uPkzGpS58K7oB6/IbJ/7nVsI18KXGv14QiQSXgWvmMZT5uqcxXJGpi9pRg52YGIuFapGQhBmjC7PUCubrO/t
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Clustering_algorithms_HW.ipynb
# line:188: RNNC+JNEEkLehbb+cpL5/lC0Ez7oTWC3StW8Uo1apsqeEY41hrlSS74Szy39RF4W1C6OILZlkWNmgQNB3tumeVjl0JpHUWhfGmUx
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Clustering_algorithms_HW.ipynb
# line:324: RNN6H1rQm0FffwNk+MOrKP1sPErR2Y3KEFoNRc0/DMWneRxBBEGgvKzMa6Q8U2w2K9jqrnfx8CHVBoOqqiLLMi9Oe5qXn5vmU6ZI
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Clustering_algorithms_HW.ipynb
# line:422: RNNmmfUYssFovlcA6buywWi8VisVhmJeMYAflGHnYi8A7oQaN/Y+iRzzLOqODShV4Xy5uP1i//JTpLBOKkckc9x2HnGj3HbiTyUc
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Feature_selection_HW.ipynb
# line:1477: RNNmDBBbrdbvXr10uTJk9WiRQulpqZq1apVmjlzps4+++ywa3bu3FmS9PLLL6tp06ZyuVxq27atmjdvrhEjRuj222/Xr3/9a91ww
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/REGEX_practice.ipynb
# line:1: RNNVxP1HBtq/HvalC/t7Ee3zfa12Cw16VTwVOvW+pgZNfb24nvsEz1WYtAh5M4TSud+sWAVtdrJJL21BFcV2dgRx08nvJXS8xjhf
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Keras/Keras_lecture_1.ipynb
# line:1: RNNk9/Pvf/8Y777yDpKQkdO/eHUVFRbjjjjuwZcsWHDlyBKNHj8a4ceOQmppa73kWLFiASZMm4fjx47jjjjswefJk5Obm1nl8SUk
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Keras/Keras_Autoencoders.ipynb
# line:1: RNNyhkxxWh7X7/f7ZQ4Gu27zwUk5ewyQhBaCrVxlbKsoWs64D5l39kednp4WJw74dAUUepx99nqyPgRUyA5ZfZyY5+3KpcFZ28gA
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Keras/Keras_intro_NN_HW.ipynb
# line:1: RNNTfWZIh2PrLIBI+Oiz2c8xyPrW7nAs/36ajxjmz8Sou0AULayFBqZIMMhu69o1Mgc2reMtl9yEc+qBwBHDozS9pFxvo8v7Zww+
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:23: "* ***RNN***-модель.\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:658: "## Реккурентные нейронные сети (RNN)\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:666: "$y_i = RNN(x_{1:i})$, $y_i \\in \\mathbb{R}^{d_{out}}$\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:670: "$y_{1:n} = RNN^{*}(x_{1:n})$, $y_i \\in \\mathbb{R}^{d_{out}}$"
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:681: "$RNN^{*}(x_{1:n}, s_0) = y_{1:n}$\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:698: "Построим языковую модель на основе RNN с помощью pytorch."
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:838: "class RNN(nn.Module):\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:860: "model = RNN(trn_ds.vocab_size, hidden_size, trn_ds.vocab_size).to(device)\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:871: RNNXQ/2/v/nliqcI4AI8FBYmJuf4pJBEVbQ0dBaGwJYGEzmhFbWPtt/Er0PAJSGhQQkIhMUZjtLj3FtqYEGPh/tYMTpZFPbuwsOc
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/language_models_netology_original.ipynb
# line:1271: RNN: https://nlp.stanford.edu/blog/maximum-likelihood-decoding-with-rnns-the-good-the-bad-and-the-ug
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/NLP_topic_modelling_Аксенова.ipynb
# line:1261: RNNNVBEQM3tkisXCeJJWe1JlhDpJFrRpRPUSSZLCK+DUnLwdEV+SeRzKIC2sIyIZej4Sxi2jpIyUXJDNP1FcrEeGRhGkUxAbBMln
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:341: RNN: encoder и decoder.  Encoder считывает предложение и выдает вектор (закодированное предложение),
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:352: "class EncoderRNN(nn.Module):\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:354: "        super(EncoderRNN, self).__init__()\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:379: "class DecoderRNN(nn.Module):\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:381: "        super(DecoderRNN, self).__init__()\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:422: "class AttnDecoderRNN(nn.Module):\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:424: "        super(AttnDecoderRNN, self).__init__()\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:759: "encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq.ipynb
# line:760:      "attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/NLP_seq2seq_standartization.ipynb
# line:1: RNN.\n","\n","Настройте аппаратный ускоритель GPU (Среда выполнения -> Сменить среду выполнения -> G
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/topic_modelling_Arthur_Saprykin.ipynb
# line:951: RNNaKw4PuWSZOK5cJ7VWRqMronW/bUmX4LYNeZIea9aQIqYUEudWfo/jy/Nwg0JvBpi5lqLLF7sxyIafuRalCj1O02DmRfJrWLh/
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/NLP_classification_HW.ipynb
# line:1: RNN for classification"]},{"cell_type":"markdown","metadata":{"id":"T6qOclJPuyif"},"source":["### Py
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/NLP/seq2seq_BigramProbabalysticModel-RNNmodel.ipynb
# line:1: RNN***-модель.\n","\n"]},{"cell_type":"markdown","metadata":{"id":"OV9TZVMAFcaN"},"source":["## Bigr

# %% [markdown]
# #### `Renaming files in a folder`

# %%
import os


def rename_files_in_dir(dir_path):
    '''Rename all files in a directory by removing the prefix "NETOLOGY_"'''
    for count, filename in enumerate(os.listdir(dir_path)):
        # new_filename = filename.replace("._", "_")
        # new_filename = filename.replace("NETOLOGY_", "")
        new_filename = filename.replace(" ", "_")
        # dst = "file_" + str(count) + ".ext"
        src = dir_path + "/" + filename
        dst = dir_path + "/" + new_filename

        # rename() function will rename all the files
        os.rename(src, dst)


# rename_files_in_dir("path/to/dir")

# rename all files in current folder
rename_files_in_dir(os.getcwd())

# %%
import os


def rename_files_recursively(dir_path):
    '''Recursively rename all files in a directory by removing the prefix "NETOLOGY_"'''
    for root, dirs, files in os.walk(dir_path):
        for filename in files:
            # Exclude hidden files and directories
            if not filename.startswith("."):
                src = os.path.join(root, filename)
                new_filename = filename.replace(" ", "_")
                dst = os.path.join(root, new_filename)
                os.rename(src, dst)


# Example usage: recursively rename files in "path/to/dir"
rename_files_recursively(os.getcwd())

# %%
# freeze the environment to requirements.txt
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
