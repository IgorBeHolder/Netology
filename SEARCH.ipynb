# %% [markdown]
# # `Searching Notebooks for a Code Snippet`
# From September 2022 I started learning Python online.
# Until everything is settled in my head,
# I am faced with the need to search for my own code snippets among all this variety of information.
# This piece of code will help you look up your Python notebooks.
# It seems to me it's quicker than using a 'grep'.
# You can define a strict search logic or case sensetive one.
# Hope it helps.
# Enjoy)

# %%
import glob
import os

# Search pattern: one level up in the directory hierarchy
# pattern = '../**/*.ipynb'
pattern = '*.ipynb'

dir_path = os.getcwd()
# Search logic: All occurrences must be found
all_occurs = True

# Case sensitive search
case_sens = False

# Result length
res_length = 20

# Search strings
# inq = ['kwarg', 'arg']
inq = input('Input search strings separated by whitespace:').split()

# Print search information
print(f'Looking for: {inq} in {pattern} files')
print(f'Incl. all occurrences: {all_occurs}')
print(f'Case sensitive: {case_sens}')
print('File:', " "*8, ': Search result:')
print('.'*80)

for filepath in glob.iglob(pattern, recursive=True): # recursive= True: include subfolders

    with open(filepath, encoding='UTF-8') as file:

        s = file.read()
        chunk = ''
        for search_str in inq:
            if case_sens:
                ind = s.find( search_str )
            else:
                ind = s.lower().find( search_str.lower() )

            found = ( ind != -1 ) 
            
            # Concatenate the chunks and print the result if any chunks were found
            if found:
                chunk +=  (s[ind:ind + res_length]) + ", "
            if (not found) and all_occurs:
                break       
            
                     
        if found:
            # print(dir_path + '/' + filepath.ljust(50)," "*3 + ":", chunk)
            print(dir_path + '/' + filepath +"\n" + " "*15 + ":", chunk)
# Out:
# Looking for: ['range'] in *.ipynb files
# Incl. all occurrences: True
# Case sensitive: False
# File:          : Search result:
# ................................................................................
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/DLS_Python_Base.ipynb
#                : range() сам по себе ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Logres_affair.ipynb
#                : RangeIndex: 6366 ent,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_A_B_testing_HW.ipynb
#                : range(n_samples):\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/MathPlotLib_VIZ2.ipynb
#                : range(-3.0,3.0,delta,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_HW1_Основы.ipynb
#                : range(3):\n","    su,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_case_study_linreg_confidence_interval.ipynb
#                : range</td>\n","     ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_HW2.ipynb
#                : range(1,10)]).reshap,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_case_study_Darwinbooks_recommend.ipynb
#                : range',\n"," 'genera,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Pandas_HW_funcs_group.ipynb
#                : range (1950,2011) )\,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ERRORS_DATES_.ipynb
#                : range, которая возвр,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_LogRegression_SVC_HW.ipynb
#                : RangeIndex: 48842 en,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/SCRAPING_PARSING.ipynb
#                : range\" type=\"radio,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/MathPlotLib_VIZ3.ipynb
#                : range(-3.0,3.0,delta,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_Confidential_intervals_HW.ipynb
#                : RangeIndex: 4074 ent,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Numpy_HW.ipynb
#                : range(r,-1,-1)))\n",,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_Data_Visualization_HW.ipynb
#                : RangeIndex: 40739 en,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_HW_8.ipynb
#                : range(n):\n",
#       ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_Datatypes_LOOPs.ipynb
#                : range(N))\n","print(,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Gradient_descent.ipynb
#                : range(n_epochs):\n",,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Metrics_Regularization_HW.ipynb
#                : RangeIndex: 11538 en,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/DLS_simpsons_baseline.ipynb
#                : range\n","from tqdm ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Pandas_pivot_and_str.ipynb
#                : RangeIndex: 18938 en,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_Advanced_Optimization.ipynb
#                : range(-2, 2, 0.1)\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Pandas_lecture_04.ipynb
#                : range(3)]\n","df1 = ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_t_Tests.ipynb
#                : range', ls=':', lw=2,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Pandas_basics.ipynb
#                : range(\"1/1/2000\", ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_Scrapping_Parsing_HW.ipynb
#                : range(1,npages+1):\n,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/DateTimeTimeZone.ipynb
#                : range(10)]"
#    ]
#   },
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/COVID-19_visualization.ipynb
#                : RangeIndex: 161568 e,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_Tricks.ipynb
#                : range(0, 10) | <rang,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ERRORS_DATES_HW.ipynb
#                : range, которая возвр,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_FILES_Read_Write_and_pip_JSON.ipynb
#                : range(5)]) # 5 раз п,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_7_ERRORS_DATETIME.ipynb
#                : range(len(dates_list,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_Binary_Classification_wo_sklearn_HW.ipynb
#                : range(len(X)//batch_,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Pandas_ESSENTIALS.ipynb
#                : RangeIndex(start=0, ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Pandas_vs_set_and_dict.ipynb
#                : range(10000))"
#    ]
# ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_LossFunc_LinRegrOptimization_HW.ipynb
#                : range(max_iter):\n",,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_linear_polynomial_regression.ipynb
#                : RangeIndex: 804 entr,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_Dynamic_Programming.ipynb
#                : range(1, k):   # ite,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_Bases2.ipynb
#                : range(1, 20):\n","  ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/python_open_files.ipynb
#                : range(max(lengths)),,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_LAB.ipynb
#                : range(1,4):   \n"," ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_HW9.ipynb
#                : range(len(n1)):\n",
# ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_HW_6.ipynb
#                : range is appr. 30, p,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_chaining_PCA_logistic_regression.ipynb
#                : range(1, pca.n_compo,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_Confidence_Intervals.ipynb
#                : RangeIndex: 4074 ent,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/DLS_linreg_regularization.ipynb
#                : range')\n","\n","plt,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_cross_val_score.ipynb
#                : range 0..16.\n",
#    ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_CS_videogames_HW.ipynb
#                : RangeIndex: 16719 en,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ML_log_regression_SVM.ipynb
#                : RangeIndex: 11538 en,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Python_list_dict.ipynb
#                : range(1, 20):\n","  ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_Power_Min_sample_size_HW.ipynb
#                : range(10, 500, 10))\,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_Case_Power_MinSampleSize_HW.ipynb
#                : range(10, 500, 10))\,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_case_study_bs_conf_int.ipynb
#                : range(bstrap_iter):\,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_Numpy_Matrix.ipynb
#                : range\n",
#     "\n",
# ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/Pandas_MULTIindex.ipynb
#                : range(10) ) , set((r,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/ABD_22_Total_HW.ipynb
#                : RangeIndex(start=0, ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_HW_7.ipynb
#                : range(1):\n",
#       ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/MathPlotLib_VIZ.ipynb
#                : range(50),\n",
#     ",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/stats_DispAnalysis_ABtests.ipynb
#                : range statistic."
#   ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_Masterclass.ipynb
#                : range(len(vecs)):\n",
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_HW_Capstone.ipynb
#                : range\")\n",
#        ,
# /Users/velo1/SynologyDrive/GIT_syno/Mac/Netology/math_LA_HW_5.ipynb
#                : range(-2, 3, 0.1)\n",

# %%
# data = pd.read_csv('/Users/velo1/SynologyDrive/GIT_syno/data/video_games_sales.csv')
# data.head()

# %%
# !ls

# %% [markdown]
# #### `Renaming files in a folder`

# %%
import os

def rename_files_in_dir(dir_path):
    for count, filename in enumerate(os.listdir(dir_path)):

        # new_filename = filename.replace("._", "_")        
        # new_filename = filename.replace("NETOLOGY_", "")
        new_filename = filename.replace(" ", "_")  
        # dst = "file_" + str(count) + ".ext"
        src = dir_path + '/' + filename
        dst = dir_path + '/' + new_filename
        
        # rename() function will rename all the files 
        os.rename(src, dst)


# rename_files_in_dir("path/to/dir")

# rename all files in current folder
rename_files_in_dir( os.getcwd() )
